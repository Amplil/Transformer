# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
notebook_dir="/content/drive/MyDrive/Colab Notebooks/Transformer"

# %%
cd "/content/drive/MyDrive/Colab Notebooks/Transformer"
# Out:
# /content/drive/.shortcut-targets-by-id/17vBJAZeuDCte4t5jYXL1emXc1Rm4jOqV/Transformer

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/packages")
import slacknotice # オリジナルモジュール slacknotice.send("")

# %% [markdown]
# # ライブラリ読み込み

# %%
# !apt install aptitude
# !aptitude install mecab libmecab-dev mecab-ipadic-utf8 git make curl xz-utils file -y
# !pip install mecab-python3==0.6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aptitude-common libcgi-fast-perl libcgi-pm-perl libclass-accessor-perl
#   libcwidget3v5 libencode-locale-perl libfcgi-perl libhtml-parser-perl
#   libhtml-tagset-perl libhttp-date-perl libhttp-message-perl libio-html-perl
#   libio-string-perl liblwp-mediatypes-perl libparse-debianchangelog-perl
#   libsigc++-2.0-0v5 libsub-name-perl libtimedate-perl liburi-perl libxapian30
# Suggested packages:
#   aptitude-doc-en | aptitude-doc apt-xapian-index debtags tasksel
#   libcwidget-dev libdata-dump-perl libhtml-template-perl libxml-simple-perl
#   libwww-perl xapian-tools
# The following NEW packages will be installed:
#   aptitude aptitude-common libcgi-fast-perl libcgi-pm-perl
#   libclass-accessor-perl libcwidget3v5 libencode-locale-perl libfcgi-perl
#   libhtml-parser-perl libhtml-tagset-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl libio-string-perl
#   liblwp-mediatypes-perl libparse-debianchangelog-perl libsigc++-2.0-0v5
#   libsub-name-perl libtimedate-perl liburi-perl libxapian30
# 0 upgraded, 21 newly installed, 0 to remove and 39 not upgraded.
# Need to get 3,877 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude-common all 0.8.10-6ubuntu1 [1,014 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigc++-2.0-0v5 amd64 2.10.0-2 [10.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcwidget3v5 amd64 0.5.17-7 [286 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxapian30 amd64 1.4.5-1ubuntu0.1 [631 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude amd64 0.8.10-6ubuntu1 [1,269 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tagset-perl all 3.20-3 [12.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 liburi-perl all 1.73-1 [77.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-parser-perl amd64 3.72-3build1 [85.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-pm-perl all 4.38-1 [185 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfcgi-perl amd64 0.78-2build1 [32.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-fast-perl all 1:2.13-1 [9,940 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsub-name-perl amd64 0.21-1build1 [11.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libclass-accessor-perl all 0.51-1 [21.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-date-perl all 6.02-1 [10.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-mediatypes-perl all 6.02-1 [21.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-message-perl all 6.14-1 [72.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-string-perl all 1.08-3 [11.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libparse-debianchangelog-perl all 1.2.0-12 [49.5 kB]
# Fetched 3,877 kB in 0s (8,257 kB/s)
# Selecting previously unselected package aptitude-common.
# (Reading database ... 156210 files and directories currently installed.)
# Preparing to unpack .../00-aptitude-common_0.8.10-6ubuntu1_all.deb ...
# Unpacking aptitude-common (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libsigc++-2.0-0v5:amd64.
# Preparing to unpack .../01-libsigc++-2.0-0v5_2.10.0-2_amd64.deb ...
# Unpacking libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Selecting previously unselected package libcwidget3v5:amd64.
# Preparing to unpack .../02-libcwidget3v5_0.5.17-7_amd64.deb ...
# Unpacking libcwidget3v5:amd64 (0.5.17-7) ...
# Selecting previously unselected package libxapian30:amd64.
# Preparing to unpack .../03-libxapian30_1.4.5-1ubuntu0.1_amd64.deb ...
# Unpacking libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Selecting previously unselected package aptitude.
# Preparing to unpack .../04-aptitude_0.8.10-6ubuntu1_amd64.deb ...
# Unpacking aptitude (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../05-libhtml-tagset-perl_3.20-3_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-3) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../06-liburi-perl_1.73-1_all.deb ...
# Unpacking liburi-perl (1.73-1) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../07-libhtml-parser-perl_3.72-3build1_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-3build1) ...
# Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../08-libcgi-pm-perl_4.38-1_all.deb ...
# Unpacking libcgi-pm-perl (4.38-1) ...
# Selecting previously unselected package libfcgi-perl.
# Preparing to unpack .../09-libfcgi-perl_0.78-2build1_amd64.deb ...
# Unpacking libfcgi-perl (0.78-2build1) ...
# Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../10-libcgi-fast-perl_1%3a2.13-1_all.deb ...
# Unpacking libcgi-fast-perl (1:2.13-1) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../11-libsub-name-perl_0.21-1build1_amd64.deb ...
# Unpacking libsub-name-perl (0.21-1build1) ...
# Selecting previously unselected package libclass-accessor-perl.
# Preparing to unpack .../12-libclass-accessor-perl_0.51-1_all.deb ...
# Unpacking libclass-accessor-perl (0.51-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../13-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../15-libhttp-date-perl_6.02-1_all.deb ...
# Unpacking libhttp-date-perl (6.02-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../16-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../17-liblwp-mediatypes-perl_6.02-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.02-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../18-libhttp-message-perl_6.14-1_all.deb ...
# Unpacking libhttp-message-perl (6.14-1) ...
# Selecting previously unselected package libio-string-perl.
# Preparing to unpack .../19-libio-string-perl_1.08-3_all.deb ...
# Unpacking libio-string-perl (1.08-3) ...
# Selecting previously unselected package libparse-debianchangelog-perl.
# Preparing to unpack .../20-libparse-debianchangelog-perl_1.2.0-12_all.deb ...
# Unpacking libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhtml-tagset-perl (3.20-3) ...
# Setting up libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up aptitude-common (0.8.10-6ubuntu1) ...
# Setting up liblwp-mediatypes-perl (6.02-1) ...
# Setting up liburi-perl (1.73-1) ...
# Setting up libhtml-parser-perl (3.72-3build1) ...
# Setting up libcgi-pm-perl (4.38-1) ...
# Setting up libio-string-perl (1.08-3) ...
# Setting up libsub-name-perl (0.21-1build1) ...
# Setting up libfcgi-perl (0.78-2build1) ...
# Setting up libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up libhttp-date-perl (6.02-1) ...
# Setting up libcgi-fast-perl (1:2.13-1) ...
# Setting up libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhttp-message-perl (6.14-1) ...
# Setting up libcwidget3v5:amd64 (0.5.17-7) ...
# Setting up aptitude (0.8.10-6ubuntu1) ...
# update-alternatives: using /usr/bin/aptitude-curses to provide /usr/bin/aptitude (aptitude) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# git is already installed at the requested version (1:2.17.1-1ubuntu0.9)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.16)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# git is already installed at the requested version (1:2.17.1-1ubuntu0.9)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.16)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# The following NEW packages will be installed:
#   file libmagic-mgc{a} libmagic1{a} libmecab-dev libmecab2{a} mecab mecab-ipadic{a} mecab-ipadic-utf8 mecab-jumandic{a} mecab-jumandic-utf8{a} mecab-utils{a}
# 0 packages upgraded, 11 newly installed, 0 to remove and 39 not upgraded.
# Need to get 29.3 MB of archives. After unpacking 282 MB will be used.
# Get: 1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get: 2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get: 3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get: 4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab2 amd64 0.996-5 [257 kB]
# Get: 5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab-dev amd64 0.996-5 [308 kB]
# Get: 6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-utils amd64 0.996-5 [4,856 B]
# Get: 7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic-utf8 all 7.0-20130310-4 [16.2 MB]
# Get: 8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic all 7.0-20130310-4 [2,212 B]
# Get: 9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic all 2.7.0-20070801+main-1 [12.1 MB]
# Get: 10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab amd64 0.996-5 [132 kB]
# Get: 11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-1 [3,522 B]
# Fetched 29.3 MB in 2s (14.5 MB/s)
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 156669 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmecab2:amd64.
# Preparing to unpack .../03-libmecab2_0.996-5_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-5) ...
# Selecting previously unselected package libmecab-dev.
# Preparing to unpack .../04-libmecab-dev_0.996-5_amd64.deb ...
# Unpacking libmecab-dev (0.996-5) ...
# Selecting previously unselected package mecab-utils.
# Preparing to unpack .../05-mecab-utils_0.996-5_amd64.deb ...
# Unpacking mecab-utils (0.996-5) ...
# Selecting previously unselected package mecab-jumandic-utf8.
# Preparing to unpack .../06-mecab-jumandic-utf8_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic-utf8 (7.0-20130310-4) ...
# Selecting previously unselected package mecab-jumandic.
# Preparing to unpack .../07-mecab-jumandic_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic (7.0-20130310-4) ...
# Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../08-mecab-ipadic_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic (2.7.0-20070801+main-1) ...
# Selecting previously unselected package mecab.
# Preparing to unpack .../09-mecab_0.996-5_amd64.deb ...
# Unpacking mecab (0.996-5) ...
# Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../10-mecab-ipadic-utf8_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Setting up libmecab2:amd64 (0.996-5) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up mecab-utils (0.996-5) ...
# Setting up mecab-ipadic (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up libmecab-dev (0.996-5) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up mecab-jumandic-utf8 (7.0-20130310-4) ...
# Compiling Juman dictionary for Mecab.
# reading /usr/share/mecab/dic/juman/unk.def ... 37
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/Rengo.csv ... 1118
# reading /usr/share/mecab/dic/juman/Suffix.csv ... 2128
# reading /usr/share/mecab/dic/juman/Auto.csv ... 18931
# reading /usr/share/mecab/dic/juman/Noun.koyuu.csv ... 7964
# reading /usr/share/mecab/dic/juman/ContentW.csv ... 551145
# reading /usr/share/mecab/dic/juman/Postp.csv ... 108
# reading /usr/share/mecab/dic/juman/Emoticon.csv ... 972
# reading /usr/share/mecab/dic/juman/Assert.csv ... 34
# reading /usr/share/mecab/dic/juman/Wikipedia.csv ... 167709
# reading /usr/share/mecab/dic/juman/AuxV.csv ... 593
# reading /usr/share/mecab/dic/juman/Noun.hukusi.csv ... 81
# reading /usr/share/mecab/dic/juman/Prefix.csv ... 90
# reading /usr/share/mecab/dic/juman/Noun.suusi.csv ... 49
# reading /usr/share/mecab/dic/juman/Special.csv ... 158
# reading /usr/share/mecab/dic/juman/Noun.keishiki.csv ... 8
# reading /usr/share/mecab/dic/juman/Demonstrative.csv ... 97
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/matrix.def ... 1876x1876
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic-utf8 to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mecab (0.996-5) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-jumandic (7.0-20130310-4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#
# Collecting mecab-python3==0.6
#   Downloading mecab-python3-0.6.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 210 kB/s
# Building wheels for collected packages: mecab-python3
#   Building wheel for mecab-python3 (setup.py) ... done
#   Created wheel for mecab-python3: filename=mecab_python3-0.6-cp37-cp37m-linux_x86_64.whl size=156597 sha256=f0b1cc97c6b17db7aa42b091c998ed85ff95486e9232a2ba0a9140b1587d4238
#   Stored in directory: /root/.cache/pip/wheels/9a/84/a1/7331af569b22ef2cbbc2a829a30145130c52663b0c9d34bcf5
# Successfully built mecab-python3
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-0.6

# %%
import numpy as np
import os
import time
import MeCab

import preprocess_utils_law
import model
import weight_utils

import tensorflow.keras as keras
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# # 日英法令対訳コーパス ダウンロード

# %%
# !wget http://www.phontron.com/jaen-law/jaen-law.tar.gz
# Out:
# --2022-04-07 09:36:53--  http://www.phontron.com/jaen-law/jaen-law.tar.gz
# Resolving www.phontron.com (www.phontron.com)... 208.113.196.149
# Connecting to www.phontron.com (www.phontron.com)|208.113.196.149|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18276054 (17M) [application/gzip]
# Saving to: ‘jaen-law.tar.gz.1’
#
# jaen-law.tar.gz.1   100%[===================>]  17.43M  37.0MB/s    in 0.5s
#
# 2022-04-07 09:36:54 (37.0 MB/s) - ‘jaen-law.tar.gz.1’ saved [18276054/18276054]

# %%
# !tar -xzf jaen-law.tar.gz # tar.gzの解凍

# %% [markdown]
# # データ読み込み

# %%
dataset = preprocess_utils_law.CreateData(
    corpus_path_source = './jaen-law/txt/law-corpus.ja',
    corpus_path_target = './jaen-law/txt/law-corpus.en',
    do_shuffle=True,
    seed_value=123,
    split_percent=0.95 # 学習データの割合
)

train_source, train_target, test_source, test_target= dataset.split_data()

print('**** Amount of data ****')
print('train_source： ', len(train_source))
print('train_target： ', len(train_target))
print('test_source： ', len(test_source))
print('test_target： ', len(test_target))
print('\n')
print('**** Train data example ****')
print('Source Example： ', train_source[0])
print('Target Example： ', train_target[0])
print('\n')
print('**** Test data example ****')
print('Source Example： ', test_source[0])
print('Target Example： ', test_target[0])
# Out:
# **** Amount of data ****
# train_source：  249327
# train_target：  249327
# test_source：  13122
# test_target：  13122
#
#
# **** Train data example ****
# Source Example：  第二十六条の四　前条第三項の認定を受けた事業主（以下「認定事業主」という。）は、当該認定に係る実施計画を変更しようとするときは、厚生労働大臣の認定を受けなければならない。
#
# Target Example：  Article 26-4  (1) An employer who has received the accreditation set forth in paragraph (3) of the preceding Article (hereinafter referred to as an "accredited employer") shall, when intending to change the plan for providing training pertaining to said accreditation, receive accreditation thereof from the Minister of Health, Labour and Welfare.
#
#
#
# **** Test data example ****
# Source Example：  附　則　〔平成十九年三月三十一日法律第二十三号〕〔抄〕
#
# Target Example：  Supplementary Provisions  [Act No. 23 of March 31, 2007]  [Extract]

# %% [markdown]
# # 前処理

# %%
BATCH_SIZE = 64 # バッチサイズ
MAX_LENGTH = 60 # シーケンスの長さ
USE_TPU = True # TPUを使うか
BUFFER_SIZE = 50000

# %%
train_dataset = preprocess_utils_law.PreprocessData(
    mecab = MeCab.Tagger("-Ochasen"),
    source_data = train_source,
    target_data = train_target,
    max_length = MAX_LENGTH,
    batch_size = BATCH_SIZE,
    test_flag = False,
    train_dataset = None,
)

train_dataset.preprocess_data()

# %% [markdown]
# # バッチ作成

# %%
if USE_TPU:
  tpu_grpc_url = "grpc://" + os.environ["COLAB_TPU_ADDR"]
  tpu_cluster_resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_grpc_url)
  tf.config.experimental_connect_to_cluster(tpu_cluster_resolver)
  tf.tpu.experimental.initialize_tpu_system(tpu_cluster_resolver)    
  strategy = tf.distribute.TPUStrategy(tpu_cluster_resolver)

trainset = tf.data.Dataset.from_tensor_slices((train_dataset.source_vector, train_dataset.target_vector))
trainset = trainset.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))).shuffle(buffer_size=BUFFER_SIZE).batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

if USE_TPU:
  trainset = strategy.experimental_distribute_dataset(trainset)
# Out:
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.38.55.178:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.38.55.178:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %% [markdown]
# # モデル定義

# %%
num_layers=4 # レイヤー数
d_model=64 # 中間層の次元数
num_heads=4 # Multi Head Attentionのヘッド数
dff=2048 # Feed Forward Networkの次元数
dropout_rate = 0.1 # ドロップアウト率

source_vocab_size = max(train_dataset.source_token.values()) + 1 # source文の語彙数
target_vocab_size = max(train_dataset.target_token.values()) + 1 # target文の語彙数

# %%
# 重み初期化
def initialize_weight(checkpoint_path, optimizer, transformer, max_length, batch_size, use_tpu=False):

  if os.path.exists(checkpoint_path+'.pkl'):
    if use_tpu:
      number_of_tpu_cores = tpu_cluster_resolver.num_accelerators()['TPU']
      initialize_source, initialize_target = [[1]*max_length]*number_of_tpu_cores, [[1]*max_length]*number_of_tpu_cores
      initialize_set = tf.data.Dataset.from_tensor_slices((initialize_source, initialize_target))
      initialize_set = initialize_set.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))
          ).shuffle(buffer_size=BUFFER_SIZE).batch(batch_size).prefetch(
              buffer_size=tf.data.experimental.AUTOTUNE
          )
      initialize_set = strategy.experimental_distribute_dataset(initialize_set)

      for inp, tar in initialize_set:
        distributed_train_step(inp, tar)

    else:
      initialize_set = tf.ones([batch_size, max_length], tf.int64)
      train_step(initialize_set, initialize_set)
    
    try:
      weight_utils.load_weights_from_pickle(checkpoint_path, optimizer, transformer)
    except:
      print('Failed to load checkpoints.')

  else:
    print('No available checkpoints.')

# %% [markdown]
# # 学習実行

# %%
with strategy.scope():
  # Transformer
  transformer = model.Transformer(num_layers, d_model, num_heads, dff,
                            source_vocab_size, target_vocab_size, 
                            pe_input=source_vocab_size, 
                            pe_target=target_vocab_size,
                            rate=dropout_rate)

  # Learning Rate
  learning_rate = model.CustomSchedule(d_model)

  # Optimizer
  optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                      epsilon=1e-9)

  # Loss
  loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

  # Loss Function
  def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

  # Metrics
  train_loss = tf.keras.metrics.Mean(name='train_loss')
  train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

  # Checkpoint
  #checkpoint_path = "/content/drive/My Drive/Transformer-master/checkpoints/tpu/model"
  checkpoint_path = notebook_dir+"/checkpoints/tpu/model"


  def train_step(inp, tar):
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]
    
    enc_padding_mask, combined_mask, dec_padding_mask = model.create_masks(inp, tar_inp)
    
    with tf.GradientTape() as tape:
      predictions, _ = transformer(inp, tar_inp, 
                                  True, 
                                  enc_padding_mask, 
                                  combined_mask, 
                                  dec_padding_mask)
      loss = loss_function(tar_real, predictions)

    gradients = tape.gradient(loss, transformer.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
    
    train_loss(loss)
    train_accuracy(tar_real, predictions)

  @tf.function
  def distributed_train_step(X, y):
    per_replica_losses = strategy.run(train_step, args=(X, y))
    return strategy.reduce(tf.distribute.ReduceOp.MEAN, per_replica_losses, axis=None)

  # Initialize Weight
  initialize_weight(checkpoint_path, optimizer, transformer, MAX_LENGTH, BATCH_SIZE, use_tpu=USE_TPU)

  EPOCHS = 30
  batch = 0

  for epoch in range(EPOCHS):
    start = time.time()
    
    train_loss.reset_states()
    train_accuracy.reset_states()
    
    for inp, tar in trainset:
      distributed_train_step(inp, tar)
      
      if batch % 50 == 0:
        print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
            epoch + 1, batch, train_loss.result(), train_accuracy.result()))
        
      batch+=1
        
    if (epoch + 1) % 5 == 0:
      weight_utils.save_weights_as_pickle(checkpoint_path, optimizer, transformer)
      
    print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                  train_loss.result(), 
                                                  train_accuracy.result()))

    print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# *** Failed to load model weights ***
# ['transformer/encoder/embedding/embeddings:0', 'transformer/encoder/encoder_layer/multi_head_attention/dense/kernel:0', 'transformer/encoder/encoder_layer/multi_head_attention/dense/bias:0', 'transformer/encoder/encoder_layer/multi_head_attention/dense_1/kernel:0', 'transformer/encoder/encoder_layer/multi_head_attention/dense_1/bias:0', 'transformer/encoder/encoder_layer/multi_head_attention/dense_2/kernel:0', 'transformer/encoder/encoder_layer/multi_head_attention/dense_2/bias:0', 'transformer/encoder/encoder_layer/multi_head_attention/dense_3/kernel:0', 'transformer/encoder/encoder_layer/multi_head_attention/dense_3/bias:0', 'dense_4/kernel:0', 'dense_4/bias:0', 'dense_5/kernel:0', 'dense_5/bias:0', 'transformer/encoder/encoder_layer/layer_normalization/gamma:0', 'transformer/encoder/encoder_layer/layer_normalization/beta:0', 'transformer/encoder/encoder_layer/layer_normalization_1/gamma:0', 'transformer/encoder/encoder_layer/layer_normalization_1/beta:0', 'transformer/encoder/encoder_layer_1/multi_head_attention_1/dense_6/kernel:0', 'transformer/encoder/encoder_layer_1/multi_head_attention_1/dense_6/bias:0', 'transformer/encoder/encoder_layer_1/multi_head_attention_1/dense_7/kernel:0', 'transformer/encoder/encoder_layer_1/multi_head_attention_1/dense_7/bias:0', 'transformer/encoder/encoder_layer_1/multi_head_attention_1/dense_8/kernel:0', 'transformer/encoder/encoder_layer_1/multi_head_attention_1/dense_8/bias:0', 'transformer/encoder/encoder_layer_1/multi_head_attention_1/dense_9/kernel:0', 'transformer/encoder/encoder_layer_1/multi_head_attention_1/dense_9/bias:0', 'dense_10/kernel:0', 'dense_10/bias:0', 'dense_11/kernel:0', 'dense_11/bias:0', 'transformer/encoder/encoder_layer_1/layer_normalization_2/gamma:0', 'transformer/encoder/encoder_layer_1/layer_normalization_2/beta:0', 'transformer/encoder/encoder_layer_1/layer_normalization_3/gamma:0', 'transformer/encoder/encoder_layer_1/layer_normalization_3/beta:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_12/kernel:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_12/bias:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_13/kernel:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_13/bias:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_14/kernel:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_14/bias:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_15/kernel:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_15/bias:0', 'dense_16/kernel:0', 'dense_16/bias:0', 'dense_17/kernel:0', 'dense_17/bias:0', 'transformer/encoder/encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/encoder/encoder_layer_2/layer_normalization_4/beta:0', 'transformer/encoder/encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/encoder/encoder_layer_2/layer_normalization_5/beta:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense
_12/bias:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_13/kernel:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_13/bias:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_14/kernel:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_14/bias:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_15/kernel:0', 'transformer/encoder/encoder_layer_2/multi_head_attention_2/dense_15/bias:0', 'dense_16/kernel:0', 'dense_16/bias:0', 'dense_17/kernel:0', 'dense_17/bias:0', 'transformer/encoder/encoder_layer_2/layer_normalization_4/gamma:0', 'transformer/encoder/encoder_layer_2/layer_normalization_4/beta:0', 'transformer/encoder/encoder_layer_2/layer_normalization_5/gamma:0', 'transformer/encoder/encoder_layer_2/layer_normalization_5/beta:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense_18/kernel:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense_18/bias:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense_19/kernel:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense_19/bias:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense_20/kernel:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense_20/bias:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense_21/kernel:0', 'transformer/encoder/encoder_layer_3/multi_head_attention_3/dense_21/bias:0', 'dense_22/kernel:0', 'dense_22/bias:0', 'dense_23/kernel:0', 'dense_23/bias:0', 'transformer/encoder/encoder_layer_3/layer_normalization_6/gamma:0', 'transformer/encoder/encoder_layer_3/layer_normalization_6/beta:0', 'transformer/encoder/encoder_layer_3/layer_normalization_7/gamma:0', 'transformer/encoder/encoder_layer_3/layer_normalization_7/beta:0', 'transformer/decoder/embedding_1/embeddings:0', 'transformer/decoder/decoder_ ...
# Epoch 1 Batch 0 Loss 4.2590 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 3.8668 Accuracy 0.0000
# Epoch 1 Batch 100 Loss 3.8776 Accuracy 0.0077
# Epoch 1 Batch 150 Loss 3.8829 Accuracy 0.0113
# Epoch 1 Batch 200 Loss 3.8375 Accuracy 0.0145
# Epoch 1 Batch 250 Loss 3.7599 Accuracy 0.0172
# Epoch 1 Batch 300 Loss 3.6747 Accuracy 0.0191
# Epoch 1 Batch 350 Loss 3.5893 Accuracy 0.0204
# Epoch 1 Batch 400 Loss 3.4976 Accuracy 0.0213
# Epoch 1 Batch 450 Loss 3.4005 Accuracy 0.0230
# Epoch 1 Batch 500 Loss 3.3063 Accuracy 0.0260
# Epoch 1 Batch 550 Loss 3.2233 Accuracy 0.0289
# Epoch 1 Batch 600 Loss 3.1509 Accuracy 0.0319
# Epoch 1 Batch 650 Loss 3.0870 Accuracy 0.0354
# Epoch 1 Batch 700 Loss 3.0250 Accuracy 0.0387
# Epoch 1 Batch 750 Loss 2.9574 Accuracy 0.0419
# Epoch 1 Batch 800 Loss 2.8944 Accuracy 0.0455
# Epoch 1 Batch 850 Loss 2.8347 Accuracy 0.0492
# Epoch 1 Batch 900 Loss 2.7760 Accuracy 0.0526
# Epoch 1 Batch 950 Loss 2.7201 Accuracy 0.0559
# Epoch 1 Batch 1000 Loss 2.6702 Accuracy 0.0592
# Epoch 1 Batch 1050 Loss 2.6223 Accuracy 0.0623
# Epoch 1 Batch 1100 Loss 2.5770 Accuracy 0.0655
# Epoch 1 Batch 1150 Loss 2.5350 Accuracy 0.0684
# Epoch 1 Batch 1200 Loss 2.4939 Accuracy 0.0712
# Epoch 1 Batch 1250 Loss 2.4547 Accuracy 0.0738
# Epoch 1 Batch 1300 Loss 2.4183 Accuracy 0.0764
# Epoch 1 Batch 1350 Loss 2.3839 Accuracy 0.0788
# Epoch 1 Batch 1400 Loss 2.3527 Accuracy 0.0812
# Epoch 1 Batch 1450 Loss 2.3225 Accuracy 0.0835
# Epoch 1 Batch 1500 Loss 2.2936 Accuracy 0.0857
# Epoch 1 Batch 1550 Loss 2.2656 Accuracy 0.0879
# Epoch 1 Batch 1600 Loss 2.2390 Accuracy 0.0899
# Epoch 1 Batch 1650 Loss 2.2132 Accuracy 0.0919
# Epoch 1 Batch 1700 Loss 2.1885 Accuracy 0.0938
# Epoch 1 Batch 1750 Loss 2.1641 Accuracy 0.0957
# Epoch 1 Batch 1800 Loss 2.1408 Accuracy 0.0974
# Epoch 1 Batch 1850 Loss 2.1185 Accuracy 0.0991
# Epoch 1 Batch 1900 Loss 2.0969 Accuracy 0.1008
# Epoch 1 Batch 1950 Loss 2.0765 Accuracy 0.1023
# Epoch 1 Batch 2000 Loss 2.0568 Accuracy 0.1038
# Epoch 1 Batch 2050 Loss 2.0375 Accuracy 0.1053
# Epoch 1 Batch 2100 Loss 2.0195 Accuracy 0.1068
# Epoch 1 Batch 2150 Loss 2.0023 Accuracy 0.1083
# Epoch 1 Batch 2200 Loss 1.9843 Accuracy 0.1096
# Epoch 1 Batch 2250 Loss 1.9677 Accuracy 0.1111
# Epoch 1 Batch 2300 Loss 1.9513 Accuracy 0.1124
# Epoch 1 Batch 2350 Loss 1.9350 Accuracy 0.1136
# Epoch 1 Batch 2400 Loss 1.9196 Accuracy 0.1149
# Epoch 1 Batch 2450 Loss 1.9050 Accuracy 0.1161
# Epoch 1 Batch 2500 Loss 1.8906 Accuracy 0.1172
# Epoch 1 Batch 2550 Loss 1.8771 Accuracy 0.1185
# Epoch 1 Batch 2600 Loss 1.8639 Accuracy 0.1197
# Epoch 1 Batch 2650 Loss 1.8504 Accuracy 0.1209
# Epoch 1 Batch 2700 Loss 1.8373 Accuracy 0.1219
# Epoch 1 Batch 2750 Loss 1.8241 Accuracy 0.1231
# Epoch 1 Batch 2800 Loss 1.8120 Accuracy 0.1242
# Epoch 1 Batch 2850 Loss 1.7995 Accuracy 0.1253
# Epoch 1 Batch 2900 Loss 1.7878 Accuracy 0.1264
# Epoch 1 Loss 1.7816 Accuracy 0.1269
# Time taken for 1 epoch: 208.5551769733429 secs
#
# Epoch 2 Batch 2950 Loss 1.0645 Accuracy 0.1885
# Epoch 2 Batch 3000 Loss 1.0811 Accuracy 0.1868
# Epoch 2 Batch 3050 Loss 1.0867 Accuracy 0.1896
# Epoch 2 Batch 3100 Loss 1.0743 Accuracy 0.1895
# Epoch 2 Batch 3150 Loss 1.0693 Accuracy 0.1895
# Epoch 2 Batch 3200 Loss 1.0641 Accuracy 0.1898
# Epoch 2 Batch 3250 Loss 1.0615 Accuracy 0.1903
# Epoch 2 Batch 3300 Loss 1.0609 Accuracy 0.1909
# Epoch 2 Batch 3350 Loss 1.0579 Accuracy 0.1919
# Epoch 2 Batch 3400 Loss 1.0523 Accuracy 0.1925
# Epoch 2 Batch 3450 Loss 1.0469 Accuracy 0.1923
# Epoch 2 Batch 3500 Loss 1.0446 Accuracy 0.1928
# Epoch 2 Batch 3550 Loss 1.0415 Accuracy 0.1937
# Epoch 2 Batch 3600 Loss 1.0372 Accuracy 0.1943
# Epoch 2 Batch 3650 Loss 1.0346 Accuracy 0.1951
# Epoch 2 Batch 3700 Loss 1.0304 Accuracy 0.1954
# Epoch 2 Batch 3750 Loss 1.0288 Accuracy 0.1960
# Epoch 2 Batch 3800 Loss 1.0252 Accuracy 0.1967
# Epoch 2 Batch 3850 Loss 1.0218 Accuracy 0.1973
# Epoch 2 Batch 3900 Loss 1.0191 Accuracy 0.1979
# Epoch 2 Batch 3950 Loss 1.0148 Accuracy 0.1983
# Epoch 2 Batch 4000 Loss 1.0109 Accuracy 0.1989
# Epoch 2 Batch 4050 Loss 1.0078 Accuracy 0.1993
# Epoch 2 Batch 4100 Loss 1.0045 Accuracy 0.1999
# Epoch 2 Batch 4150 Loss 1.0023 Accuracy 0.2004
# Epoch 2 Batch 4200 Loss 0.9984 Accuracy 0.2009
# Epoch 2 Batch 4250 Loss 0.9945 Accuracy 0.2015
# Epoch 2 Batch 4300 Loss 0.9916 Accuracy 0.2020
# Epoch 2 Batch 4350 Loss 0.9882 Accuracy 0.2024
# Epoch 2 Batch 4400 Loss 0.9856 Accuracy 0.2030
# Epoch 2 Batch 4450 Loss 0.9816 Accuracy 0.2034
# Epoch 2 Batch 4500 Loss 0.9791 Accuracy 0.2039
# Epoch 2 Batch 4550 Loss 0.9758 Accuracy 0.2043
# Epoch 2 Batch 4600 Loss 0.9730 Accuracy 0.2049
# Epoch 2 Batch 4650 Loss 0.9693 Accuracy 0.2053
# Epoch 2 Batch 4700 Loss 0.9668 Accuracy 0.2057
# Epoch 2 Batch 4750 Loss 0.9641 Accuracy 0.2062
# Epoch 2 Batch 4800 Loss 0.9608 Accuracy 0.2066
# Epoch 2 Batch 4850 Loss 0.9581 Accuracy 0.2070
# Epoch 2 Batch 4900 Loss 0.9551 Accuracy 0.2074
# Epoch 2 Batch 4950 Loss 0.9531 Accuracy 0.2080
# Epoch 2 Batch 5000 Loss 0.9504 Accuracy 0.2085
# Epoch 2 Batch 5050 Loss 0.9472 Accuracy 0.2088
# Epoch 2 Batch 5100 Loss 0.9446 Accuracy 0.2092
# Epoch 2 Batch 5150 Loss 0.9422 Accuracy 0.2096
# Epoch 2 Batch 5200 Loss 0.9390 Accuracy 0.2100
# Epoch 2 Batch 5250 Loss 0.9366 Accuracy 0.2104
# Epoch 2 Batch 5300 Loss 0.9338 Accuracy 0.2109
# Epoch 2 Batch 5350 Loss 0.9314 Accuracy 0.2112
# Epoch 2 Batch 5400 Loss 0.9289 Accuracy 0.2116
# Epoch 2 Batch 5450 Loss 0.9262 Accuracy 0.2118
# Epoch 2 Batch 5500 Loss 0.9239 Accuracy 0.2122
# Epoch 2 Batch 5550 Loss 0.9215 Accuracy 0.2126
# Epoch 2 Batch 5600 Loss 0.9188 Accuracy 0.2129
# Epoch 2 Batch 5650 Loss 0.9165 Accuracy 0.2133
# Epoch 2 Batch 5700 Loss 0.9143 Accuracy 0.2136
# Epoch 2 Batch 5750 Loss 0.9117 Accuracy 0.2139
# Epoch 2 Batch 5800 Loss 0.9092 Accuracy 0.2143
# Epoch 2 Batch 5850 Loss 0.9073 Accuracy 0.2146
# Epoch 2 Loss 0.9071 Accuracy 0.2146
# Time taken for 1 epoch: 181.52926111221313 secs
#
# Epoch 3 Batch 5900 Loss 0.7602 Accuracy 0.2349
# Epoch 3 Batch 5950 Loss 0.7651 Accuracy 0.2359
# Epoch 3 Batch 6000 Loss 0.7611 Accuracy 0.2347
# Epoch 3 Batch 6050 Loss 0.7567 Accuracy 0.2333
# Epoch 3 Batch 6100 Loss 0.7571 Accuracy 0.2345
# Epoch 3 Batch 6150 Loss 0.7555 Accuracy 0.2344
# Epoch 3 Batch 6200 Loss 0.7546 Accuracy 0.2347
# Epoch 3 Batch 6250 Loss 0.7504 Accuracy 0.2355
# Epoch 3 Batch 6300 Loss 0.7505 Accuracy 0.2352
# Epoch 3 Batch 6350 Loss 0.7501 Accuracy 0.2356
# Epoch 3 Batch 6400 Loss 0.7485 Accuracy 0.2358
# Epoch 3 Batch 6450 Loss 0.7456 Accuracy 0.2360
# Epoch 3 Batch 6500 Loss 0.7445 Accuracy 0.2364
# Epoch 3 Batch 6550 Loss 0.7446 Accuracy 0.2363
# Epoch 3 Batch 6600 Loss 0.7452 Accuracy 0.2368
# Epoch 3 Batch 6650 Loss 0.7446 Accuracy 0.2371
# Epoch 3 Batch 6700 Loss 0.7437 Accuracy 0.2373
# Epoch 3 Batch 6750 Loss 0.7431 Accuracy 0.2375
# Epoch 3 Batch 6800 Loss 0.7425 Accuracy 0.2378
# Epoch 3 Batch 6850 Loss 0.7407 Accuracy 0.2380
# Epoch 3 Batch 6900 Loss 0.7400 Accuracy 0.2382
# Epoch 3 Batch 6950 Loss 0.7401 Accuracy 0.2385
# Epoch 3 Batch 7000 Loss 0.7397 Accuracy 0.2387
# Epoch 3 Batch 7050 Loss 0.7384 Accuracy 0.2389
# Epoch 3 Batch 7100 Loss 0.7377 Accuracy 0.2391
# Epoch 3 Batch 7150 Loss 0.7365 Accuracy 0.2393
# Epoch 3 Batch 7200 Loss 0.7349 Accuracy 0.2395
# Epoch 3 Batch 7250 Loss 0.7348 Accuracy 0.2399
# Epoch 3 Batch 7300 Loss 0.7337 Accuracy 0.2400
# Epoch 3 Batch 7350 Loss 0.7330 Accuracy 0.2403
# Epoch 3 Batch 7400 Loss 0.7318 Accuracy 0.2405
# Epoch 3 Batch 7450 Loss 0.7309 Accuracy 0.2405
# Epoch 3 Batch 7500 Loss 0.7310 Accuracy 0.2407
# Epoch 3 Batch 7550 Loss 0.7307 Accuracy 0.2408
# Epoch 3 Batch 7600 Loss 0.7294 Accuracy 0.2409
# Epoch 3 Batch 7650 Loss 0.7290 Accuracy 0.2412
# Epoch 3 Batch 7700 Loss 0.7282 Accuracy 0.2414
# Epoch 3 Batch 7750 Loss 0.7271 Accuracy 0.2414
# Epoch 3 Batch 7800 Loss 0.7265 Accuracy 0.2416
# Epoch 3 Batch 7850 Loss 0.7260 Accuracy 0.2417
# Epoch 3 Batch 7900 Loss 0.7251 Accuracy 0.2418
# Epoch 3 Batch 7950 Loss 0.7248 Accuracy 0.2419
# Epoch 3 Batch 8000 Loss 0.7239 Accuracy 0.2420
# Epoch 3 Batch 8050 Loss 0.7230 Accuracy 0.2423
# Epoch 3 Batch 8100 Loss 0.7227 Accuracy 0.2424
# Epoch 3 Batch 8150 Loss 0.7219 Accuracy 0.2425
# Epoch 3 Batch 8200 Loss 0.7210 Accuracy 0.2426
# Epoch 3 Batch 8250 Loss 0.7202 Accuracy 0.2429
# Epoch 3 Batch 8300 Loss 0.7200 Accuracy 0.2430
# Epoch 3 Batch 8350 Loss 0.7192 Accuracy 0.2431
# Epoch 3 Batch 8400 Loss 0.7184 Accuracy 0.2433
# Epoch 3 Batch 8450 Loss 0.7179 Accuracy 0.2434
# Epoch 3 Batch 8500 Loss 0.7172 Accuracy 0.2436
# Epoch 3 Batch 8550 Loss 0.7164 Accuracy 0.2437
# Epoch 3 Batch 8600 Loss 0.7157 Accuracy 0.2439
# Epoch 3 Batch 8650 Loss 0.7155 Accuracy 0.2441
# Epoch 3 Batch 8700 Loss 0.7151 Accuracy 0.2443
# Epoch 3 Batch 8750 Loss 0.7143 Accuracy 0.2444
# Epoch 3 Loss 0.7139 Accuracy 0.2444
# Time taken for 1 epoch: 181.98947167396545 secs
#
# Epoch 4 Batch 8800 Loss 0.6177 Accuracy 0.2487
# Epoch 4 Batch 8850 Loss 0.6285 Accuracy 0.2490
# Epoch 4 Batch 8900 Loss 0.6539 Accuracy 0.2524
# Epoch 4 Batch 8950 Loss 0.6560 Accuracy 0.2526
# Epoch 4 Batch 9000 Loss 0.6594 Accuracy 0.2516
# Epoch 4 Batch 9050 Loss 0.6569 Accuracy 0.2518
# Epoch 4 Batch 9100 Loss 0.6545 Accuracy 0.2512
# Epoch 4 Batch 9150 Loss 0.6518 Accuracy 0.2514
# Epoch 4 Batch 9200 Loss 0.6516 Accuracy 0.2510
# Epoch 4 Batch 9250 Loss 0.6496 Accuracy 0.2513
# Epoch 4 Batch 9300 Loss 0.6508 Accuracy 0.2514
# Epoch 4 Batch 9350 Loss 0.6523 Accuracy 0.2515
# Epoch 4 Batch 9400 Loss 0.6521 Accuracy 0.2518
# Epoch 4 Batch 9450 Loss 0.6532 Accuracy 0.2521
# Epoch 4 Batch 9500 Loss 0.6526 Accuracy 0.2521
# Epoch 4 Batch 9550 Loss 0.6517 Accuracy 0.2523
# Epoch 4 Batch 9600 Loss 0.6522 Accuracy 0.2526
# Epoch 4 Batch 9650 Loss 0.6517 Accuracy 0.2529
# Epoch 4 Batch 9700 Loss 0.6513 Accuracy 0.2531
# Epoch 4 Batch 9750 Loss 0.6513 Accuracy 0.2532
# Epoch 4 Batch 9800 Loss 0.6519 Accuracy 0.2538
# Epoch 4 Batch 9850 Loss 0.6513 Accuracy 0.2538
# Epoch 4 Batch 9900 Loss 0.6508 Accuracy 0.2541
# Epoch 4 Batch 9950 Loss 0.6510 Accuracy 0.2541
# Epoch 4 Batch 10000 Loss 0.6505 Accuracy 0.2543
# Epoch 4 Batch 10050 Loss 0.6493 Accuracy 0.2544
# Epoch 4 Batch 10100 Loss 0.6487 Accuracy 0.2545
# Epoch 4 Batch 10150 Loss 0.6487 Accuracy 0.2545
# Epoch 4 Batch 10200 Loss 0.6487 Accuracy 0.2547
# Epoch 4 Batch 10250 Loss 0.6485 Accuracy 0.2548
# Epoch 4 Batch 10300 Loss 0.6483 Accuracy 0.2549
# Epoch 4 Batch 10350 Loss 0.6480 Accuracy 0.2550
# Epoch 4 Batch 10400 Loss 0.6479 Accuracy 0.2552
# Epoch 4 Batch 10450 Loss 0.6475 Accuracy 0.2552
# Epoch 4 Batch 10500 Loss 0.6471 Accuracy 0.2553
# Epoch 4 Batch 10550 Loss 0.6472 Accuracy 0.2555
# Epoch 4 Batch 10600 Loss 0.6463 Accuracy 0.2554
# Epoch 4 Batch 10650 Loss 0.6465 Accuracy 0.2555
# Epoch 4 Batch 10700 Loss 0.6463 Accuracy 0.2556
# Epoch 4 Batch 10750 Loss 0.6460 Accuracy 0.2557
# Epoch 4 Batch 10800 Loss 0.6456 Accuracy 0.2557
# Epoch 4 Batch 10850 Loss 0.6455 Accuracy 0.2558
# Epoch 4 Batch 10900 Loss 0.6452 Accuracy 0.2559
# Epoch 4 Batch 10950 Loss 0.6446 Accuracy 0.2558
# Epoch 4 Batch 11000 Loss 0.6444 Accuracy 0.2560
# Epoch 4 Batch 11050 Loss 0.6438 Accuracy 0.2560
# Epoch 4 Batch 11100 Loss 0.6439 Accuracy 0.2562
# Epoch 4 Batch 11150 Loss 0.6438 Accuracy 0.2562
# Epoch 4 Batch 11200 Loss 0.6435 Accuracy 0.2563
# Epoch 4 Batch 11250 Loss 0.6434 Accuracy 0.2565
# Epoch 4 Batch 11300 Loss 0.6428 Accuracy 0.2564
# Epoch 4 Batch 11350 Loss 0.6423 Accuracy 0.2564
# Epoch 4 Batch 11400 Loss 0.6425 Accuracy 0.2566
# Epoch 4 Batch 11450 Loss 0.6421 Accuracy 0.2567
# Epoch 4 Batch 11500 Loss 0.6418 Accuracy 0.2567
# Epoch 4 Batch 11550 Loss 0.6416 Accuracy 0.2568
# Epoch 4 Batch 11600 Loss 0.6411 Accuracy 0.2568
# Epoch 4 Batch 11650 Loss 0.6409 Accuracy 0.2569
# Epoch 4 Batch 11700 Loss 0.6405 Accuracy 0.2569
# Epoch 5 Batch 13800 Loss 0.6030 Accuracy 0.2638
# Epoch 5 Batch 13850 Loss 0.6030 Accuracy 0.2640
# Epoch 5 Batch 13900 Loss 0.6029 Accuracy 0.2640
# Epoch 5 Batch 13950 Loss 0.6023 Accuracy 0.2639
# Epoch 5 Batch 14000 Loss 0.6023 Accuracy 0.2640
# Epoch 5 Batch 14050 Loss 0.6022 Accuracy 0.2640
# Epoch 5 Batch 14100 Loss 0.6020 Accuracy 0.2640
# Epoch 5 Batch 14150 Loss 0.6018 Accuracy 0.2642
# Epoch 5 Batch 14200 Loss 0.6016 Accuracy 0.2641
# Epoch 5 Batch 14250 Loss 0.6013 Accuracy 0.2641
# Epoch 5 Batch 14300 Loss 0.6012 Accuracy 0.2641
# Epoch 5 Batch 14350 Loss 0.6010 Accuracy 0.2641
# Epoch 5 Batch 14400 Loss 0.6007 Accuracy 0.2641
# Epoch 5 Batch 14450 Loss 0.6003 Accuracy 0.2641
# Epoch 5 Batch 14500 Loss 0.5998 Accuracy 0.2640
# Epoch 5 Batch 14550 Loss 0.6000 Accuracy 0.2640
# Epoch 5 Batch 14600 Loss 0.5997 Accuracy 0.2640
# Save checkpoints
# Epoch 5 Loss 0.5996 Accuracy 0.2640
# Time taken for 1 epoch: 184.11241245269775 secs
#
# Epoch 6 Batch 14650 Loss 0.6057 Accuracy 0.2647
# Epoch 6 Batch 14700 Loss 0.5772 Accuracy 0.2635
# Epoch 6 Batch 14750 Loss 0.5716 Accuracy 0.2635
# Epoch 6 Batch 14800 Loss 0.5709 Accuracy 0.2644
# Epoch 6 Batch 14850 Loss 0.5692 Accuracy 0.2646
# Epoch 6 Batch 14900 Loss 0.5703 Accuracy 0.2641
# Epoch 6 Batch 14950 Loss 0.5680 Accuracy 0.2644
# Epoch 6 Batch 15000 Loss 0.5732 Accuracy 0.2650
# Epoch 6 Batch 15050 Loss 0.5719 Accuracy 0.2658
# Epoch 6 Batch 15100 Loss 0.5727 Accuracy 0.2661
# Epoch 6 Batch 15150 Loss 0.5732 Accuracy 0.2660
# Epoch 6 Batch 15200 Loss 0.5720 Accuracy 0.2663
# Epoch 6 Batch 15250 Loss 0.5727 Accuracy 0.2662
# Epoch 6 Batch 15300 Loss 0.5733 Accuracy 0.2663
# Epoch 6 Batch 15350 Loss 0.5732 Accuracy 0.2669
# Epoch 6 Batch 15400 Loss 0.5734 Accuracy 0.2670
# Epoch 6 Batch 15450 Loss 0.5735 Accuracy 0.2671
# Epoch 6 Batch 15500 Loss 0.5742 Accuracy 0.2673
# Epoch 6 Batch 15550 Loss 0.5750 Accuracy 0.2677
# Epoch 6 Batch 15600 Loss 0.5747 Accuracy 0.2676
# Epoch 6 Batch 15650 Loss 0.5748 Accuracy 0.2674
# Epoch 6 Batch 15700 Loss 0.5744 Accuracy 0.2674
# Epoch 6 Batch 15750 Loss 0.5746 Accuracy 0.2675
# Epoch 6 Batch 15800 Loss 0.5742 Accuracy 0.2675
# Epoch 6 Batch 15850 Loss 0.5743 Accuracy 0.2678
# Epoch 6 Batch 15900 Loss 0.5744 Accuracy 0.2677
# Epoch 6 Batch 15950 Loss 0.5743 Accuracy 0.2680
# Epoch 6 Batch 16000 Loss 0.5733 Accuracy 0.2680
# Epoch 6 Batch 16050 Loss 0.5729 Accuracy 0.2678
# Epoch 6 Batch 16100 Loss 0.5726 Accuracy 0.2679
# Epoch 6 Batch 16150 Loss 0.5729 Accuracy 0.2680
# Epoch 6 Batch 16200 Loss 0.5727 Accuracy 0.2680
# Epoch 6 Batch 16250 Loss 0.5727 Accuracy 0.2680
# Epoch 6 Batch 16300 Loss 0.5730 Accuracy 0.2680
# Epoch 6 Batch 16350 Loss 0.5731 Accuracy 0.2681
# Epoch 6 Batch 16400 Loss 0.5733 Accuracy 0.2681
# Epoch 6 Batch 16450 Loss 0.5732 Accuracy 0.2680
# Epoch 6 Batch 16500 Loss 0.5727 Accuracy 0.2680
# Epoch 6 Batch 16550 Loss 0.5730 Accuracy 0.2680
# Epoch 6 Batch 16600 Loss 0.5732 Accuracy 0.2682
# Epoch 6 Batch 16650 Loss 0.5732 Accuracy 0.2681
# Epoch 6 Batch 16700 Loss 0.5732 Accuracy 0.2682
# Epoch 6 Batch 16750 Loss 0.5729 Accuracy 0.2683
# Epoch 6 Batch 16800 Loss 0.5725 Accuracy 0.2684
# Epoch 6 Batch 16850 Loss 0.5723 Accuracy 0.2685
# Epoch 6 Batch 16900 Loss 0.5727 Accuracy 0.2686
# Epoch 6 Batch 16950 Loss 0.5727 Accuracy 0.2686
# Epoch 6 Batch 17000 Loss 0.5728 Accuracy 0.2686
# Epoch 6 Batch 17050 Loss 0.5728 Accuracy 0.2686
# Epoch 6 Batch 17100 Loss 0.5729 Accuracy 0.2687
# Epoch 6 Batch 17150 Loss 0.5726 Accuracy 0.2687
# Epoch 6 Batch 17200 Loss 0.5727 Accuracy 0.2687
# Epoch 6 Batch 17250 Loss 0.5723 Accuracy 0.2687
# Epoch 6 Batch 17300 Loss 0.5722 Accuracy 0.2687
# Epoch 6 Batch 17350 Loss 0.5723 Accuracy 0.2688
# Epoch 6 Batch 17400 Loss 0.5726 Accuracy 0.2689
# Epoch 6 Batch 17450 Loss 0.5722 Accuracy 0.2690
# Epoch 6 Batch 17500 Loss 0.5721 Accuracy 0.2691
# Epoch 6 Batch 17550 Loss 0.5722 Accuracy 0.2691
# Epoch 6 Loss 0.5721 Accuracy 0.2691
# Time taken for 1 epoch: 183.57974314689636 secs
#
# Epoch 7 Batch 17600 Loss 0.5401 Accuracy 0.2708
# Epoch 7 Batch 17650 Loss 0.5442 Accuracy 0.2693
# Epoch 7 Batch 17700 Loss 0.5413 Accuracy 0.2700
# Epoch 7 Batch 17750 Loss 0.5410 Accuracy 0.2686
# Epoch 7 Batch 17800 Loss 0.5437 Accuracy 0.2693
# Epoch 7 Batch 17850 Loss 0.5452 Accuracy 0.2697
# Epoch 7 Batch 17900 Loss 0.5486 Accuracy 0.2692
# Epoch 7 Batch 17950 Loss 0.5489 Accuracy 0.2697
# Epoch 7 Batch 20150 Loss 0.5533 Accuracy 0.2727
# Epoch 7 Batch 20200 Loss 0.5530 Accuracy 0.2727
# Epoch 7 Batch 20250 Loss 0.5526 Accuracy 0.2726
# Epoch 7 Batch 20300 Loss 0.5522 Accuracy 0.2726
# Epoch 7 Batch 20350 Loss 0.5520 Accuracy 0.2725
# Epoch 7 Batch 20400 Loss 0.5522 Accuracy 0.2726
# Epoch 7 Batch 20450 Loss 0.5521 Accuracy 0.2726
# Epoch 7 Loss 0.5521 Accuracy 0.2726
# Time taken for 1 epoch: 182.66085815429688 secs
#
# Epoch 8 Batch 20500 Loss 0.5148 Accuracy 0.2782
# Epoch 8 Batch 20550 Loss 0.5336 Accuracy 0.2783
# Epoch 8 Batch 20600 Loss 0.5381 Accuracy 0.2762
# Epoch 8 Batch 20650 Loss 0.5366 Accuracy 0.2759
# Epoch 8 Batch 20700 Loss 0.5381 Accuracy 0.2753
# Epoch 8 Batch 20750 Loss 0.5365 Accuracy 0.2748
# Epoch 8 Batch 20800 Loss 0.5356 Accuracy 0.2742
# Epoch 8 Batch 20850 Loss 0.5339 Accuracy 0.2744
# Epoch 8 Batch 20900 Loss 0.5334 Accuracy 0.2742
# Epoch 8 Batch 20950 Loss 0.5337 Accuracy 0.2735
# Epoch 8 Batch 21000 Loss 0.5334 Accuracy 0.2738
# Epoch 8 Batch 21050 Loss 0.5323 Accuracy 0.2734
# Epoch 8 Batch 21100 Loss 0.5331 Accuracy 0.2735
# Epoch 8 Batch 21150 Loss 0.5333 Accuracy 0.2738
# Epoch 8 Batch 21200 Loss 0.5330 Accuracy 0.2740
# Epoch 8 Batch 21250 Loss 0.5329 Accuracy 0.2739
# Epoch 8 Batch 21300 Loss 0.5329 Accuracy 0.2739
# Epoch 8 Batch 21350 Loss 0.5325 Accuracy 0.2742
# Epoch 8 Batch 21400 Loss 0.5329 Accuracy 0.2743
# Epoch 8 Batch 21450 Loss 0.5340 Accuracy 0.2745
# Epoch 8 Batch 21500 Loss 0.5338 Accuracy 0.2744
# Epoch 8 Batch 21550 Loss 0.5344 Accuracy 0.2745
# Epoch 8 Batch 21600 Loss 0.5333 Accuracy 0.2744
# Epoch 8 Batch 21650 Loss 0.5331 Accuracy 0.2743
# Epoch 8 Batch 21700 Loss 0.5335 Accuracy 0.2743
# Epoch 8 Batch 21750 Loss 0.5341 Accuracy 0.2745
# Epoch 8 Batch 21800 Loss 0.5341 Accuracy 0.2747
# Epoch 8 Batch 21850 Loss 0.5338 Accuracy 0.2748
# Epoch 8 Batch 21900 Loss 0.5340 Accuracy 0.2747
# Epoch 8 Batch 21950 Loss 0.5340 Accuracy 0.2747
# Epoch 8 Batch 22000 Loss 0.5342 Accuracy 0.2747
# Epoch 8 Batch 22050 Loss 0.5342 Accuracy 0.2745
# Epoch 8 Batch 22100 Loss 0.5346 Accuracy 0.2745
# Epoch 8 Batch 22150 Loss 0.5345 Accuracy 0.2745
# Epoch 8 Batch 22200 Loss 0.5350 Accuracy 0.2746
# Epoch 10 Batch 26450 Loss 0.5035 Accuracy 0.2760
# Epoch 10 Batch 26500 Loss 0.4998 Accuracy 0.2756
# Epoch 10 Batch 26550 Loss 0.5032 Accuracy 0.2759
# Epoch 10 Batch 26600 Loss 0.5013 Accuracy 0.2757
# Epoch 10 Batch 26650 Loss 0.5021 Accuracy 0.2756
# Epoch 10 Batch 26700 Loss 0.5032 Accuracy 0.2766
# Epoch 10 Batch 26750 Loss 0.5035 Accuracy 0.2774
# Epoch 10 Batch 26800 Loss 0.5050 Accuracy 0.2782
# Epoch 10 Batch 26850 Loss 0.5063 Accuracy 0.2784
# Epoch 10 Batch 26900 Loss 0.5069 Accuracy 0.2784
# Epoch 10 Batch 26950 Loss 0.5072 Accuracy 0.2786
# Epoch 10 Batch 27000 Loss 0.5073 Accuracy 0.2784
# Epoch 10 Batch 27050 Loss 0.5083 Accuracy 0.2785
# Epoch 10 Batch 27100 Loss 0.5088 Accuracy 0.2788
# Epoch 10 Batch 27150 Loss 0.5084 Accuracy 0.2783
# Epoch 10 Batch 27200 Loss 0.5083 Accuracy 0.2782
# Epoch 10 Batch 27250 Loss 0.5082 Accuracy 0.2781
# Epoch 10 Batch 27300 Loss 0.5084 Accuracy 0.2782
# Epoch 10 Batch 27350 Loss 0.5077 Accuracy 0.2780
# Epoch 10 Batch 27400 Loss 0.5082 Accuracy 0.2780
# Epoch 10 Batch 27450 Loss 0.5094 Accuracy 0.2782
# Epoch 10 Batch 27500 Loss 0.5097 Accuracy 0.2784
# Epoch 10 Batch 27550 Loss 0.5108 Accuracy 0.2786
# Epoch 10 Batch 27600 Loss 0.5107 Accuracy 0.2791
# Epoch 10 Batch 27650 Loss 0.5107 Accuracy 0.2792
# Epoch 10 Batch 27700 Loss 0.5103 Accuracy 0.2791
# Epoch 10 Batch 27750 Loss 0.5105 Accuracy 0.2793
# Epoch 10 Batch 27800 Loss 0.5106 Accuracy 0.2795
# Epoch 10 Batch 27850 Loss 0.5105 Accuracy 0.2795
# Epoch 10 Batch 27900 Loss 0.5107 Accuracy 0.2797
# Epoch 10 Batch 27950 Loss 0.5109 Accuracy 0.2798
# Epoch 10 Batch 28000 Loss 0.5105 Accuracy 0.2798
# Epoch 10 Batch 28050 Loss 0.5110 Accuracy 0.2798
# Epoch 10 Batch 28100 Loss 0.5111 Accuracy 0.2799
# Epoch 10 Batch 28150 Loss 0.5108 Accuracy 0.2798
# Epoch 10 Batch 28200 Loss 0.5110 Accuracy 0.2798
# Epoch 10 Batch 28250 Loss 0.5107 Accuracy 0.2798
# Epoch 10 Batch 28300 Loss 0.5105 Accuracy 0.2798
# Epoch 10 Batch 28350 Loss 0.5104 Accuracy 0.2797
# Epoch 10 Batch 28400 Loss 0.5103 Accuracy 0.2796
# Epoch 10 Batch 28450 Loss 0.5105 Accuracy 0.2795
# Epoch 10 Batch 28500 Loss 0.5106 Accuracy 0.2795
# Epoch 10 Batch 28550 Loss 0.5107 Accuracy 0.2794
# Epoch 10 Batch 28600 Loss 0.5115 Accuracy 0.2797
# Epoch 10 Batch 28650 Loss 0.5118 Accuracy 0.2797
# Epoch 10 Batch 28700 Loss 0.5119 Accuracy 0.2798
# Epoch 10 Batch 28750 Loss 0.5122 Accuracy 0.2799
# Epoch 10 Batch 28800 Loss 0.5122 Accuracy 0.2800
# Epoch 10 Batch 28850 Loss 0.5120 Accuracy 0.2799
# Epoch 10 Batch 28900 Loss 0.5122 Accuracy 0.2799
# Epoch 10 Batch 28950 Loss 0.5126 Accuracy 0.2799
# Epoch 10 Batch 29000 Loss 0.5127 Accuracy 0.2800
# Epoch 10 Batch 29050 Loss 0.5126 Accuracy 0.2799
# Epoch 10 Batch 29100 Loss 0.5127 Accuracy 0.2800
# Epoch 10 Batch 29150 Loss 0.5124 Accuracy 0.2800
# Epoch 10 Batch 29200 Loss 0.5126 Accuracy 0.2800
# Epoch 10 Batch 29250 Loss 0.5125 Accuracy 0.2798
# Save checkpoints
# Epoch 10 Loss 0.5126 Accuracy 0.2799
# Time taken for 1 epoch: 184.73050904273987 secs
#
# Epoch 11 Batch 29300 Loss 0.4878 Accuracy 0.2794
# Epoch 11 Batch 29350 Loss 0.4871 Accuracy 0.2760
# Epoch 11 Batch 29400 Loss 0.4916 Accuracy 0.2741
# Epoch 11 Batch 29450 Loss 0.4920 Accuracy 0.2753
# Epoch 11 Batch 29500 Loss 0.5012 Accuracy 0.2778
# Epoch 11 Batch 29550 Loss 0.4994 Accuracy 0.2789
# Epoch 11 Batch 29600 Loss 0.5009 Accuracy 0.2797
# Epoch 11 Batch 29650 Loss 0.5024 Accuracy 0.2803
# Epoch 11 Batch 29700 Loss 0.5007 Accuracy 0.2804
# Epoch 11 Batch 29750 Loss 0.5008 Accuracy 0.2807
# Epoch 11 Batch 29800 Loss 0.5010 Accuracy 0.2813
# Epoch 11 Batch 29850 Loss 0.4985 Accuracy 0.2812
# Epoch 11 Batch 29900 Loss 0.4998 Accuracy 0.2812
# Epoch 11 Batch 29950 Loss 0.4992 Accuracy 0.2808
# Epoch 11 Batch 30000 Loss 0.4993 Accuracy 0.2805
# Epoch 11 Batch 30050 Loss 0.4993 Accuracy 0.2806
# Epoch 11 Batch 30100 Loss 0.5000 Accuracy 0.2804
# Epoch 11 Batch 30150 Loss 0.4996 Accuracy 0.2801
# Epoch 11 Batch 30200 Loss 0.4999 Accuracy 0.2800
# Epoch 11 Batch 30250 Loss 0.5001 Accuracy 0.2801
# Epoch 11 Batch 30300 Loss 0.5003 Accuracy 0.2804
# Epoch 11 Batch 30350 Loss 0.5007 Accuracy 0.2805
# Epoch 11 Batch 30400 Loss 0.5010 Accuracy 0.2806
# Epoch 11 Batch 30450 Loss 0.5005 Accuracy 0.2807
# Epoch 11 Batch 30500 Loss 0.5008 Accuracy 0.2809
# Epoch 11 Batch 30550 Loss 0.5010 Accuracy 0.2811
# Epoch 11 Batch 30600 Loss 0.5015 Accuracy 0.2811
# Epoch 11 Batch 30650 Loss 0.5015 Accuracy 0.2811
# Epoch 11 Batch 30700 Loss 0.5020 Accuracy 0.2812
# Epoch 11 Batch 30750 Loss 0.5019 Accuracy 0.2812
# Epoch 11 Batch 30800 Loss 0.5020 Accuracy 0.2812
# Epoch 11 Batch 30850 Loss 0.5021 Accuracy 0.2812
# Epoch 11 Batch 30900 Loss 0.5023 Accuracy 0.2811
# Epoch 11 Batch 30950 Loss 0.5022 Accuracy 0.2810
# Epoch 11 Batch 31000 Loss 0.5020 Accuracy 0.2808
# Epoch 11 Batch 31050 Loss 0.5022 Accuracy 0.2809
# Epoch 11 Batch 31100 Loss 0.5027 Accuracy 0.2809
# Epoch 11 Batch 31150 Loss 0.5027 Accuracy 0.2810
# Epoch 11 Batch 31200 Loss 0.5028 Accuracy 0.2811
# Epoch 11 Batch 31250 Loss 0.5028 Accuracy 0.2810
# Epoch 11 Batch 31300 Loss 0.5030 Accuracy 0.2811
# Epoch 11 Batch 31350 Loss 0.5029 Accuracy 0.2813
# Epoch 11 Batch 31400 Loss 0.5033 Accuracy 0.2814
# Epoch 11 Batch 31450 Loss 0.5029 Accuracy 0.2813
# Epoch 11 Batch 31500 Loss 0.5030 Accuracy 0.2814
# Epoch 11 Batch 31550 Loss 0.5031 Accuracy 0.2814
# Epoch 11 Batch 31600 Loss 0.5033 Accuracy 0.2814
# Epoch 11 Batch 31650 Loss 0.5031 Accuracy 0.2813
# Epoch 11 Batch 31700 Loss 0.5030 Accuracy 0.2814
# Epoch 11 Batch 31750 Loss 0.5031 Accuracy 0.2813
# Epoch 11 Batch 31800 Loss 0.5031 Accuracy 0.2813
# Epoch 11 Batch 31850 Loss 0.5033 Accuracy 0.2813
# Epoch 11 Batch 31900 Loss 0.5033 Accuracy 0.2814
# Epoch 11 Batch 31950 Loss 0.5033 Accuracy 0.2815
# Epoch 11 Batch 32000 Loss 0.5032 Accuracy 0.2814
# Epoch 11 Batch 32050 Loss 0.5034 Accuracy 0.2815
# Epoch 11 Batch 32100 Loss 0.5033 Accuracy 0.2815
# Epoch 11 Batch 32150 Loss 0.5036 Accuracy 0.2815
# Epoch 11 Loss 0.5036 Accuracy 0.2816
# Time taken for 1 epoch: 184.18111515045166 secs
#
# Epoch 12 Batch 32200 Loss 0.4706 Accuracy 0.2614
# Epoch 12 Batch 32250 Loss 0.4756 Accuracy 0.2774
# Epoch 12 Batch 32300 Loss 0.4771 Accuracy 0.2791
# Epoch 12 Batch 32350 Loss 0.4824 Accuracy 0.2801
# Epoch 12 Batch 32400 Loss 0.4851 Accuracy 0.2810
# Epoch 12 Batch 32450 Loss 0.4858 Accuracy 0.2813
# Epoch 12 Batch 32500 Loss 0.4841 Accuracy 0.2809
# Epoch 12 Batch 32550 Loss 0.4847 Accuracy 0.2809
# Epoch 12 Batch 32600 Loss 0.4865 Accuracy 0.2819
# Epoch 12 Batch 32650 Loss 0.4873 Accuracy 0.2816
# Epoch 12 Batch 32700 Loss 0.4866 Accuracy 0.2813
# Epoch 12 Batch 32750 Loss 0.4890 Accuracy 0.2816
# Epoch 12 Batch 32800 Loss 0.4910 Accuracy 0.2822
# Epoch 12 Batch 32850 Loss 0.4929 Accuracy 0.2827
# Epoch 12 Batch 32900 Loss 0.4931 Accuracy 0.2827
# Epoch 12 Batch 32950 Loss 0.4921 Accuracy 0.2826
# Epoch 12 Batch 33000 Loss 0.4922 Accuracy 0.2825
# Epoch 12 Batch 33050 Loss 0.4925 Accuracy 0.2823
# Epoch 12 Batch 33100 Loss 0.4927 Accuracy 0.2821
# Epoch 12 Batch 33150 Loss 0.4927 Accuracy 0.2821
# Epoch 12 Batch 33200 Loss 0.4933 Accuracy 0.2822
# Epoch 12 Batch 33250 Loss 0.4928 Accuracy 0.2819
# Epoch 12 Batch 33300 Loss 0.4937 Accuracy 0.2822
# Epoch 12 Batch 33350 Loss 0.4942 Accuracy 0.2821
# Epoch 12 Batch 33400 Loss 0.4935 Accuracy 0.2821
# Epoch 12 Batch 33450 Loss 0.4940 Accuracy 0.2823
# Epoch 12 Batch 33500 Loss 0.4936 Accuracy 0.2824
# Epoch 12 Batch 33550 Loss 0.4933 Accuracy 0.2824
# Epoch 12 Batch 33600 Loss 0.4938 Accuracy 0.2826
# Epoch 12 Batch 33650 Loss 0.4942 Accuracy 0.2828
# Epoch 12 Batch 33700 Loss 0.4940 Accuracy 0.2825
# Epoch 12 Batch 33750 Loss 0.4946 Accuracy 0.2825
# Epoch 12 Batch 33800 Loss 0.4946 Accuracy 0.2826
# Epoch 12 Batch 33850 Loss 0.4948 Accuracy 0.2827
# Epoch 12 Batch 33900 Loss 0.4951 Accuracy 0.2826
# Epoch 12 Batch 33950 Loss 0.4952 Accuracy 0.2826
# Epoch 12 Batch 34000 Loss 0.4951 Accuracy 0.2828
# Epoch 12 Batch 34050 Loss 0.4954 Accuracy 0.2829
# Epoch 12 Batch 34100 Loss 0.4955 Accuracy 0.2829
# Epoch 12 Batch 34150 Loss 0.4957 Accuracy 0.2829
# Epoch 12 Batch 34200 Loss 0.4955 Accuracy 0.2828
# Epoch 12 Batch 34250 Loss 0.4957 Accuracy 0.2829
# Epoch 12 Batch 34300 Loss 0.4958 Accuracy 0.2829
# Epoch 12 Batch 34350 Loss 0.4957 Accuracy 0.2829
# Epoch 12 Batch 34400 Loss 0.4955 Accuracy 0.2828
# Epoch 12 Batch 34450 Loss 0.4956 Accuracy 0.2827
# Epoch 12 Batch 34500 Loss 0.4954 Accuracy 0.2828
# Epoch 12 Batch 34550 Loss 0.4953 Accuracy 0.2827
# Epoch 12 Batch 34600 Loss 0.4956 Accuracy 0.2828
# Epoch 12 Batch 34650 Loss 0.4957 Accuracy 0.2827
# Epoch 12 Batch 34700 Loss 0.4956 Accuracy 0.2828
# Epoch 12 Batch 34750 Loss 0.4954 Accuracy 0.2828
# Epoch 12 Batch 34800 Loss 0.4952 Accuracy 0.2827
# Epoch 12 Batch 34850 Loss 0.4956 Accuracy 0.2828
# Epoch 12 Batch 34900 Loss 0.4957 Accuracy 0.2829
# Epoch 12 Batch 34950 Loss 0.4956 Accuracy 0.2829
# Epoch 12 Batch 35000 Loss 0.4956 Accuracy 0.2830
# Epoch 12 Batch 35050 Loss 0.4957 Accuracy 0.2830
# Epoch 12 Batch 35100 Loss 0.4957 Accuracy 0.2831
# Epoch 12 Loss 0.4957 Accuracy 0.2830
# Time taken for 1 epoch: 181.11614322662354 secs
#
# Epoch 13 Batch 35150 Loss 0.4826 Accuracy 0.2898
# Epoch 13 Batch 35200 Loss 0.4725 Accuracy 0.2852
# Epoch 13 Batch 35250 Loss 0.4752 Accuracy 0.2851
# Epoch 13 Batch 35300 Loss 0.4732 Accuracy 0.2853
# Epoch 13 Batch 35350 Loss 0.4723 Accuracy 0.2837
# Epoch 13 Batch 35400 Loss 0.4736 Accuracy 0.2830
# Epoch 13 Batch 35450 Loss 0.4763 Accuracy 0.2828
# Epoch 13 Batch 35500 Loss 0.4778 Accuracy 0.2826
# Epoch 13 Batch 35550 Loss 0.4778 Accuracy 0.2825
# Epoch 13 Batch 35600 Loss 0.4786 Accuracy 0.2822
# Epoch 13 Batch 35650 Loss 0.4809 Accuracy 0.2827
# Epoch 13 Batch 35700 Loss 0.4812 Accuracy 0.2830
# Epoch 13 Batch 35750 Loss 0.4822 Accuracy 0.2832
# Epoch 13 Batch 35800 Loss 0.4832 Accuracy 0.2833
# Epoch 13 Batch 35850 Loss 0.4843 Accuracy 0.2836
# Epoch 13 Batch 35900 Loss 0.4846 Accuracy 0.2838
# Epoch 13 Batch 35950 Loss 0.4851 Accuracy 0.2837
# Epoch 13 Batch 36000 Loss 0.4857 Accuracy 0.2838
# Epoch 13 Batch 36050 Loss 0.4864 Accuracy 0.2838
# Epoch 13 Batch 36100 Loss 0.4868 Accuracy 0.2840
# Epoch 13 Batch 36150 Loss 0.4863 Accuracy 0.2842
# Epoch 13 Batch 36200 Loss 0.4859 Accuracy 0.2840
# Epoch 13 Batch 36250 Loss 0.4864 Accuracy 0.2839
# Epoch 13 Batch 36300 Loss 0.4867 Accuracy 0.2840
# Epoch 13 Batch 36350 Loss 0.4871 Accuracy 0.2839
# Epoch 13 Batch 36400 Loss 0.4880 Accuracy 0.2842
# Epoch 13 Batch 36450 Loss 0.4884 Accuracy 0.2842
# Epoch 13 Batch 36500 Loss 0.4875 Accuracy 0.2842
# Epoch 13 Batch 36550 Loss 0.4868 Accuracy 0.2842
# Epoch 13 Batch 36600 Loss 0.4871 Accuracy 0.2841
# Epoch 13 Batch 36650 Loss 0.4866 Accuracy 0.2841
# Epoch 13 Batch 36700 Loss 0.4867 Accuracy 0.2840
# Epoch 13 Batch 36750 Loss 0.4869 Accuracy 0.2839
# Epoch 13 Batch 36800 Loss 0.4870 Accuracy 0.2840
# Epoch 13 Batch 36850 Loss 0.4873 Accuracy 0.2842
# Epoch 13 Batch 36900 Loss 0.4869 Accuracy 0.2840
# Epoch 13 Batch 36950 Loss 0.4874 Accuracy 0.2841
# Epoch 13 Batch 37000 Loss 0.4873 Accuracy 0.2843
# Epoch 14 Batch 39150 Loss 0.4798 Accuracy 0.2849
# Epoch 14 Batch 39200 Loss 0.4797 Accuracy 0.2852
# Epoch 14 Batch 39250 Loss 0.4791 Accuracy 0.2851
# Epoch 14 Batch 39300 Loss 0.4786 Accuracy 0.2848
# Epoch 14 Batch 39350 Loss 0.4786 Accuracy 0.2850
# Epoch 14 Batch 39400 Loss 0.4790 Accuracy 0.2851
# Epoch 14 Batch 39450 Loss 0.4785 Accuracy 0.2850
# Epoch 14 Batch 39500 Loss 0.4790 Accuracy 0.2851
# Epoch 14 Batch 39550 Loss 0.4789 Accuracy 0.2851
# Epoch 14 Batch 39600 Loss 0.4789 Accuracy 0.2851
# Epoch 14 Batch 39650 Loss 0.4794 Accuracy 0.2853
# Epoch 14 Batch 39700 Loss 0.4794 Accuracy 0.2853
# Epoch 14 Batch 39750 Loss 0.4800 Accuracy 0.2855
# Epoch 14 Batch 39800 Loss 0.4802 Accuracy 0.2855
# Epoch 14 Batch 39850 Loss 0.4804 Accuracy 0.2856
# Epoch 14 Batch 39900 Loss 0.4807 Accuracy 0.2856
# Epoch 14 Batch 39950 Loss 0.4808 Accuracy 0.2856
# Epoch 14 Batch 40000 Loss 0.4811 Accuracy 0.2856
# Epoch 14 Batch 40050 Loss 0.4813 Accuracy 0.2857
# Epoch 14 Batch 40100 Loss 0.4814 Accuracy 0.2857
# Epoch 14 Batch 40150 Loss 0.4814 Accuracy 0.2857
# Epoch 14 Batch 40200 Loss 0.4815 Accuracy 0.2856
# Epoch 14 Batch 40250 Loss 0.4817 Accuracy 0.2856
# ...
# Epoch 25 Batch 72100 Loss 0.4365 Accuracy 0.2934
# Epoch 25 Batch 72150 Loss 0.4367 Accuracy 0.2935
# Epoch 25 Batch 72200 Loss 0.4367 Accuracy 0.2936
# Epoch 25 Batch 72250 Loss 0.4371 Accuracy 0.2937
# Epoch 25 Batch 72300 Loss 0.4371 Accuracy 0.2938
# Epoch 25 Batch 72350 Loss 0.4371 Accuracy 0.2938
# Epoch 25 Batch 72400 Loss 0.4372 Accuracy 0.2938
# Epoch 25 Batch 72450 Loss 0.4373 Accuracy 0.2938
# Epoch 25 Batch 72500 Loss 0.4373 Accuracy 0.2938
# Epoch 25 Batch 72550 Loss 0.4372 Accuracy 0.2937
# Epoch 25 Batch 72600 Loss 0.4373 Accuracy 0.2937
# Epoch 25 Batch 72650 Loss 0.4374 Accuracy 0.2936
# Epoch 25 Batch 72700 Loss 0.4374 Accuracy 0.2937
# Epoch 25 Batch 72750 Loss 0.4374 Accuracy 0.2937
# Epoch 25 Batch 72800 Loss 0.4378 Accuracy 0.2937
# Epoch 25 Batch 72850 Loss 0.4378 Accuracy 0.2937
# Epoch 25 Batch 72900 Loss 0.4376 Accuracy 0.2936
# Epoch 25 Batch 72950 Loss 0.4379 Accuracy 0.2937
# Epoch 25 Batch 73000 Loss 0.4381 Accuracy 0.2937
# Epoch 25 Batch 73050 Loss 0.4380 Accuracy 0.2937
# Epoch 25 Batch 73100 Loss 0.4381 Accuracy 0.2936
# Epoch 25 Batch 73150 Loss 0.4380 Accuracy 0.2937
# Save checkpoints
# Epoch 25 Loss 0.4380 Accuracy 0.2937
# Time taken for 1 epoch: 187.0341558456421 secs
#
# Epoch 26 Batch 73200 Loss 0.4197 Accuracy 0.2982
# Epoch 26 Batch 73250 Loss 0.4202 Accuracy 0.2921
# Epoch 26 Batch 73300 Loss 0.4243 Accuracy 0.2907
# Epoch 26 Batch 73350 Loss 0.4229 Accuracy 0.2918
# Epoch 26 Batch 73400 Loss 0.4216 Accuracy 0.2917
# Epoch 26 Batch 73450 Loss 0.4229 Accuracy 0.2920
# Epoch 26 Batch 73500 Loss 0.4259 Accuracy 0.2929
# Epoch 26 Batch 73550 Loss 0.4256 Accuracy 0.2921
# Epoch 26 Batch 73600 Loss 0.4253 Accuracy 0.2924
# Epoch 26 Batch 73650 Loss 0.4257 Accuracy 0.2927
# Epoch 26 Batch 73700 Loss 0.4265 Accuracy 0.2931
# Epoch 26 Batch 73750 Loss 0.4249 Accuracy 0.2926
# Epoch 26 Batch 73800 Loss 0.4258 Accuracy 0.2928
# Epoch 26 Batch 73850 Loss 0.4280 Accuracy 0.2932
# Epoch 26 Batch 73900 Loss 0.4280 Accuracy 0.2931
# Epoch 26 Batch 73950 Loss 0.4280 Accuracy 0.2930
# Epoch 26 Batch 74000 Loss 0.4288 Accuracy 0.2933
# Epoch 26 Batch 74050 Loss 0.4299 Accuracy 0.2937
# Epoch 26 Batch 74100 Loss 0.4301 Accuracy 0.2938
# Epoch 26 Batch 74150 Loss 0.4306 Accuracy 0.2940
# Epoch 26 Batch 74200 Loss 0.4308 Accuracy 0.2939
# Epoch 26 Batch 74250 Loss 0.4313 Accuracy 0.2939
# Epoch 26 Batch 74300 Loss 0.4311 Accuracy 0.2939
# Epoch 26 Batch 74350 Loss 0.4309 Accuracy 0.2938
# Epoch 26 Batch 74400 Loss 0.4306 Accuracy 0.2938
# Epoch 26 Batch 74450 Loss 0.4306 Accuracy 0.2938
# Epoch 26 Batch 74500 Loss 0.4308 Accuracy 0.2938
# Epoch 26 Batch 74550 Loss 0.4310 Accuracy 0.2941
# Epoch 26 Batch 74600 Loss 0.4311 Accuracy 0.2940
# Epoch 26 Batch 74650 Loss 0.4318 Accuracy 0.2940
# Epoch 26 Batch 74700 Loss 0.4319 Accuracy 0.2940
# Epoch 26 Batch 74750 Loss 0.4321 Accuracy 0.2943
# Epoch 26 Batch 74800 Loss 0.4328 Accuracy 0.2943
# Epoch 26 Batch 74850 Loss 0.4328 Accuracy 0.2943
# Epoch 26 Batch 74900 Loss 0.4332 Accuracy 0.2942
# Epoch 26 Batch 74950 Loss 0.4335 Accuracy 0.2941
# Epoch 26 Batch 75000 Loss 0.4332 Accuracy 0.2940
# Epoch 26 Batch 75050 Loss 0.4334 Accuracy 0.2939
# Epoch 26 Batch 75100 Loss 0.4335 Accuracy 0.2939
# Epoch 26 Batch 75150 Loss 0.4339 Accuracy 0.2940
# Epoch 26 Batch 75200 Loss 0.4340 Accuracy 0.2940
# Epoch 26 Batch 75250 Loss 0.4340 Accuracy 0.2938
# Epoch 26 Batch 75300 Loss 0.4341 Accuracy 0.2937
# Epoch 26 Batch 75350 Loss 0.4340 Accuracy 0.2938
# Epoch 26 Batch 75400 Loss 0.4341 Accuracy 0.2939
# Epoch 26 Batch 75450 Loss 0.4342 Accuracy 0.2939
# Epoch 26 Batch 75500 Loss 0.4344 Accuracy 0.2940
# Epoch 26 Batch 75550 Loss 0.4345 Accuracy 0.2941
# Epoch 26 Batch 75600 Loss 0.4348 Accuracy 0.2943
# Epoch 26 Batch 75650 Loss 0.4350 Accuracy 0.2943
# Epoch 26 Batch 75700 Loss 0.4351 Accuracy 0.2943
# Epoch 26 Batch 75750 Loss 0.4350 Accuracy 0.2942
# Epoch 26 Batch 75800 Loss 0.4349 Accuracy 0.2942
# Epoch 26 Batch 75850 Loss 0.4350 Accuracy 0.2943
# Epoch 26 Batch 75900 Loss 0.4349 Accuracy 0.2943
# Epoch 26 Batch 75950 Loss 0.4345 Accuracy 0.2942
# Epoch 26 Batch 76000 Loss 0.4347 Accuracy 0.2942
# Epoch 26 Batch 76050 Loss 0.4347 Accuracy 0.2942
# Epoch 26 Batch 76100 Loss 0.4350 Accuracy 0.2943
# Epoch 26 Loss 0.4350 Accuracy 0.2942
# Time taken for 1 epoch: 183.2712368965149 secs
#
# Epoch 27 Batch 76150 Loss 0.4088 Accuracy 0.2913
# Epoch 27 Batch 76200 Loss 0.4157 Accuracy 0.2903
# Epoch 27 Batch 76250 Loss 0.4154 Accuracy 0.2918
# Epoch 27 Batch 76300 Loss 0.4212 Accuracy 0.2930
# Epoch 27 Batch 76350 Loss 0.4249 Accuracy 0.2937
# Epoch 27 Batch 76400 Loss 0.4255 Accuracy 0.2929
# Epoch 27 Batch 76450 Loss 0.4242 Accuracy 0.2926
# Epoch 27 Batch 76500 Loss 0.4243 Accuracy 0.2920
# Epoch 27 Batch 76550 Loss 0.4245 Accuracy 0.2926
# Epoch 27 Batch 76600 Loss 0.4251 Accuracy 0.2928
# Epoch 27 Batch 76650 Loss 0.4261 Accuracy 0.2931
# Epoch 27 Batch 76700 Loss 0.4263 Accuracy 0.2936
# Epoch 27 Batch 76750 Loss 0.4267 Accuracy 0.2935
# Epoch 27 Batch 76800 Loss 0.4269 Accuracy 0.2937
# Epoch 27 Batch 76850 Loss 0.4276 Accuracy 0.2940
# Epoch 27 Batch 76900 Loss 0.4282 Accuracy 0.2938
# Epoch 27 Batch 76950 Loss 0.4278 Accuracy 0.2938
# Epoch 27 Batch 77000 Loss 0.4282 Accuracy 0.2939
# Epoch 27 Batch 77050 Loss 0.4279 Accuracy 0.2937
# Epoch 27 Batch 77100 Loss 0.4271 Accuracy 0.2938
# Epoch 27 Batch 77150 Loss 0.4278 Accuracy 0.2941
# Epoch 27 Batch 77200 Loss 0.4274 Accuracy 0.2939
# Epoch 27 Batch 77250 Loss 0.4274 Accuracy 0.2940
# Epoch 27 Batch 77300 Loss 0.4276 Accuracy 0.2942
# Epoch 27 Batch 77350 Loss 0.4276 Accuracy 0.2942
# Epoch 27 Batch 77400 Loss 0.4277 Accuracy 0.2944
# Epoch 27 Batch 77450 Loss 0.4283 Accuracy 0.2944
# Epoch 27 Batch 77500 Loss 0.4286 Accuracy 0.2945
# Epoch 27 Batch 77550 Loss 0.4289 Accuracy 0.2945
# Epoch 27 Batch 77600 Loss 0.4289 Accuracy 0.2944
# Epoch 27 Batch 77650 Loss 0.4290 Accuracy 0.2944
# Epoch 27 Batch 77700 Loss 0.4292 Accuracy 0.2944
# Epoch 27 Batch 77750 Loss 0.4297 Accuracy 0.2945
# Epoch 27 Batch 77800 Loss 0.4300 Accuracy 0.2946
# Epoch 27 Batch 77850 Loss 0.4303 Accuracy 0.2946
# Epoch 27 Batch 77900 Loss 0.4303 Accuracy 0.2945
# Epoch 27 Batch 77950 Loss 0.4302 Accuracy 0.2945
# Epoch 27 Batch 78000 Loss 0.4305 Accuracy 0.2946
# Epoch 27 Batch 78050 Loss 0.4302 Accuracy 0.2946
# Epoch 27 Batch 78100 Loss 0.4304 Accuracy 0.2946
# Epoch 27 Batch 78150 Loss 0.4305 Accuracy 0.2946
# Epoch 27 Batch 78200 Loss 0.4305 Accuracy 0.2944
# Epoch 27 Batch 78250 Loss 0.4307 Accuracy 0.2945
# Epoch 27 Batch 78300 Loss 0.4308 Accuracy 0.2946
# Epoch 27 Batch 78350 Loss 0.4309 Accuracy 0.2947
# Epoch 27 Batch 78400 Loss 0.4313 Accuracy 0.2947
# Epoch 27 Batch 78450 Loss 0.4316 Accuracy 0.2947
# Epoch 27 Batch 78500 Loss 0.4316 Accuracy 0.2946
# Epoch 27 Batch 78550 Loss 0.4318 Accuracy 0.2945
# Epoch 27 Batch 78600 Loss 0.4316 Accuracy 0.2944
# Epoch 27 Batch 78650 Loss 0.4319 Accuracy 0.2945
# Epoch 27 Batch 78700 Loss 0.4319 Accuracy 0.2944
# Epoch 27 Batch 78750 Loss 0.4318 Accuracy 0.2945
# Epoch 27 Batch 78800 Loss 0.4320 Accuracy 0.2944
# Epoch 27 Batch 78850 Loss 0.4321 Accuracy 0.2945
# Epoch 27 Batch 78900 Loss 0.4322 Accuracy 0.2944
# Epoch 27 Batch 78950 Loss 0.4327 Accuracy 0.2945
# Epoch 27 Batch 79000 Loss 0.4327 Accuracy 0.2946
# Epoch 27 Loss 0.4327 Accuracy 0.2946
# Time taken for 1 epoch: 182.91691827774048 secs
#
# Epoch 28 Batch 79050 Loss 0.3896 Accuracy 0.2948
# Epoch 28 Batch 79100 Loss 0.4155 Accuracy 0.2905
# Epoch 28 Batch 79150 Loss 0.4122 Accuracy 0.2894
# Epoch 28 Batch 79200 Loss 0.4124 Accuracy 0.2893
# Epoch 28 Batch 79250 Loss 0.4181 Accuracy 0.2907
# Epoch 28 Batch 79300 Loss 0.4177 Accuracy 0.2909
# Epoch 28 Batch 79350 Loss 0.4194 Accuracy 0.2912
# Epoch 29 Batch 83650 Loss 0.4266 Accuracy 0.2951
# Epoch 29 Batch 83700 Loss 0.4264 Accuracy 0.2951
# Epoch 29 Batch 83750 Loss 0.4268 Accuracy 0.2951
# Epoch 29 Batch 83800 Loss 0.4271 Accuracy 0.2953
# Epoch 29 Batch 83850 Loss 0.4272 Accuracy 0.2954
# Epoch 29 Batch 83900 Loss 0.4273 Accuracy 0.2953
# Epoch 29 Batch 83950 Loss 0.4271 Accuracy 0.2952
# Epoch 29 Batch 84000 Loss 0.4276 Accuracy 0.2953
# Epoch 29 Batch 84050 Loss 0.4278 Accuracy 0.2954
# Epoch 29 Batch 84100 Loss 0.4279 Accuracy 0.2954
# Epoch 29 Batch 84150 Loss 0.4283 Accuracy 0.2955
# Epoch 29 Batch 84200 Loss 0.4283 Accuracy 0.2954
# Epoch 29 Batch 84250 Loss 0.4282 Accuracy 0.2954
# Epoch 29 Batch 84300 Loss 0.4284 Accuracy 0.2954
# Epoch 29 Batch 84350 Loss 0.4285 Accuracy 0.2955
# Epoch 29 Batch 84400 Loss 0.4284 Accuracy 0.2956
# Epoch 29 Batch 84450 Loss 0.4286 Accuracy 0.2957
# Epoch 29 Batch 84500 Loss 0.4284 Accuracy 0.2956
# Epoch 29 Batch 84550 Loss 0.4286 Accuracy 0.2957
# Epoch 29 Batch 84600 Loss 0.4286 Accuracy 0.2958
# Epoch 29 Batch 84650 Loss 0.4285 Accuracy 0.2957
# Epoch 29 Batch 84700 Loss 0.4285 Accuracy 0.2956
# Epoch 29 Batch 84750 Loss 0.4284 Accuracy 0.2955
# Epoch 29 Batch 84800 Loss 0.4285 Accuracy 0.2956
# Epoch 29 Batch 84850 Loss 0.4283 Accuracy 0.2955
# Epoch 29 Loss 0.4282 Accuracy 0.2955
# Time taken for 1 epoch: 183.92150974273682 secs
#
# Epoch 30 Batch 84900 Loss 0.4156 Accuracy 0.2920
# Epoch 30 Batch 84950 Loss 0.4119 Accuracy 0.2935
# Epoch 30 Batch 85000 Loss 0.4174 Accuracy 0.2941
# Epoch 30 Batch 85050 Loss 0.4154 Accuracy 0.2929
# Epoch 30 Batch 85100 Loss 0.4169 Accuracy 0.2934
# Epoch 30 Batch 85150 Loss 0.4188 Accuracy 0.2939
# Epoch 30 Batch 85200 Loss 0.4199 Accuracy 0.2949
# Epoch 30 Batch 85250 Loss 0.4191 Accuracy 0.2957
# Epoch 30 Batch 85300 Loss 0.4195 Accuracy 0.2956
# Epoch 30 Batch 85350 Loss 0.4207 Accuracy 0.2955
# Epoch 30 Batch 85400 Loss 0.4208 Accuracy 0.2954
# Epoch 30 Batch 85450 Loss 0.4200 Accuracy 0.2950
# Epoch 30 Batch 85500 Loss 0.4204 Accuracy 0.2949
# Epoch 30 Batch 85550 Loss 0.4214 Accuracy 0.2947
# Epoch 30 Batch 85600 Loss 0.4225 Accuracy 0.2946
# Epoch 30 Batch 85650 Loss 0.4223 Accuracy 0.2946
# Epoch 30 Batch 85700 Loss 0.4218 Accuracy 0.2945
# Epoch 30 Batch 85750 Loss 0.4222 Accuracy 0.2947
# Epoch 30 Batch 85800 Loss 0.4222 Accuracy 0.2951
# Epoch 30 Batch 85850 Loss 0.4225 Accuracy 0.2955
# Epoch 30 Batch 85900 Loss 0.4228 Accuracy 0.2957
# Epoch 30 Batch 85950 Loss 0.4232 Accuracy 0.2956
# Epoch 30 Batch 86000 Loss 0.4231 Accuracy 0.2957
# Epoch 30 Batch 86050 Loss 0.4233 Accuracy 0.2958
# Epoch 30 Batch 86100 Loss 0.4232 Accuracy 0.2959
# Epoch 30 Batch 86150 Loss 0.4235 Accuracy 0.2958
# Epoch 30 Batch 86200 Loss 0.4236 Accuracy 0.2959
# Epoch 30 Batch 86250 Loss 0.4231 Accuracy 0.2958
# Epoch 30 Batch 86300 Loss 0.4239 Accuracy 0.2961
# Epoch 30 Batch 86350 Loss 0.4235 Accuracy 0.2959
# Epoch 30 Batch 86400 Loss 0.4236 Accuracy 0.2960
# Epoch 30 Batch 86450 Loss 0.4238 Accuracy 0.2960
# Epoch 30 Batch 86500 Loss 0.4243 Accuracy 0.2960
# Epoch 30 Batch 86550 Loss 0.4245 Accuracy 0.2958
# Epoch 30 Batch 86600 Loss 0.4245 Accuracy 0.2960
# Epoch 30 Batch 86650 Loss 0.4247 Accuracy 0.2959
# Epoch 30 Batch 86700 Loss 0.4250 Accuracy 0.2959
# Epoch 30 Batch 86750 Loss 0.4248 Accuracy 0.2958
# Epoch 30 Batch 86800 Loss 0.4252 Accuracy 0.2958
# Epoch 30 Batch 86850 Loss 0.4253 Accuracy 0.2958
# Epoch 30 Batch 86900 Loss 0.4253 Accuracy 0.2959
# Epoch 30 Batch 86950 Loss 0.4255 Accuracy 0.2959
# Epoch 30 Batch 87000 Loss 0.4254 Accuracy 0.2959
# Epoch 30 Batch 87050 Loss 0.4257 Accuracy 0.2959
# Epoch 30 Batch 87100 Loss 0.4255 Accuracy 0.2959
# Epoch 30 Batch 87150 Loss 0.4257 Accuracy 0.2959
# Epoch 30 Batch 87200 Loss 0.4257 Accuracy 0.2959
# Epoch 30 Batch 87250 Loss 0.4257 Accuracy 0.2959
# Epoch 30 Batch 87300 Loss 0.4259 Accuracy 0.2961
# Epoch 30 Batch 87350 Loss 0.4258 Accuracy 0.2960
# Epoch 30 Batch 87400 Loss 0.4255 Accuracy 0.2959
# Epoch 30 Batch 87450 Loss 0.4254 Accuracy 0.2959
# Epoch 30 Batch 87500 Loss 0.4256 Accuracy 0.2960
# Epoch 30 Batch 87550 Loss 0.4255 Accuracy 0.2960
# Epoch 30 Batch 87600 Loss 0.4260 Accuracy 0.2960
# Epoch 30 Batch 87650 Loss 0.4259 Accuracy 0.2960
# Epoch 30 Batch 87700 Loss 0.4260 Accuracy 0.2960
# Epoch 30 Batch 87750 Loss 0.4262 Accuracy 0.2959
# Epoch 30 Batch 87800 Loss 0.4262 Accuracy 0.2960
# Save checkpoints
# Epoch 30 Loss 0.4262 Accuracy 0.2959
# Time taken for 1 epoch: 185.89127326011658 secs
