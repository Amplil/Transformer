# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
notebook_dir="/content/drive/MyDrive/Colab Notebooks/Transformer"

# %%
cd "/content/drive/MyDrive/Colab Notebooks/Transformer"
# Out:
# /content/drive/.shortcut-targets-by-id/17vBJAZeuDCte4t5jYXL1emXc1Rm4jOqV/Transformer

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/packages")
import slacknotice # オリジナルモジュール slacknotice.send("")

# %% [markdown]
# # ライブラリ読み込み

# %%
# !apt install aptitude
# !aptitude install mecab libmecab-dev mecab-ipadic-utf8 git make curl xz-utils file -y
# !pip install mecab-python3==0.6
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   aptitude-common libcgi-fast-perl libcgi-pm-perl libclass-accessor-perl
#   libcwidget3v5 libencode-locale-perl libfcgi-perl libhtml-parser-perl
#   libhtml-tagset-perl libhttp-date-perl libhttp-message-perl libio-html-perl
#   libio-string-perl liblwp-mediatypes-perl libparse-debianchangelog-perl
#   libsigc++-2.0-0v5 libsub-name-perl libtimedate-perl liburi-perl libxapian30
# Suggested packages:
#   aptitude-doc-en | aptitude-doc apt-xapian-index debtags tasksel
#   libcwidget-dev libdata-dump-perl libhtml-template-perl libxml-simple-perl
#   libwww-perl xapian-tools
# The following NEW packages will be installed:
#   aptitude aptitude-common libcgi-fast-perl libcgi-pm-perl
#   libclass-accessor-perl libcwidget3v5 libencode-locale-perl libfcgi-perl
#   libhtml-parser-perl libhtml-tagset-perl libhttp-date-perl
#   libhttp-message-perl libio-html-perl libio-string-perl
#   liblwp-mediatypes-perl libparse-debianchangelog-perl libsigc++-2.0-0v5
#   libsub-name-perl libtimedate-perl liburi-perl libxapian30
# 0 upgraded, 21 newly installed, 0 to remove and 39 not upgraded.
# Need to get 3,877 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude-common all 0.8.10-6ubuntu1 [1,014 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigc++-2.0-0v5 amd64 2.10.0-2 [10.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcwidget3v5 amd64 0.5.17-7 [286 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxapian30 amd64 1.4.5-1ubuntu0.1 [631 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 aptitude amd64 0.8.10-6ubuntu1 [1,269 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-tagset-perl all 3.20-3 [12.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 liburi-perl all 1.73-1 [77.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhtml-parser-perl amd64 3.72-3build1 [85.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-pm-perl all 4.38-1 [185 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfcgi-perl amd64 0.78-2build1 [32.8 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcgi-fast-perl all 1:2.13-1 [9,940 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsub-name-perl amd64 0.21-1build1 [11.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libclass-accessor-perl all 0.51-1 [21.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libencode-locale-perl all 1.05-1 [12.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-date-perl all 6.02-1 [10.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-html-perl all 1.001-1 [14.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblwp-mediatypes-perl all 6.02-1 [21.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhttp-message-perl all 6.14-1 [72.1 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libio-string-perl all 1.08-3 [11.1 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libparse-debianchangelog-perl all 1.2.0-12 [49.5 kB]
# Fetched 3,877 kB in 0s (23.1 MB/s)
# Selecting previously unselected package aptitude-common.
# (Reading database ... 156210 files and directories currently installed.)
# Preparing to unpack .../00-aptitude-common_0.8.10-6ubuntu1_all.deb ...
# Unpacking aptitude-common (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libsigc++-2.0-0v5:amd64.
# Preparing to unpack .../01-libsigc++-2.0-0v5_2.10.0-2_amd64.deb ...
# Unpacking libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Selecting previously unselected package libcwidget3v5:amd64.
# Preparing to unpack .../02-libcwidget3v5_0.5.17-7_amd64.deb ...
# Unpacking libcwidget3v5:amd64 (0.5.17-7) ...
# Selecting previously unselected package libxapian30:amd64.
# Preparing to unpack .../03-libxapian30_1.4.5-1ubuntu0.1_amd64.deb ...
# Unpacking libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Selecting previously unselected package aptitude.
# Preparing to unpack .../04-aptitude_0.8.10-6ubuntu1_amd64.deb ...
# Unpacking aptitude (0.8.10-6ubuntu1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../05-libhtml-tagset-perl_3.20-3_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-3) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../06-liburi-perl_1.73-1_all.deb ...
# Unpacking liburi-perl (1.73-1) ...
# Selecting previously unselected package libhtml-parser-perl.
# Preparing to unpack .../07-libhtml-parser-perl_3.72-3build1_amd64.deb ...
# Unpacking libhtml-parser-perl (3.72-3build1) ...
# Selecting previously unselected package libcgi-pm-perl.
# Preparing to unpack .../08-libcgi-pm-perl_4.38-1_all.deb ...
# Unpacking libcgi-pm-perl (4.38-1) ...
# Selecting previously unselected package libfcgi-perl.
# Preparing to unpack .../09-libfcgi-perl_0.78-2build1_amd64.deb ...
# Unpacking libfcgi-perl (0.78-2build1) ...
# Selecting previously unselected package libcgi-fast-perl.
# Preparing to unpack .../10-libcgi-fast-perl_1%3a2.13-1_all.deb ...
# Unpacking libcgi-fast-perl (1:2.13-1) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../11-libsub-name-perl_0.21-1build1_amd64.deb ...
# Unpacking libsub-name-perl (0.21-1build1) ...
# Selecting previously unselected package libclass-accessor-perl.
# Preparing to unpack .../12-libclass-accessor-perl_0.51-1_all.deb ...
# Unpacking libclass-accessor-perl (0.51-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../13-libencode-locale-perl_1.05-1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../15-libhttp-date-perl_6.02-1_all.deb ...
# Unpacking libhttp-date-perl (6.02-1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../16-libio-html-perl_1.001-1_all.deb ...
# Unpacking libio-html-perl (1.001-1) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../17-liblwp-mediatypes-perl_6.02-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.02-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../18-libhttp-message-perl_6.14-1_all.deb ...
# Unpacking libhttp-message-perl (6.14-1) ...
# Selecting previously unselected package libio-string-perl.
# Preparing to unpack .../19-libio-string-perl_1.08-3_all.deb ...
# Unpacking libio-string-perl (1.08-3) ...
# Selecting previously unselected package libparse-debianchangelog-perl.
# Preparing to unpack .../20-libparse-debianchangelog-perl_1.2.0-12_all.deb ...
# Unpacking libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhtml-tagset-perl (3.20-3) ...
# Setting up libxapian30:amd64 (1.4.5-1ubuntu0.1) ...
# Setting up libencode-locale-perl (1.05-1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libio-html-perl (1.001-1) ...
# Setting up aptitude-common (0.8.10-6ubuntu1) ...
# Setting up liblwp-mediatypes-perl (6.02-1) ...
# Setting up liburi-perl (1.73-1) ...
# Setting up libhtml-parser-perl (3.72-3build1) ...
# Setting up libcgi-pm-perl (4.38-1) ...
# Setting up libio-string-perl (1.08-3) ...
# Setting up libsub-name-perl (0.21-1build1) ...
# Setting up libfcgi-perl (0.78-2build1) ...
# Setting up libsigc++-2.0-0v5:amd64 (2.10.0-2) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up libhttp-date-perl (6.02-1) ...
# Setting up libcgi-fast-perl (1:2.13-1) ...
# Setting up libparse-debianchangelog-perl (1.2.0-12) ...
# Setting up libhttp-message-perl (6.14-1) ...
# Setting up libcwidget3v5:amd64 (0.5.17-7) ...
# Setting up aptitude (0.8.10-6ubuntu1) ...
# update-alternatives: using /usr/bin/aptitude-curses to provide /usr/bin/aptitude (aptitude) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# git is already installed at the requested version (1:2.17.1-1ubuntu0.9)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.16)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# git is already installed at the requested version (1:2.17.1-1ubuntu0.9)
# make is already installed at the requested version (4.1-9.1ubuntu1)
# curl is already installed at the requested version (7.58.0-2ubuntu3.16)
# xz-utils is already installed at the requested version (5.2.2-1.3)
# The following NEW packages will be installed:
#   file libmagic-mgc{a} libmagic1{a} libmecab-dev libmecab2{a} mecab mecab-ipadic{a} mecab-ipadic-utf8 mecab-jumandic{a} mecab-jumandic-utf8{a} mecab-utils{a}
# 0 packages upgraded, 11 newly installed, 0 to remove and 39 not upgraded.
# Need to get 29.3 MB of archives. After unpacking 282 MB will be used.
# Get: 1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get: 2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get: 3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get: 4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab2 amd64 0.996-5 [257 kB]
# Get: 5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmecab-dev amd64 0.996-5 [308 kB]
# Get: 6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-utils amd64 0.996-5 [4,856 B]
# Get: 7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic-utf8 all 7.0-20130310-4 [16.2 MB]
# Get: 8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-jumandic all 7.0-20130310-4 [2,212 B]
# Get: 9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic all 2.7.0-20070801+main-1 [12.1 MB]
# Get: 10 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab amd64 0.996-5 [132 kB]
# Get: 11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 mecab-ipadic-utf8 all 2.7.0-20070801+main-1 [3,522 B]
# Fetched 29.3 MB in 2s (17.8 MB/s)
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 156669 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmecab2:amd64.
# Preparing to unpack .../03-libmecab2_0.996-5_amd64.deb ...
# Unpacking libmecab2:amd64 (0.996-5) ...
# Selecting previously unselected package libmecab-dev.
# Preparing to unpack .../04-libmecab-dev_0.996-5_amd64.deb ...
# Unpacking libmecab-dev (0.996-5) ...
# Selecting previously unselected package mecab-utils.
# Preparing to unpack .../05-mecab-utils_0.996-5_amd64.deb ...
# Unpacking mecab-utils (0.996-5) ...
# Selecting previously unselected package mecab-jumandic-utf8.
# Preparing to unpack .../06-mecab-jumandic-utf8_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic-utf8 (7.0-20130310-4) ...
# Selecting previously unselected package mecab-jumandic.
# Preparing to unpack .../07-mecab-jumandic_7.0-20130310-4_all.deb ...
# Unpacking mecab-jumandic (7.0-20130310-4) ...
# Selecting previously unselected package mecab-ipadic.
# Preparing to unpack .../08-mecab-ipadic_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic (2.7.0-20070801+main-1) ...
# Selecting previously unselected package mecab.
# Preparing to unpack .../09-mecab_0.996-5_amd64.deb ...
# Unpacking mecab (0.996-5) ...
# Selecting previously unselected package mecab-ipadic-utf8.
# Preparing to unpack .../10-mecab-ipadic-utf8_2.7.0-20070801+main-1_all.deb ...
# Unpacking mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Setting up libmecab2:amd64 (0.996-5) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up mecab-utils (0.996-5) ...
# Setting up mecab-ipadic (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up libmecab-dev (0.996-5) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up mecab-jumandic-utf8 (7.0-20130310-4) ...
# Compiling Juman dictionary for Mecab.
# reading /usr/share/mecab/dic/juman/unk.def ... 37
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/AuxV.csv ... 593
# reading /usr/share/mecab/dic/juman/Wikipedia.csv ... 167709
# reading /usr/share/mecab/dic/juman/Noun.keishiki.csv ... 8
# reading /usr/share/mecab/dic/juman/Auto.csv ... 18931
# reading /usr/share/mecab/dic/juman/Demonstrative.csv ... 97
# reading /usr/share/mecab/dic/juman/Postp.csv ... 108
# reading /usr/share/mecab/dic/juman/ContentW.csv ... 551145
# reading /usr/share/mecab/dic/juman/Prefix.csv ... 90
# reading /usr/share/mecab/dic/juman/Assert.csv ... 34
# reading /usr/share/mecab/dic/juman/Suffix.csv ... 2128
# reading /usr/share/mecab/dic/juman/Noun.suusi.csv ... 49
# reading /usr/share/mecab/dic/juman/Special.csv ... 158
# reading /usr/share/mecab/dic/juman/Emoticon.csv ... 972
# reading /usr/share/mecab/dic/juman/Rengo.csv ... 1118
# reading /usr/share/mecab/dic/juman/Noun.hukusi.csv ... 81
# reading /usr/share/mecab/dic/juman/Noun.koyuu.csv ... 7964
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/juman/matrix.def ... 1876x1876
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-ipadic-utf8 (2.7.0-20070801+main-1) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# update-alternatives: using /var/lib/mecab/dic/ipadic-utf8 to provide /var/lib/mecab/dic/debian (mecab-dictionary) in auto mode
# Setting up mecab (0.996-5) ...
# Compiling IPA dictionary for Mecab.  This takes long time...
# reading /usr/share/mecab/dic/ipadic/unk.def ... 40
# emitting double-array: 100% |###########################################|
# /usr/share/mecab/dic/ipadic/model.def is not found. skipped.
# reading /usr/share/mecab/dic/ipadic/Adj.csv ... 27210
# reading /usr/share/mecab/dic/ipadic/Noun.name.csv ... 34202
# reading /usr/share/mecab/dic/ipadic/Noun.org.csv ... 16668
# reading /usr/share/mecab/dic/ipadic/Noun.nai.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Interjection.csv ... 252
# reading /usr/share/mecab/dic/ipadic/Symbol.csv ... 208
# reading /usr/share/mecab/dic/ipadic/Postp.csv ... 146
# reading /usr/share/mecab/dic/ipadic/Postp-col.csv ... 91
# reading /usr/share/mecab/dic/ipadic/Noun.csv ... 60477
# reading /usr/share/mecab/dic/ipadic/Noun.proper.csv ... 27327
# reading /usr/share/mecab/dic/ipadic/Noun.adjv.csv ... 3328
# reading /usr/share/mecab/dic/ipadic/Prefix.csv ... 221
# reading /usr/share/mecab/dic/ipadic/Adnominal.csv ... 135
# reading /usr/share/mecab/dic/ipadic/Auxil.csv ... 199
# reading /usr/share/mecab/dic/ipadic/Noun.verbal.csv ... 12146
# reading /usr/share/mecab/dic/ipadic/Noun.others.csv ... 151
# reading /usr/share/mecab/dic/ipadic/Filler.csv ... 19
# reading /usr/share/mecab/dic/ipadic/Suffix.csv ... 1393
# reading /usr/share/mecab/dic/ipadic/Others.csv ... 2
# reading /usr/share/mecab/dic/ipadic/Verb.csv ... 130750
# reading /usr/share/mecab/dic/ipadic/Noun.adverbal.csv ... 795
# reading /usr/share/mecab/dic/ipadic/Noun.number.csv ... 42
# reading /usr/share/mecab/dic/ipadic/Adverb.csv ... 3032
# reading /usr/share/mecab/dic/ipadic/Noun.place.csv ... 72999
# reading /usr/share/mecab/dic/ipadic/Noun.demonst.csv ... 120
# reading /usr/share/mecab/dic/ipadic/Conjunction.csv ... 171
# emitting double-array: 100% |###########################################|
# reading /usr/share/mecab/dic/ipadic/matrix.def ... 1316x1316
# emitting matrix      : 100% |###########################################|
#
# done!
# Setting up mecab-jumandic (7.0-20130310-4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#
# Collecting mecab-python3==0.6
#   Downloading mecab-python3-0.6.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 396 kB/s
# Building wheels for collected packages: mecab-python3
#   Building wheel for mecab-python3 (setup.py) ... done
#   Created wheel for mecab-python3: filename=mecab_python3-0.6-cp37-cp37m-linux_x86_64.whl size=156606 sha256=89ba46d69a7ad4a0e74abdd429b2794353387eede23fdcdbf88b9ea504274de7
#   Stored in directory: /root/.cache/pip/wheels/9a/84/a1/7331af569b22ef2cbbc2a829a30145130c52663b0c9d34bcf5
# Successfully built mecab-python3
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-0.6

# %%
import numpy as np
import os
import time
import MeCab

import preprocess_utils_law
import model
import weight_utils

import tensorflow.keras as keras
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %% [markdown]
# # 日英法令対訳コーパス ダウンロード

# %%
# !wget http://www.phontron.com/jaen-law/jaen-law.tar.gz
# Out:
# --2022-04-07 09:36:53--  http://www.phontron.com/jaen-law/jaen-law.tar.gz
# Resolving www.phontron.com (www.phontron.com)... 208.113.196.149
# Connecting to www.phontron.com (www.phontron.com)|208.113.196.149|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18276054 (17M) [application/gzip]
# Saving to: ‘jaen-law.tar.gz.1’
#
# jaen-law.tar.gz.1   100%[===================>]  17.43M  37.0MB/s    in 0.5s
#
# 2022-04-07 09:36:54 (37.0 MB/s) - ‘jaen-law.tar.gz.1’ saved [18276054/18276054]

# %%
# !tar -xzf jaen-law.tar.gz # tar.gzの解凍

# %% [markdown]
# # データ読み込み

# %%
dataset = preprocess_utils_law.CreateData(
    corpus_path_source = './jaen-law/txt/law-corpus.ja',
    corpus_path_target = './jaen-law/txt/law-corpus.en',
    do_shuffle=True,
    seed_value=123,
    split_percent=0.95 # 学習データの割合
)

train_source, train_target, test_source, test_target= dataset.split_data()

print('**** Amount of data ****')
print('train_source： ', len(train_source))
print('train_target： ', len(train_target))
print('test_source： ', len(test_source))
print('test_target： ', len(test_target))
print('\n')
print('**** Train data example ****')
print('Source Example： ', train_source[0])
print('Target Example： ', train_target[0])
print('\n')
print('**** Test data example ****')
print('Source Example： ', test_source[0])
print('Target Example： ', test_target[0])
# Out:
# **** Amount of data ****
# train_source：  249327
# train_target：  249327
# test_source：  13122
# test_target：  13122
#
#
# **** Train data example ****
# Source Example：  第二十六条の四　前条第三項の認定を受けた事業主（以下「認定事業主」という。）は、当該認定に係る実施計画を変更しようとするときは、厚生労働大臣の認定を受けなければならない。
#
# Target Example：  Article 26-4  (1) An employer who has received the accreditation set forth in paragraph (3) of the preceding Article (hereinafter referred to as an "accredited employer") shall, when intending to change the plan for providing training pertaining to said accreditation, receive accreditation thereof from the Minister of Health, Labour and Welfare.
#
#
#
# **** Test data example ****
# Source Example：  附　則　〔平成十九年三月三十一日法律第二十三号〕〔抄〕
#
# Target Example：  Supplementary Provisions  [Act No. 23 of March 31, 2007]  [Extract]

# %% [markdown]
# # 前処理

# %%
BATCH_SIZE = 64 # バッチサイズ
MAX_LENGTH = 60 # シーケンスの長さ
USE_TPU = False # TPUを使うか
BUFFER_SIZE = 50000

# %%
train_dataset = preprocess_utils_law.PreprocessData(
    mecab = MeCab.Tagger("-Ochasen"),
    source_data = train_source,
    target_data = train_target,
    max_length = MAX_LENGTH,
    batch_size = BATCH_SIZE,
    test_flag = False,
    train_dataset = None,
)

train_dataset.preprocess_data()

# %%
if USE_TPU:
  tpu_grpc_url = "grpc://" + os.environ["COLAB_TPU_ADDR"]
  tpu_cluster_resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu_grpc_url)
  tf.config.experimental_connect_to_cluster(tpu_cluster_resolver)
  tf.tpu.experimental.initialize_tpu_system(tpu_cluster_resolver)    
  strategy = tf.distribute.experimental.TPUStrategy(tpu_cluster_resolver)

trainset = tf.data.Dataset.from_tensor_slices((train_dataset.source_vector, train_dataset.target_vector))
trainset = trainset.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))).shuffle(buffer_size=BUFFER_SIZE).batch(BATCH_SIZE).prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

if USE_TPU:
  trainset = strategy.experimental_distribute_dataset(trainset)

# %% [markdown]
# # モデル定義

# %%
num_layers=4 # レイヤー数
d_model=64 # 中間層の次元数
num_heads=4 # Multi Head Attentionのヘッド数
dff=2048 # Feed Forward Networkの次元数
dropout_rate = 0.1 # ドロップアウト率

source_vocab_size = max(train_dataset.source_token.values()) + 1 # source文の語彙数
target_vocab_size = max(train_dataset.target_token.values()) + 1 # target文の語彙数

# %%
# 重み初期化
def initialize_weight(checkpoint_path, optimizer, transformer, max_length, batch_size, use_tpu=False):

  if os.path.exists(checkpoint_path+'.pkl'):
    if use_tpu:
      number_of_tpu_cores = tpu_cluster_resolver.num_accelerators()['TPU']
      initialize_source, initialize_target = [[1]*max_length]*number_of_tpu_cores, [[1]*max_length]*number_of_tpu_cores
      initialize_set = tf.data.Dataset.from_tensor_slices((initialize_source, initialize_target))
      initialize_set = initialize_set.map(lambda source, target: (tf.cast(source, tf.int64), tf.cast(target, tf.int64))
          ).shuffle(buffer_size=BUFFER_SIZE).batch(batch_size).prefetch(
              buffer_size=tf.data.experimental.AUTOTUNE
          )
      initialize_set = strategy.experimental_distribute_dataset(initialize_set)

      for inp, tar in initialize_set:
        distributed_train_step(inp, tar)

    else:
      initialize_set = tf.ones([batch_size, max_length], tf.int64)
      train_step(initialize_set, initialize_set)
    
    try:
      weight_utils.load_weights_from_pickle(checkpoint_path, optimizer, transformer)
    except:
      print('Failed to load checkpoints.')

  else:
    print('No available checkpoints.')

# %% [markdown]
# # 学習実行

# %%
# Transformer
transformer = model.Transformer(num_layers, d_model, num_heads, dff,
                          source_vocab_size, target_vocab_size, 
                          pe_input=source_vocab_size, 
                          pe_target=target_vocab_size,
                          rate=dropout_rate)

# Learning Rate
learning_rate = model.CustomSchedule(d_model)

# Optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# Loss
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

# Loss Function
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  return tf.reduce_mean(loss_)

# Metrics
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

# Checkpoint
#checkpoint_path = "/content/drive/My Drive/Transformer-master/checkpoints/gpu/model"
checkpoint_path = notebook_dir+"/checkpoints/gpu/model"

train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]
@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]
  
  enc_padding_mask, combined_mask, dec_padding_mask = model.create_masks(inp, tar_inp)
  
  with tf.GradientTape() as tape:
    predictions, _ = transformer(inp, tar_inp, 
                                 True, 
                                 enc_padding_mask, 
                                 combined_mask, 
                                 dec_padding_mask)
    loss = loss_function(tar_real, predictions)

  gradients = tape.gradient(loss, transformer.trainable_variables)    
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
  
  train_loss(loss)
  train_accuracy(tar_real, predictions)

# Initialize Weight
initialize_weight(checkpoint_path, optimizer, transformer, MAX_LENGTH, BATCH_SIZE, use_tpu=USE_TPU)

EPOCHS = 30
batch = 0

for epoch in range(EPOCHS):
  start = time.time()
  
  train_loss.reset_states()
  train_accuracy.reset_states()
  
  for inp, tar in trainset:
    train_step(inp, tar)
    
    if batch % 50 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
          epoch + 1, batch, train_loss.result(), train_accuracy.result()))
      
    batch+=1
      
  if (epoch + 1) % 5 == 0:
    print('Saving checkpoint for epoch {} at {}'.format(epoch+1, checkpoint_path))
    weight_utils.save_weights_as_pickle(checkpoint_path, optimizer, transformer)
    
  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))

  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Failed to load checkpoints.
# Epoch 1 Batch 0 Loss 3.7372 Accuracy 0.0000
# Epoch 1 Batch 50 Loss 3.9527 Accuracy 0.0004
# Epoch 1 Batch 100 Loss 3.8785 Accuracy 0.0106
# Epoch 1 Batch 150 Loss 3.8782 Accuracy 0.0154
# Epoch 1 Batch 200 Loss 3.8075 Accuracy 0.0176
# Epoch 1 Batch 250 Loss 3.7382 Accuracy 0.0190
# Epoch 1 Batch 300 Loss 3.6570 Accuracy 0.0197
# Epoch 1 Batch 350 Loss 3.5765 Accuracy 0.0207
# Epoch 1 Batch 400 Loss 3.4958 Accuracy 0.0224
# Epoch 1 Batch 450 Loss 3.4038 Accuracy 0.0244
# Epoch 1 Batch 500 Loss 3.3115 Accuracy 0.0265
# Epoch 1 Batch 550 Loss 3.2279 Accuracy 0.0283
# Epoch 1 Batch 600 Loss 3.1521 Accuracy 0.0306
# Epoch 1 Batch 650 Loss 3.0827 Accuracy 0.0341
# Epoch 1 Batch 700 Loss 3.0191 Accuracy 0.0374
# Epoch 1 Batch 750 Loss 2.9518 Accuracy 0.0405
# Epoch 1 Batch 800 Loss 2.8876 Accuracy 0.0440
# Epoch 1 Batch 850 Loss 2.8264 Accuracy 0.0477
# Epoch 1 Batch 900 Loss 2.7691 Accuracy 0.0514
# Epoch 1 Batch 950 Loss 2.7140 Accuracy 0.0548
# Epoch 1 Batch 1000 Loss 2.6642 Accuracy 0.0581
# Epoch 1 Batch 1050 Loss 2.6172 Accuracy 0.0613
# Epoch 1 Batch 1100 Loss 2.5702 Accuracy 0.0643
# Epoch 1 Batch 1150 Loss 2.5281 Accuracy 0.0673
# Epoch 1 Batch 1200 Loss 2.4877 Accuracy 0.0701
# Epoch 1 Batch 1250 Loss 2.4490 Accuracy 0.0728
# Epoch 1 Batch 1300 Loss 2.4138 Accuracy 0.0754
# Epoch 1 Batch 1350 Loss 2.3801 Accuracy 0.0780
# Epoch 1 Batch 1400 Loss 2.3481 Accuracy 0.0805
# Epoch 1 Batch 1450 Loss 2.3175 Accuracy 0.0828
# Epoch 1 Batch 1500 Loss 2.2883 Accuracy 0.0850
# Epoch 1 Batch 1550 Loss 2.2602 Accuracy 0.0872
# Epoch 1 Batch 1600 Loss 2.2330 Accuracy 0.0893
# Epoch 1 Batch 1650 Loss 2.2069 Accuracy 0.0912
# Epoch 1 Batch 1700 Loss 2.1828 Accuracy 0.0931
# Epoch 1 Batch 1750 Loss 2.1587 Accuracy 0.0949
# Epoch 1 Batch 1800 Loss 2.1359 Accuracy 0.0967
# Epoch 1 Batch 1850 Loss 2.1144 Accuracy 0.0984
# Epoch 1 Batch 1900 Loss 2.0926 Accuracy 0.1002
# Epoch 1 Batch 1950 Loss 2.0717 Accuracy 0.1018
# Epoch 1 Batch 2000 Loss 2.0518 Accuracy 0.1033
# Epoch 1 Batch 2050 Loss 2.0332 Accuracy 0.1049
# Epoch 1 Batch 2100 Loss 2.0151 Accuracy 0.1065
# Epoch 1 Batch 2150 Loss 1.9978 Accuracy 0.1080
# Epoch 1 Batch 2200 Loss 1.9805 Accuracy 0.1094
# Epoch 1 Batch 2250 Loss 1.9636 Accuracy 0.1107
# Epoch 1 Batch 2300 Loss 1.9482 Accuracy 0.1122
# Epoch 1 Batch 2350 Loss 1.9328 Accuracy 0.1135
# Epoch 1 Batch 2400 Loss 1.9177 Accuracy 0.1148
# Epoch 1 Batch 2450 Loss 1.9025 Accuracy 0.1161
# Epoch 1 Batch 2500 Loss 1.8880 Accuracy 0.1173
# Epoch 1 Batch 2550 Loss 1.8738 Accuracy 0.1186
# Epoch 1 Batch 2600 Loss 1.8599 Accuracy 0.1198
# Epoch 1 Batch 2650 Loss 1.8469 Accuracy 0.1210
# Epoch 1 Batch 2700 Loss 1.8335 Accuracy 0.1221
# Epoch 1 Batch 2750 Loss 1.8206 Accuracy 0.1232
# Epoch 1 Batch 2800 Loss 1.8088 Accuracy 0.1243
# Epoch 1 Batch 2850 Loss 1.7964 Accuracy 0.1254
# Epoch 1 Batch 2900 Loss 1.7844 Accuracy 0.1265
# Epoch 1 Loss 1.7782 Accuracy 0.1270
# Time taken for 1 epoch: 730.3050005435944 secs
#
# Epoch 2 Batch 2950 Loss 1.0573 Accuracy 0.1935
# Epoch 2 Batch 3000 Loss 1.0762 Accuracy 0.1920
# Epoch 2 Batch 3050 Loss 1.0752 Accuracy 0.1912
# Epoch 2 Batch 3100 Loss 1.0724 Accuracy 0.1909
# Epoch 2 Batch 3150 Loss 1.0719 Accuracy 0.1911
# Epoch 2 Batch 3200 Loss 1.0623 Accuracy 0.1915
# Epoch 2 Batch 3250 Loss 1.0580 Accuracy 0.1911
# Epoch 2 Batch 3300 Loss 1.0532 Accuracy 0.1914
# Epoch 2 Batch 3350 Loss 1.0504 Accuracy 0.1922
# Epoch 2 Batch 3400 Loss 1.0495 Accuracy 0.1933
# Epoch 2 Batch 3450 Loss 1.0433 Accuracy 0.1940
# Epoch 2 Batch 3500 Loss 1.0381 Accuracy 0.1944
# Epoch 2 Batch 3550 Loss 1.0348 Accuracy 0.1954
# Epoch 2 Batch 3600 Loss 1.0311 Accuracy 0.1960
# Epoch 2 Batch 3650 Loss 1.0268 Accuracy 0.1963
# Epoch 2 Batch 3700 Loss 1.0235 Accuracy 0.1967
# Epoch 2 Batch 3750 Loss 1.0196 Accuracy 0.1974
# Epoch 2 Batch 3800 Loss 1.0164 Accuracy 0.1981
# Epoch 2 Batch 3850 Loss 1.0141 Accuracy 0.1984
# Epoch 2 Batch 3900 Loss 1.0109 Accuracy 0.1989
# Epoch 2 Batch 3950 Loss 1.0061 Accuracy 0.1996
# Epoch 2 Batch 4000 Loss 1.0032 Accuracy 0.2001
# Epoch 2 Batch 4050 Loss 1.0001 Accuracy 0.2007
# Epoch 2 Batch 4100 Loss 0.9963 Accuracy 0.2011
# Epoch 2 Batch 4150 Loss 0.9937 Accuracy 0.2018
# Epoch 2 Batch 4200 Loss 0.9896 Accuracy 0.2023
# Epoch 2 Batch 4250 Loss 0.9859 Accuracy 0.2028
# Epoch 2 Batch 4300 Loss 0.9822 Accuracy 0.2032
# Epoch 2 Batch 4350 Loss 0.9789 Accuracy 0.2037
# Epoch 2 Batch 4400 Loss 0.9767 Accuracy 0.2043
# Epoch 2 Batch 4450 Loss 0.9732 Accuracy 0.2047
# Epoch 2 Batch 4500 Loss 0.9694 Accuracy 0.2051
# Epoch 2 Batch 4550 Loss 0.9660 Accuracy 0.2056
# Epoch 2 Batch 4600 Loss 0.9631 Accuracy 0.2061
# Epoch 2 Batch 4650 Loss 0.9601 Accuracy 0.2066
# Epoch 2 Batch 4700 Loss 0.9572 Accuracy 0.2071
# Epoch 2 Batch 4750 Loss 0.9531 Accuracy 0.2073
# Epoch 2 Batch 4800 Loss 0.9503 Accuracy 0.2078
# Epoch 2 Batch 4850 Loss 0.9480 Accuracy 0.2082
# Epoch 2 Batch 4900 Loss 0.9449 Accuracy 0.2087
# Epoch 2 Batch 4950 Loss 0.9419 Accuracy 0.2090
# Epoch 2 Batch 5000 Loss 0.9395 Accuracy 0.2094
# Epoch 2 Batch 5050 Loss 0.9366 Accuracy 0.2097
# Epoch 2 Batch 5100 Loss 0.9339 Accuracy 0.2101
# Epoch 2 Batch 5150 Loss 0.9309 Accuracy 0.2104
# Epoch 2 Batch 5200 Loss 0.9284 Accuracy 0.2107
# Epoch 2 Batch 5250 Loss 0.9262 Accuracy 0.2112
# Epoch 2 Batch 5300 Loss 0.9234 Accuracy 0.2115
# Epoch 2 Batch 5350 Loss 0.9211 Accuracy 0.2118
# Epoch 2 Batch 5400 Loss 0.9188 Accuracy 0.2122
# Epoch 2 Batch 5450 Loss 0.9168 Accuracy 0.2126
# Epoch 2 Batch 5500 Loss 0.9145 Accuracy 0.2130
# Epoch 2 Batch 5550 Loss 0.9123 Accuracy 0.2134
# Epoch 2 Batch 5600 Loss 0.9097 Accuracy 0.2138
# Epoch 2 Batch 5650 Loss 0.9078 Accuracy 0.2141
# Epoch 2 Batch 5700 Loss 0.9057 Accuracy 0.2145
# Epoch 2 Batch 5750 Loss 0.9042 Accuracy 0.2149
# Epoch 2 Batch 5800 Loss 0.9017 Accuracy 0.2152
# Epoch 2 Batch 5850 Loss 0.8996 Accuracy 0.2157
# Epoch 2 Loss 0.8995 Accuracy 0.2157
# Time taken for 1 epoch: 726.7865128517151 secs
#
# Epoch 3 Batch 5900 Loss 0.7736 Accuracy 0.2344
# Epoch 3 Batch 5950 Loss 0.7636 Accuracy 0.2353
# Epoch 3 Batch 6000 Loss 0.7619 Accuracy 0.2360
# Epoch 3 Batch 6050 Loss 0.7573 Accuracy 0.2352
# Epoch 3 Batch 6100 Loss 0.7566 Accuracy 0.2350
# Epoch 3 Batch 6150 Loss 0.7521 Accuracy 0.2352
# Epoch 3 Batch 6200 Loss 0.7485 Accuracy 0.2351
# Epoch 3 Batch 6250 Loss 0.7469 Accuracy 0.2351
# Epoch 3 Batch 6300 Loss 0.7462 Accuracy 0.2355
# Epoch 3 Batch 6350 Loss 0.7449 Accuracy 0.2363
# Epoch 3 Batch 6400 Loss 0.7468 Accuracy 0.2367
# Epoch 3 Batch 6450 Loss 0.7466 Accuracy 0.2371
# Epoch 3 Batch 6500 Loss 0.7460 Accuracy 0.2376
# Epoch 3 Batch 6550 Loss 0.7463 Accuracy 0.2379
# Epoch 3 Batch 6600 Loss 0.7442 Accuracy 0.2382
# Epoch 3 Batch 6650 Loss 0.7432 Accuracy 0.2384
# Epoch 3 Batch 6700 Loss 0.7416 Accuracy 0.2384
# Epoch 3 Batch 6750 Loss 0.7413 Accuracy 0.2387
# Epoch 3 Batch 6800 Loss 0.7403 Accuracy 0.2388
# Epoch 3 Batch 6850 Loss 0.7398 Accuracy 0.2390
# Epoch 3 Batch 6900 Loss 0.7391 Accuracy 0.2391
# Epoch 3 Batch 6950 Loss 0.7384 Accuracy 0.2390
# Epoch 3 Batch 7000 Loss 0.7379 Accuracy 0.2389
# Epoch 3 Batch 7050 Loss 0.7371 Accuracy 0.2392
# Epoch 3 Batch 7100 Loss 0.7356 Accuracy 0.2395
# Epoch 3 Batch 7150 Loss 0.7342 Accuracy 0.2396
# Epoch 3 Batch 7200 Loss 0.7334 Accuracy 0.2398
# Epoch 3 Batch 7250 Loss 0.7319 Accuracy 0.2402
# Epoch 3 Batch 7300 Loss 0.7310 Accuracy 0.2403
# Epoch 3 Batch 7350 Loss 0.7294 Accuracy 0.2404
# Epoch 3 Batch 7400 Loss 0.7287 Accuracy 0.2405
# Epoch 3 Batch 7450 Loss 0.7277 Accuracy 0.2408
# Epoch 3 Batch 7500 Loss 0.7273 Accuracy 0.2409
# Epoch 3 Batch 7550 Loss 0.7264 Accuracy 0.2411
# Epoch 3 Batch 7600 Loss 0.7251 Accuracy 0.2411
# Epoch 3 Batch 7650 Loss 0.7250 Accuracy 0.2413
# Epoch 3 Batch 7700 Loss 0.7241 Accuracy 0.2414
# Epoch 3 Batch 7750 Loss 0.7240 Accuracy 0.2416
# Epoch 3 Batch 7800 Loss 0.7234 Accuracy 0.2417
# Epoch 3 Batch 7850 Loss 0.7224 Accuracy 0.2419
# Epoch 3 Batch 7900 Loss 0.7220 Accuracy 0.2421
# Epoch 3 Batch 7950 Loss 0.7209 Accuracy 0.2424
# Epoch 3 Batch 8000 Loss 0.7205 Accuracy 0.2426
# Epoch 3 Batch 8050 Loss 0.7201 Accuracy 0.2429
# Epoch 3 Batch 8100 Loss 0.7191 Accuracy 0.2429
# Epoch 3 Batch 8150 Loss 0.7177 Accuracy 0.2429
# Epoch 3 Batch 8200 Loss 0.7171 Accuracy 0.2430
# Epoch 3 Batch 8250 Loss 0.7164 Accuracy 0.2431
# Epoch 3 Batch 8300 Loss 0.7158 Accuracy 0.2433
# Epoch 3 Batch 8350 Loss 0.7154 Accuracy 0.2435
# Epoch 3 Batch 8400 Loss 0.7150 Accuracy 0.2437
# Epoch 3 Batch 8450 Loss 0.7139 Accuracy 0.2438
# Epoch 3 Batch 8500 Loss 0.7134 Accuracy 0.2439
# Epoch 3 Batch 8550 Loss 0.7131 Accuracy 0.2441
# Epoch 3 Batch 8600 Loss 0.7124 Accuracy 0.2443
# Epoch 3 Batch 8650 Loss 0.7115 Accuracy 0.2444
# Epoch 3 Batch 8700 Loss 0.7108 Accuracy 0.2446
# Epoch 3 Batch 8750 Loss 0.7106 Accuracy 0.2447
# Epoch 3 Loss 0.7102 Accuracy 0.2448
# Time taken for 1 epoch: 726.1287136077881 secs
#
# Epoch 4 Batch 8800 Loss 0.6581 Accuracy 0.2522
# Epoch 4 Batch 8850 Loss 0.6497 Accuracy 0.2510
# Epoch 4 Batch 8900 Loss 0.6584 Accuracy 0.2523
# Epoch 4 Batch 8950 Loss 0.6546 Accuracy 0.2522
# Epoch 4 Batch 9000 Loss 0.6530 Accuracy 0.2526
# Epoch 4 Batch 9050 Loss 0.6549 Accuracy 0.2527
# Epoch 4 Batch 9100 Loss 0.6535 Accuracy 0.2524
# Epoch 4 Batch 9150 Loss 0.6515 Accuracy 0.2525
# Epoch 4 Batch 9200 Loss 0.6542 Accuracy 0.2531
# Epoch 4 Batch 9250 Loss 0.6538 Accuracy 0.2531
# Epoch 4 Batch 9300 Loss 0.6539 Accuracy 0.2533
# Epoch 4 Batch 9350 Loss 0.6538 Accuracy 0.2535
# Epoch 4 Batch 9400 Loss 0.6531 Accuracy 0.2536
# Epoch 4 Batch 9450 Loss 0.6525 Accuracy 0.2538
# Epoch 4 Batch 9500 Loss 0.6523 Accuracy 0.2536
# Epoch 4 Batch 9550 Loss 0.6521 Accuracy 0.2538
# Epoch 4 Batch 9600 Loss 0.6519 Accuracy 0.2539
# Epoch 4 Batch 9650 Loss 0.6518 Accuracy 0.2541
# Epoch 4 Batch 9700 Loss 0.6511 Accuracy 0.2543
# Epoch 4 Batch 9750 Loss 0.6512 Accuracy 0.2545
# Epoch 4 Batch 9800 Loss 0.6504 Accuracy 0.2544
# Epoch 4 Batch 9850 Loss 0.6488 Accuracy 0.2544
# Epoch 4 Batch 9900 Loss 0.6490 Accuracy 0.2544
# Epoch 4 Batch 9950 Loss 0.6491 Accuracy 0.2545
# Epoch 4 Batch 10000 Loss 0.6481 Accuracy 0.2546
# Epoch 4 Batch 10050 Loss 0.6477 Accuracy 0.2546
# Epoch 4 Batch 10100 Loss 0.6473 Accuracy 0.2546
# Epoch 4 Batch 10150 Loss 0.6472 Accuracy 0.2547
# Epoch 4 Batch 10200 Loss 0.6464 Accuracy 0.2549
# Epoch 4 Batch 10250 Loss 0.6466 Accuracy 0.2549
# Epoch 4 Batch 10300 Loss 0.6468 Accuracy 0.2552
# Epoch 4 Batch 10350 Loss 0.6463 Accuracy 0.2552
# Epoch 4 Batch 10400 Loss 0.6463 Accuracy 0.2553
# Epoch 4 Batch 10450 Loss 0.6465 Accuracy 0.2555
# Epoch 4 Batch 10500 Loss 0.6464 Accuracy 0.2557
# Epoch 4 Batch 10550 Loss 0.6455 Accuracy 0.2558
# Epoch 4 Batch 10600 Loss 0.6452 Accuracy 0.2558
# Epoch 4 Batch 10650 Loss 0.6449 Accuracy 0.2558
# Epoch 4 Batch 10700 Loss 0.6443 Accuracy 0.2557
# Epoch 4 Batch 10750 Loss 0.6438 Accuracy 0.2558
# Epoch 4 Batch 10800 Loss 0.6434 Accuracy 0.2558
# Epoch 4 Batch 10850 Loss 0.6431 Accuracy 0.2560
# Epoch 4 Batch 10900 Loss 0.6430 Accuracy 0.2561
# Epoch 4 Batch 10950 Loss 0.6430 Accuracy 0.2562
# Epoch 4 Batch 11000 Loss 0.6423 Accuracy 0.2562
# Epoch 4 Batch 11050 Loss 0.6419 Accuracy 0.2562
# Epoch 4 Batch 11100 Loss 0.6414 Accuracy 0.2563
# Epoch 4 Batch 11150 Loss 0.6412 Accuracy 0.2563
# Epoch 4 Batch 11200 Loss 0.6406 Accuracy 0.2563
# Epoch 4 Batch 11250 Loss 0.6404 Accuracy 0.2564
# Epoch 4 Batch 11300 Loss 0.6403 Accuracy 0.2564
# Epoch 4 Batch 11350 Loss 0.6397 Accuracy 0.2564
# Epoch 4 Batch 11400 Loss 0.6392 Accuracy 0.2564
# Epoch 4 Batch 11450 Loss 0.6391 Accuracy 0.2565
# Epoch 4 Batch 11500 Loss 0.6388 Accuracy 0.2566
# Epoch 4 Batch 11550 Loss 0.6389 Accuracy 0.2568
# Epoch 4 Batch 11600 Loss 0.6386 Accuracy 0.2568
# Epoch 4 Batch 11650 Loss 0.6383 Accuracy 0.2569
# Epoch 4 Batch 11700 Loss 0.6379 Accuracy 0.2570
# Epoch 4 Loss 0.6379 Accuracy 0.2570
# Time taken for 1 epoch: 725.729567527771 secs
#
# Epoch 5 Batch 11750 Loss 0.5952 Accuracy 0.2579
# Epoch 5 Batch 11800 Loss 0.5913 Accuracy 0.2575
# Epoch 5 Batch 11850 Loss 0.5978 Accuracy 0.2588
# Epoch 5 Batch 11900 Loss 0.6020 Accuracy 0.2594
# Epoch 5 Batch 11950 Loss 0.6057 Accuracy 0.2590
# Epoch 5 Batch 12000 Loss 0.6038 Accuracy 0.2585
# Epoch 5 Batch 12050 Loss 0.6050 Accuracy 0.2596
# Epoch 5 Batch 12100 Loss 0.6035 Accuracy 0.2596
# Epoch 5 Batch 12150 Loss 0.6033 Accuracy 0.2601
# Epoch 5 Batch 12200 Loss 0.6019 Accuracy 0.2602
# Epoch 5 Batch 12250 Loss 0.6014 Accuracy 0.2600
# Epoch 5 Batch 12300 Loss 0.6033 Accuracy 0.2603
# Epoch 5 Batch 12350 Loss 0.6027 Accuracy 0.2603
# Epoch 5 Batch 12400 Loss 0.6012 Accuracy 0.2603
# Epoch 5 Batch 12450 Loss 0.5999 Accuracy 0.2604
# Epoch 5 Batch 12500 Loss 0.6002 Accuracy 0.2607
# Epoch 5 Batch 12550 Loss 0.6008 Accuracy 0.2612
# Epoch 5 Batch 12600 Loss 0.6006 Accuracy 0.2611
# Epoch 5 Batch 12650 Loss 0.6013 Accuracy 0.2613
# Epoch 5 Batch 12700 Loss 0.6009 Accuracy 0.2611
# Epoch 5 Batch 12750 Loss 0.6011 Accuracy 0.2612
# Epoch 5 Batch 12800 Loss 0.6010 Accuracy 0.2615
# Epoch 5 Batch 12850 Loss 0.6008 Accuracy 0.2615
# Epoch 5 Batch 12900 Loss 0.6008 Accuracy 0.2617
# Epoch 5 Batch 12950 Loss 0.6013 Accuracy 0.2619
# Epoch 5 Batch 13000 Loss 0.6018 Accuracy 0.2621
# Epoch 5 Batch 13050 Loss 0.6029 Accuracy 0.2625
# Epoch 5 Batch 13100 Loss 0.6027 Accuracy 0.2627
# Epoch 5 Batch 13150 Loss 0.6023 Accuracy 0.2628
# Epoch 5 Batch 13200 Loss 0.6024 Accuracy 0.2629
# Epoch 5 Batch 13250 Loss 0.6019 Accuracy 0.2629
# Epoch 5 Batch 13300 Loss 0.6018 Accuracy 0.2628
# Epoch 5 Batch 13350 Loss 0.6019 Accuracy 0.2629
# Epoch 5 Batch 13400 Loss 0.6018 Accuracy 0.2629
# Epoch 5 Batch 13450 Loss 0.6017 Accuracy 0.2631
# Epoch 5 Batch 13500 Loss 0.6012 Accuracy 0.2632
# Epoch 5 Batch 13550 Loss 0.6013 Accuracy 0.2633
# Epoch 5 Batch 13600 Loss 0.6012 Accuracy 0.2634
# Epoch 5 Batch 13650 Loss 0.6014 Accuracy 0.2635
# Epoch 5 Batch 13700 Loss 0.6009 Accuracy 0.2634
# Epoch 5 Batch 13750 Loss 0.6012 Accuracy 0.2635
# Epoch 5 Batch 13800 Loss 0.6003 Accuracy 0.2635
# Epoch 5 Batch 13850 Loss 0.5997 Accuracy 0.2634
# Epoch 5 Batch 13900 Loss 0.5994 Accuracy 0.2634
# Epoch 5 Batch 13950 Loss 0.5991 Accuracy 0.2634
# Epoch 5 Batch 14000 Loss 0.5990 Accuracy 0.2634
# Epoch 5 Batch 14050 Loss 0.5994 Accuracy 0.2635
# Epoch 5 Batch 14100 Loss 0.5990 Accuracy 0.2635
# Epoch 5 Batch 14150 Loss 0.5990 Accuracy 0.2635
# Epoch 5 Batch 14200 Loss 0.5985 Accuracy 0.2637
# Epoch 5 Batch 14250 Loss 0.5987 Accuracy 0.2639
# Epoch 5 Batch 14300 Loss 0.5984 Accuracy 0.2639
# Epoch 5 Batch 14350 Loss 0.5980 Accuracy 0.2638
# Epoch 5 Batch 14400 Loss 0.5980 Accuracy 0.2639
# Epoch 5 Batch 14450 Loss 0.5978 Accuracy 0.2639
# Epoch 5 Batch 14500 Loss 0.5975 Accuracy 0.2638
# Epoch 5 Batch 14550 Loss 0.5972 Accuracy 0.2639
# Epoch 5 Batch 14600 Loss 0.5970 Accuracy 0.2640
# Saving checkpoint for epoch 5 at /content/drive/MyDrive/Colab Notebooks/Transformer/checkpoints/gpu/model
# Save checkpoints
# Epoch 5 Loss 0.5969 Accuracy 0.2641
# Time taken for 1 epoch: 726.4358835220337 secs
#
# Epoch 6 Batch 14650 Loss 0.6042 Accuracy 0.2692
# Epoch 6 Batch 14700 Loss 0.5689 Accuracy 0.2669
# Epoch 6 Batch 14750 Loss 0.5676 Accuracy 0.2688
# Epoch 6 Batch 14800 Loss 0.5675 Accuracy 0.2676
# Epoch 6 Batch 14850 Loss 0.5682 Accuracy 0.2673
# Epoch 6 Batch 14900 Loss 0.5688 Accuracy 0.2676
# Epoch 6 Batch 14950 Loss 0.5695 Accuracy 0.2676
# Epoch 6 Batch 15000 Loss 0.5689 Accuracy 0.2670
# Epoch 6 Batch 15050 Loss 0.5696 Accuracy 0.2665
# Epoch 6 Batch 15100 Loss 0.5699 Accuracy 0.2671
# Epoch 6 Batch 15150 Loss 0.5705 Accuracy 0.2670
# Epoch 6 Batch 15200 Loss 0.5717 Accuracy 0.2673
# Epoch 6 Batch 15250 Loss 0.5721 Accuracy 0.2671
# Epoch 6 Batch 15300 Loss 0.5713 Accuracy 0.2672
# Epoch 6 Batch 15350 Loss 0.5728 Accuracy 0.2675
# Epoch 6 Batch 15400 Loss 0.5712 Accuracy 0.2672
# Epoch 6 Batch 15450 Loss 0.5717 Accuracy 0.2673
# Epoch 6 Batch 15500 Loss 0.5717 Accuracy 0.2672
# Epoch 6 Batch 15550 Loss 0.5709 Accuracy 0.2670
# Epoch 6 Batch 15600 Loss 0.5711 Accuracy 0.2671
# Epoch 6 Batch 15650 Loss 0.5716 Accuracy 0.2673
# Epoch 6 Batch 15700 Loss 0.5714 Accuracy 0.2672
# Epoch 6 Batch 15750 Loss 0.5716 Accuracy 0.2672
# Epoch 6 Batch 15800 Loss 0.5720 Accuracy 0.2676
# Epoch 6 Batch 15850 Loss 0.5714 Accuracy 0.2674
# Epoch 6 Batch 15900 Loss 0.5715 Accuracy 0.2675
# Epoch 6 Batch 15950 Loss 0.5716 Accuracy 0.2677
# Epoch 6 Batch 16000 Loss 0.5722 Accuracy 0.2678
# Epoch 6 Batch 16050 Loss 0.5716 Accuracy 0.2679
# Epoch 6 Batch 16100 Loss 0.5712 Accuracy 0.2680
# Epoch 6 Batch 16150 Loss 0.5704 Accuracy 0.2679
# Epoch 6 Batch 16200 Loss 0.5707 Accuracy 0.2680
# Epoch 6 Batch 16250 Loss 0.5707 Accuracy 0.2682
# Epoch 6 Batch 16300 Loss 0.5708 Accuracy 0.2680
# Epoch 6 Batch 16350 Loss 0.5706 Accuracy 0.2680
# Epoch 6 Batch 16400 Loss 0.5710 Accuracy 0.2682
# Epoch 6 Batch 16450 Loss 0.5712 Accuracy 0.2683
# Epoch 6 Batch 16500 Loss 0.5713 Accuracy 0.2685
# Epoch 6 Batch 16550 Loss 0.5711 Accuracy 0.2685
# Epoch 6 Batch 16600 Loss 0.5710 Accuracy 0.2685
# Epoch 6 Batch 16650 Loss 0.5711 Accuracy 0.2686
# Epoch 6 Batch 16700 Loss 0.5711 Accuracy 0.2687
# Epoch 6 Batch 16750 Loss 0.5712 Accuracy 0.2686
# Epoch 6 Batch 16800 Loss 0.5708 Accuracy 0.2688
# Epoch 6 Batch 16850 Loss 0.5708 Accuracy 0.2688
# Epoch 6 Batch 16900 Loss 0.5706 Accuracy 0.2688
# Epoch 6 Batch 16950 Loss 0.5698 Accuracy 0.2687
# Epoch 6 Batch 17000 Loss 0.5701 Accuracy 0.2688
# Epoch 6 Batch 17050 Loss 0.5694 Accuracy 0.2687
# Epoch 6 Batch 17100 Loss 0.5696 Accuracy 0.2687
# Epoch 6 Batch 17150 Loss 0.5697 Accuracy 0.2689
# Epoch 6 Batch 17200 Loss 0.5698 Accuracy 0.2689
# Epoch 6 Batch 17250 Loss 0.5695 Accuracy 0.2690
# Epoch 6 Batch 17300 Loss 0.5695 Accuracy 0.2691
# Epoch 6 Batch 17350 Loss 0.5693 Accuracy 0.2691
# Epoch 6 Batch 17400 Loss 0.5691 Accuracy 0.2691
# Epoch 6 Batch 17450 Loss 0.5690 Accuracy 0.2691
# Epoch 6 Batch 17500 Loss 0.5688 Accuracy 0.2691
# Epoch 6 Batch 17550 Loss 0.5689 Accuracy 0.2691
# Epoch 6 Loss 0.5688 Accuracy 0.2691
# Time taken for 1 epoch: 726.1143357753754 secs
#
# Epoch 7 Batch 17600 Loss 0.5626 Accuracy 0.2738
# Epoch 7 Batch 17650 Loss 0.5607 Accuracy 0.2723
# Epoch 7 Batch 17700 Loss 0.5509 Accuracy 0.2715
# Epoch 7 Batch 17750 Loss 0.5467 Accuracy 0.2691
# Epoch 7 Batch 17800 Loss 0.5461 Accuracy 0.2700
# Epoch 7 Batch 17850 Loss 0.5478 Accuracy 0.2710
# Epoch 7 Batch 17900 Loss 0.5451 Accuracy 0.2708
# Epoch 7 Batch 17950 Loss 0.5446 Accuracy 0.2704
# Epoch 7 Batch 18000 Loss 0.5437 Accuracy 0.2702
# Epoch 7 Batch 18050 Loss 0.5440 Accuracy 0.2706
# Epoch 7 Batch 18100 Loss 0.5449 Accuracy 0.2704
# Epoch 7 Batch 18150 Loss 0.5462 Accuracy 0.2712
# Epoch 7 Batch 18200 Loss 0.5451 Accuracy 0.2709
# Epoch 7 Batch 18250 Loss 0.5446 Accuracy 0.2708
# Epoch 7 Batch 18300 Loss 0.5446 Accuracy 0.2710
# Epoch 7 Batch 18350 Loss 0.5450 Accuracy 0.2712
# Epoch 7 Batch 18400 Loss 0.5451 Accuracy 0.2707
# Epoch 7 Batch 18450 Loss 0.5462 Accuracy 0.2711
# Epoch 7 Batch 18500 Loss 0.5468 Accuracy 0.2712
# Epoch 7 Batch 18550 Loss 0.5467 Accuracy 0.2713
# Epoch 7 Batch 18600 Loss 0.5468 Accuracy 0.2710
# Epoch 7 Batch 18650 Loss 0.5481 Accuracy 0.2710
# Epoch 7 Batch 18700 Loss 0.5483 Accuracy 0.2710
# Epoch 7 Batch 18750 Loss 0.5485 Accuracy 0.2713
# Epoch 7 Batch 18800 Loss 0.5484 Accuracy 0.2714
# Epoch 7 Batch 18850 Loss 0.5488 Accuracy 0.2717
# Epoch 7 Batch 18900 Loss 0.5489 Accuracy 0.2716
# Epoch 7 Batch 18950 Loss 0.5483 Accuracy 0.2716
# Epoch 7 Batch 19000 Loss 0.5485 Accuracy 0.2718
# Epoch 7 Batch 19050 Loss 0.5482 Accuracy 0.2718
# Epoch 7 Batch 19100 Loss 0.5481 Accuracy 0.2719
# Epoch 7 Batch 19150 Loss 0.5481 Accuracy 0.2720
# Epoch 7 Batch 19200 Loss 0.5482 Accuracy 0.2720
# Epoch 7 Batch 19250 Loss 0.5485 Accuracy 0.2722
# Epoch 7 Batch 19300 Loss 0.5483 Accuracy 0.2721
# Epoch 7 Batch 19350 Loss 0.5485 Accuracy 0.2721
# Epoch 7 Batch 19400 Loss 0.5490 Accuracy 0.2723
# Epoch 7 Batch 19450 Loss 0.5494 Accuracy 0.2724
# Epoch 7 Batch 19500 Loss 0.5493 Accuracy 0.2724
# Epoch 7 Batch 19550 Loss 0.5492 Accuracy 0.2723
# Epoch 7 Batch 19600 Loss 0.5490 Accuracy 0.2724
# Epoch 7 Batch 19650 Loss 0.5489 Accuracy 0.2724
# Epoch 7 Batch 19700 Loss 0.5483 Accuracy 0.2725
# Epoch 7 Batch 19750 Loss 0.5482 Accuracy 0.2726
# Epoch 7 Batch 19800 Loss 0.5479 Accuracy 0.2725
# Epoch 7 Batch 19850 Loss 0.5477 Accuracy 0.2725
# Epoch 7 Batch 19900 Loss 0.5477 Accuracy 0.2726
# Epoch 7 Batch 19950 Loss 0.5478 Accuracy 0.2725
# Epoch 7 Batch 20000 Loss 0.5480 Accuracy 0.2725
# Epoch 7 Batch 20050 Loss 0.5481 Accuracy 0.2725
# Epoch 7 Batch 20100 Loss 0.5477 Accuracy 0.2724
# Epoch 7 Batch 20150 Loss 0.5478 Accuracy 0.2724
# Epoch 7 Batch 20200 Loss 0.5479 Accuracy 0.2725
# Epoch 7 Batch 20250 Loss 0.5480 Accuracy 0.2725
# Epoch 7 Batch 20300 Loss 0.5480 Accuracy 0.2725
# Epoch 7 Batch 20350 Loss 0.5479 Accuracy 0.2725
# Epoch 7 Batch 20400 Loss 0.5480 Accuracy 0.2727
# Epoch 7 Batch 20450 Loss 0.5480 Accuracy 0.2727
# Epoch 7 Loss 0.5479 Accuracy 0.2728
# Time taken for 1 epoch: 725.4213778972626 secs
#
# Epoch 8 Batch 20500 Loss 0.4959 Accuracy 0.2710
# Epoch 8 Batch 20550 Loss 0.5293 Accuracy 0.2745
# Epoch 8 Batch 20600 Loss 0.5264 Accuracy 0.2764
# Epoch 8 Batch 20650 Loss 0.5243 Accuracy 0.2742
# Epoch 8 Batch 20700 Loss 0.5238 Accuracy 0.2729
# Epoch 8 Batch 20750 Loss 0.5268 Accuracy 0.2736
# Epoch 8 Batch 20800 Loss 0.5274 Accuracy 0.2738
# Epoch 8 Batch 20850 Loss 0.5268 Accuracy 0.2743
# Epoch 8 Batch 20900 Loss 0.5284 Accuracy 0.2746
# Epoch 8 Batch 20950 Loss 0.5298 Accuracy 0.2748
# Epoch 8 Batch 21000 Loss 0.5288 Accuracy 0.2747
# Epoch 8 Batch 21050 Loss 0.5294 Accuracy 0.2743
# Epoch 8 Batch 21100 Loss 0.5279 Accuracy 0.2736
# Epoch 8 Batch 21150 Loss 0.5279 Accuracy 0.2738
# Epoch 8 Batch 21200 Loss 0.5291 Accuracy 0.2737
# Epoch 8 Batch 21250 Loss 0.5296 Accuracy 0.2740
# Epoch 8 Batch 21300 Loss 0.5291 Accuracy 0.2739
# Epoch 8 Batch 21350 Loss 0.5302 Accuracy 0.2743
# Epoch 8 Batch 21400 Loss 0.5303 Accuracy 0.2747
# Epoch 8 Batch 21450 Loss 0.5314 Accuracy 0.2750
# Epoch 8 Batch 21500 Loss 0.5319 Accuracy 0.2751
# Epoch 8 Batch 21550 Loss 0.5322 Accuracy 0.2751
# Epoch 8 Batch 21600 Loss 0.5323 Accuracy 0.2753
# Epoch 8 Batch 21650 Loss 0.5330 Accuracy 0.2753
# Epoch 8 Batch 21700 Loss 0.5330 Accuracy 0.2753
# Epoch 8 Batch 21750 Loss 0.5328 Accuracy 0.2755
# Epoch 8 Batch 21800 Loss 0.5316 Accuracy 0.2751
# Epoch 8 Batch 21850 Loss 0.5318 Accuracy 0.2752
# Epoch 8 Batch 21900 Loss 0.5318 Accuracy 0.2752
# Epoch 8 Batch 21950 Loss 0.5319 Accuracy 0.2755
# Epoch 8 Batch 22000 Loss 0.5323 Accuracy 0.2757
# Epoch 8 Batch 22050 Loss 0.5318 Accuracy 0.2759
# Epoch 8 Batch 22100 Loss 0.5316 Accuracy 0.2759
# Epoch 8 Batch 22150 Loss 0.5314 Accuracy 0.2758
# Epoch 8 Batch 22200 Loss 0.5310 Accuracy 0.2757
# Epoch 8 Batch 22250 Loss 0.5311 Accuracy 0.2759
# Epoch 8 Batch 22300 Loss 0.5308 Accuracy 0.2758
# Epoch 8 Batch 22350 Loss 0.5305 Accuracy 0.2757
# Epoch 8 Batch 22400 Loss 0.5309 Accuracy 0.2759
# Epoch 8 Batch 22450 Loss 0.5306 Accuracy 0.2759
# Epoch 8 Batch 22500 Loss 0.5305 Accuracy 0.2759
# Epoch 8 Batch 22550 Loss 0.5311 Accuracy 0.2760
# Epoch 8 Batch 22600 Loss 0.5312 Accuracy 0.2760
# Epoch 8 Batch 22650 Loss 0.5312 Accuracy 0.2760
# Epoch 8 Batch 22700 Loss 0.5311 Accuracy 0.2760
# Epoch 8 Batch 22750 Loss 0.5313 Accuracy 0.2760
# Epoch 8 Batch 22800 Loss 0.5317 Accuracy 0.2759
# Epoch 8 Batch 22850 Loss 0.5317 Accuracy 0.2759
# Epoch 8 Batch 22900 Loss 0.5315 Accuracy 0.2760
# Epoch 8 Batch 22950 Loss 0.5314 Accuracy 0.2759
# Epoch 8 Batch 23000 Loss 0.5308 Accuracy 0.2760
# Epoch 8 Batch 23050 Loss 0.5307 Accuracy 0.2758
# Epoch 8 Batch 23100 Loss 0.5312 Accuracy 0.2759
# Epoch 8 Batch 23150 Loss 0.5312 Accuracy 0.2759
# Epoch 8 Batch 23200 Loss 0.5314 Accuracy 0.2759
# Epoch 8 Batch 23250 Loss 0.5315 Accuracy 0.2759
# Epoch 8 Batch 23300 Loss 0.5317 Accuracy 0.2759
# Epoch 8 Batch 23350 Loss 0.5315 Accuracy 0.2759
# Epoch 8 Batch 23400 Loss 0.5316 Accuracy 0.2759
# Epoch 8 Loss 0.5316 Accuracy 0.2759
# Time taken for 1 epoch: 726.655969619751 secs
#
# Epoch 9 Batch 23450 Loss 0.5054 Accuracy 0.2793
# Epoch 9 Batch 23500 Loss 0.5138 Accuracy 0.2793
# Epoch 9 Batch 23550 Loss 0.5155 Accuracy 0.2773
# Epoch 9 Batch 23600 Loss 0.5157 Accuracy 0.2779
# Epoch 9 Batch 23650 Loss 0.5160 Accuracy 0.2769
# Epoch 9 Batch 23700 Loss 0.5148 Accuracy 0.2772
# Epoch 9 Batch 23750 Loss 0.5150 Accuracy 0.2769
# Epoch 9 Batch 23800 Loss 0.5169 Accuracy 0.2771
# Epoch 9 Batch 23850 Loss 0.5168 Accuracy 0.2772
# Epoch 9 Batch 23900 Loss 0.5163 Accuracy 0.2771
# Epoch 9 Batch 23950 Loss 0.5159 Accuracy 0.2767
# Epoch 9 Batch 24000 Loss 0.5169 Accuracy 0.2771
# Epoch 9 Batch 24050 Loss 0.5172 Accuracy 0.2773
# Epoch 9 Batch 24100 Loss 0.5168 Accuracy 0.2775
# Epoch 9 Batch 24150 Loss 0.5162 Accuracy 0.2776
# Epoch 9 Batch 24200 Loss 0.5151 Accuracy 0.2776
# Epoch 9 Batch 24250 Loss 0.5148 Accuracy 0.2775
# Epoch 9 Batch 24300 Loss 0.5151 Accuracy 0.2774
# Epoch 9 Batch 24350 Loss 0.5152 Accuracy 0.2775
# Epoch 9 Batch 24400 Loss 0.5148 Accuracy 0.2774
# Epoch 9 Batch 24450 Loss 0.5153 Accuracy 0.2773
# Epoch 9 Batch 24500 Loss 0.5154 Accuracy 0.2773
# Epoch 9 Batch 24550 Loss 0.5154 Accuracy 0.2772
# Epoch 9 Batch 24600 Loss 0.5153 Accuracy 0.2775
# Epoch 9 Batch 24650 Loss 0.5157 Accuracy 0.2777
# Epoch 9 Batch 24700 Loss 0.5156 Accuracy 0.2778
# Epoch 9 Batch 24750 Loss 0.5157 Accuracy 0.2777
# Epoch 9 Batch 24800 Loss 0.5152 Accuracy 0.2775
# Epoch 9 Batch 24850 Loss 0.5154 Accuracy 0.2776
# Epoch 9 Batch 24900 Loss 0.5156 Accuracy 0.2777
# Epoch 9 Batch 24950 Loss 0.5154 Accuracy 0.2777
# Epoch 9 Batch 25000 Loss 0.5161 Accuracy 0.2778
# Epoch 9 Batch 25050 Loss 0.5159 Accuracy 0.2777
# Epoch 9 Batch 25100 Loss 0.5159 Accuracy 0.2777
# Epoch 9 Batch 25150 Loss 0.5160 Accuracy 0.2777
# Epoch 9 Batch 25200 Loss 0.5162 Accuracy 0.2777
# Epoch 9 Batch 25250 Loss 0.5165 Accuracy 0.2778
# Epoch 9 Batch 25300 Loss 0.5164 Accuracy 0.2777
# Epoch 9 Batch 25350 Loss 0.5165 Accuracy 0.2777
# Epoch 9 Batch 25400 Loss 0.5166 Accuracy 0.2777
# Epoch 9 Batch 25450 Loss 0.5170 Accuracy 0.2778
# Epoch 9 Batch 25500 Loss 0.5171 Accuracy 0.2778
# Epoch 9 Batch 25550 Loss 0.5173 Accuracy 0.2779
# Epoch 9 Batch 25600 Loss 0.5173 Accuracy 0.2779
# Epoch 9 Batch 25650 Loss 0.5173 Accuracy 0.2781
# Epoch 9 Batch 25700 Loss 0.5173 Accuracy 0.2781
# Epoch 9 Batch 25750 Loss 0.5174 Accuracy 0.2781
# Epoch 9 Batch 25800 Loss 0.5177 Accuracy 0.2782
# Epoch 9 Batch 25850 Loss 0.5175 Accuracy 0.2782
# Epoch 9 Batch 25900 Loss 0.5175 Accuracy 0.2782
# Epoch 9 Batch 25950 Loss 0.5177 Accuracy 0.2783
# Epoch 9 Batch 26000 Loss 0.5180 Accuracy 0.2782
# Epoch 9 Batch 26050 Loss 0.5179 Accuracy 0.2782
# Epoch 9 Batch 26100 Loss 0.5177 Accuracy 0.2782
# Epoch 9 Batch 26150 Loss 0.5179 Accuracy 0.2782
# Epoch 9 Batch 26200 Loss 0.5183 Accuracy 0.2782
# Epoch 9 Batch 26250 Loss 0.5183 Accuracy 0.2782
# Epoch 9 Batch 26300 Loss 0.5180 Accuracy 0.2782
# Epoch 9 Loss 0.5183 Accuracy 0.2783
# Time taken for 1 epoch: 728.1470782756805 secs
#
# Epoch 10 Batch 26350 Loss 0.4850 Accuracy 0.2701
# Epoch 10 Batch 26400 Loss 0.4934 Accuracy 0.2788
# Epoch 10 Batch 26450 Loss 0.5029 Accuracy 0.2794
# Epoch 10 Batch 26500 Loss 0.5043 Accuracy 0.2782
# Epoch 10 Batch 26550 Loss 0.5009 Accuracy 0.2782
# Epoch 10 Batch 26600 Loss 0.5041 Accuracy 0.2792
# Epoch 10 Batch 26650 Loss 0.5027 Accuracy 0.2785
# Epoch 10 Batch 26700 Loss 0.5033 Accuracy 0.2788
# Epoch 10 Batch 26750 Loss 0.5028 Accuracy 0.2787
# Epoch 10 Batch 26800 Loss 0.5021 Accuracy 0.2785
# Epoch 10 Batch 26850 Loss 0.5014 Accuracy 0.2786
# Epoch 10 Batch 26900 Loss 0.5020 Accuracy 0.2783
# Epoch 10 Batch 26950 Loss 0.5026 Accuracy 0.2782
# Epoch 10 Batch 27000 Loss 0.5037 Accuracy 0.2786
# Epoch 10 Batch 27050 Loss 0.5030 Accuracy 0.2781
# Epoch 10 Batch 27100 Loss 0.5037 Accuracy 0.2785
# Epoch 10 Batch 27150 Loss 0.5045 Accuracy 0.2790
# Epoch 10 Batch 27200 Loss 0.5034 Accuracy 0.2789
# Epoch 10 Batch 27250 Loss 0.5036 Accuracy 0.2787
# Epoch 10 Batch 27300 Loss 0.5036 Accuracy 0.2788
# Epoch 10 Batch 27350 Loss 0.5041 Accuracy 0.2790
# Epoch 10 Batch 27400 Loss 0.5050 Accuracy 0.2793
# Epoch 10 Batch 27450 Loss 0.5052 Accuracy 0.2793
# Epoch 10 Batch 27500 Loss 0.5057 Accuracy 0.2794
# Epoch 10 Batch 27550 Loss 0.5048 Accuracy 0.2791
# Epoch 10 Batch 27600 Loss 0.5041 Accuracy 0.2789
# Epoch 10 Batch 27650 Loss 0.5056 Accuracy 0.2793
# Epoch 10 Batch 27700 Loss 0.5059 Accuracy 0.2795
# Epoch 10 Batch 27750 Loss 0.5061 Accuracy 0.2796
# Epoch 10 Batch 27800 Loss 0.5063 Accuracy 0.2798
# Epoch 10 Batch 27850 Loss 0.5066 Accuracy 0.2798
# Epoch 10 Batch 27900 Loss 0.5067 Accuracy 0.2798
# Epoch 10 Batch 27950 Loss 0.5064 Accuracy 0.2798
# Epoch 10 Batch 28000 Loss 0.5069 Accuracy 0.2799
# Epoch 10 Batch 28050 Loss 0.5071 Accuracy 0.2799
# Epoch 10 Batch 28100 Loss 0.5074 Accuracy 0.2800
# Epoch 10 Batch 28150 Loss 0.5077 Accuracy 0.2800
# Epoch 10 Batch 28200 Loss 0.5074 Accuracy 0.2800
# Epoch 10 Batch 28250 Loss 0.5076 Accuracy 0.2801
# Epoch 10 Batch 28300 Loss 0.5078 Accuracy 0.2800
# Epoch 10 Batch 28350 Loss 0.5079 Accuracy 0.2802
# Epoch 10 Batch 28400 Loss 0.5077 Accuracy 0.2801
# Epoch 10 Batch 28450 Loss 0.5079 Accuracy 0.2801
# Epoch 10 Batch 28500 Loss 0.5078 Accuracy 0.2801
# Epoch 10 Batch 28550 Loss 0.5075 Accuracy 0.2801
# Epoch 10 Batch 28600 Loss 0.5078 Accuracy 0.2801
# Epoch 10 Batch 28650 Loss 0.5079 Accuracy 0.2801
# Epoch 10 Batch 28700 Loss 0.5080 Accuracy 0.2802
# Epoch 10 Batch 28750 Loss 0.5079 Accuracy 0.2802
# Epoch 10 Batch 28800 Loss 0.5077 Accuracy 0.2801
# Epoch 10 Batch 28850 Loss 0.5078 Accuracy 0.2801
# Epoch 10 Batch 28900 Loss 0.5079 Accuracy 0.2802
# Epoch 10 Batch 28950 Loss 0.5078 Accuracy 0.2801
# Epoch 10 Batch 29000 Loss 0.5081 Accuracy 0.2802
# Epoch 10 Batch 29050 Loss 0.5081 Accuracy 0.2802
# Epoch 10 Batch 29100 Loss 0.5080 Accuracy 0.2803
# Epoch 10 Batch 29150 Loss 0.5080 Accuracy 0.2804
# Epoch 10 Batch 29200 Loss 0.5078 Accuracy 0.2803
# Epoch 10 Batch 29250 Loss 0.5077 Accuracy 0.2802
# Saving checkpoint for epoch 10 at /content/drive/MyDrive/Colab Notebooks/Transformer/checkpoints/gpu/model
# Save checkpoints
# Epoch 10 Loss 0.5077 Accuracy 0.2803
# Time taken for 1 epoch: 729.9851520061493 secs
#
# Epoch 11 Batch 29300 Loss 0.5122 Accuracy 0.2799
# Epoch 11 Batch 29350 Loss 0.4972 Accuracy 0.2785
# Epoch 11 Batch 29400 Loss 0.4952 Accuracy 0.2789
# Epoch 11 Batch 29450 Loss 0.4940 Accuracy 0.2800
# Epoch 11 Batch 29500 Loss 0.4959 Accuracy 0.2802
# Epoch 11 Batch 29550 Loss 0.4959 Accuracy 0.2791
# Epoch 11 Batch 29600 Loss 0.4971 Accuracy 0.2791
# Epoch 11 Batch 29650 Loss 0.4939 Accuracy 0.2790
# Epoch 11 Batch 29700 Loss 0.4934 Accuracy 0.2792
# Epoch 11 Batch 29750 Loss 0.4951 Accuracy 0.2794
# Epoch 11 Batch 29800 Loss 0.4938 Accuracy 0.2791
# Epoch 11 Batch 29850 Loss 0.4935 Accuracy 0.2794
# Epoch 11 Batch 29900 Loss 0.4943 Accuracy 0.2797
# Epoch 11 Batch 29950 Loss 0.4940 Accuracy 0.2797
# Epoch 11 Batch 30000 Loss 0.4946 Accuracy 0.2799
# Epoch 11 Batch 30050 Loss 0.4946 Accuracy 0.2802
# Epoch 11 Batch 30100 Loss 0.4947 Accuracy 0.2801
# Epoch 11 Batch 30150 Loss 0.4952 Accuracy 0.2803
# Epoch 11 Batch 30200 Loss 0.4950 Accuracy 0.2804
# Epoch 11 Batch 30250 Loss 0.4946 Accuracy 0.2806
# Epoch 11 Batch 30300 Loss 0.4950 Accuracy 0.2806
# Epoch 11 Batch 30350 Loss 0.4946 Accuracy 0.2808
# Epoch 11 Batch 30400 Loss 0.4962 Accuracy 0.2812
# Epoch 11 Batch 30450 Loss 0.4965 Accuracy 0.2814
# Epoch 11 Batch 30500 Loss 0.4964 Accuracy 0.2812
# Epoch 11 Batch 30550 Loss 0.4966 Accuracy 0.2814
# Epoch 11 Batch 30600 Loss 0.4961 Accuracy 0.2816
# Epoch 11 Batch 30650 Loss 0.4959 Accuracy 0.2816
# Epoch 11 Batch 30700 Loss 0.4957 Accuracy 0.2819
# Epoch 11 Batch 30750 Loss 0.4955 Accuracy 0.2818
# Epoch 11 Batch 30800 Loss 0.4955 Accuracy 0.2818
# Epoch 11 Batch 30850 Loss 0.4955 Accuracy 0.2817
# Epoch 11 Batch 30900 Loss 0.4958 Accuracy 0.2816
# Epoch 11 Batch 30950 Loss 0.4960 Accuracy 0.2816
# Epoch 11 Batch 31000 Loss 0.4961 Accuracy 0.2817
# Epoch 11 Batch 31050 Loss 0.4964 Accuracy 0.2818
# Epoch 11 Batch 31100 Loss 0.4970 Accuracy 0.2817
# Epoch 11 Batch 31150 Loss 0.4966 Accuracy 0.2817
# Epoch 11 Batch 31200 Loss 0.4964 Accuracy 0.2816
# Epoch 11 Batch 31250 Loss 0.4967 Accuracy 0.2815
# Epoch 11 Batch 31300 Loss 0.4973 Accuracy 0.2817
# Epoch 11 Batch 31350 Loss 0.4975 Accuracy 0.2817
# Epoch 11 Batch 31400 Loss 0.4976 Accuracy 0.2818
# Epoch 11 Batch 31450 Loss 0.4974 Accuracy 0.2818
# Epoch 11 Batch 31500 Loss 0.4971 Accuracy 0.2818
# Epoch 11 Batch 31550 Loss 0.4969 Accuracy 0.2817
# Epoch 11 Batch 31600 Loss 0.4971 Accuracy 0.2817
# Epoch 11 Batch 31650 Loss 0.4976 Accuracy 0.2817
# Epoch 11 Batch 31700 Loss 0.4976 Accuracy 0.2817
# Epoch 11 Batch 31750 Loss 0.4976 Accuracy 0.2817
# Epoch 11 Batch 31800 Loss 0.4976 Accuracy 0.2817
# Epoch 11 Batch 31850 Loss 0.4977 Accuracy 0.2817
# Epoch 11 Batch 31900 Loss 0.4977 Accuracy 0.2818
# Epoch 11 Batch 31950 Loss 0.4975 Accuracy 0.2819
# Epoch 11 Batch 32000 Loss 0.4976 Accuracy 0.2819
# Epoch 11 Batch 32050 Loss 0.4978 Accuracy 0.2820
# Epoch 11 Batch 32100 Loss 0.4981 Accuracy 0.2820
# Epoch 11 Batch 32150 Loss 0.4985 Accuracy 0.2821
# Epoch 11 Loss 0.4984 Accuracy 0.2821
# Time taken for 1 epoch: 729.1678173542023 secs
#
# Epoch 12 Batch 32200 Loss 0.5470 Accuracy 0.2865
# Epoch 12 Batch 32250 Loss 0.4908 Accuracy 0.2818
# Epoch 12 Batch 32300 Loss 0.4893 Accuracy 0.2838
# Epoch 12 Batch 32350 Loss 0.4880 Accuracy 0.2848
# Epoch 12 Batch 32400 Loss 0.4852 Accuracy 0.2841
# Epoch 12 Batch 32450 Loss 0.4837 Accuracy 0.2834
# Epoch 12 Batch 32500 Loss 0.4839 Accuracy 0.2836
# Epoch 12 Batch 32550 Loss 0.4824 Accuracy 0.2832
# Epoch 12 Batch 32600 Loss 0.4816 Accuracy 0.2828
# Epoch 12 Batch 32650 Loss 0.4830 Accuracy 0.2826
# Epoch 12 Batch 32700 Loss 0.4818 Accuracy 0.2821
# Epoch 12 Batch 32750 Loss 0.4839 Accuracy 0.2826
# Epoch 12 Batch 32800 Loss 0.4842 Accuracy 0.2826
# Epoch 12 Batch 32850 Loss 0.4851 Accuracy 0.2823
# Epoch 12 Batch 32900 Loss 0.4860 Accuracy 0.2825
# Epoch 12 Batch 32950 Loss 0.4865 Accuracy 0.2824
# Epoch 12 Batch 33000 Loss 0.4862 Accuracy 0.2826
# Epoch 12 Batch 33050 Loss 0.4863 Accuracy 0.2823
# Epoch 12 Batch 33100 Loss 0.4860 Accuracy 0.2821
# Epoch 12 Batch 33150 Loss 0.4857 Accuracy 0.2822
# Epoch 12 Batch 33200 Loss 0.4860 Accuracy 0.2824
# Epoch 12 Batch 33250 Loss 0.4869 Accuracy 0.2824
# Epoch 12 Batch 33300 Loss 0.4872 Accuracy 0.2822
# Epoch 12 Batch 33350 Loss 0.4880 Accuracy 0.2824
# Epoch 12 Batch 33400 Loss 0.4880 Accuracy 0.2825
# Epoch 12 Batch 33450 Loss 0.4875 Accuracy 0.2824
# Epoch 12 Batch 33500 Loss 0.4876 Accuracy 0.2825
# Epoch 12 Batch 33550 Loss 0.4883 Accuracy 0.2827
# Epoch 12 Batch 33600 Loss 0.4880 Accuracy 0.2829
# Epoch 12 Batch 33650 Loss 0.4883 Accuracy 0.2830
# Epoch 12 Batch 33700 Loss 0.4880 Accuracy 0.2829
# Epoch 12 Batch 33750 Loss 0.4880 Accuracy 0.2829
# Epoch 12 Batch 33800 Loss 0.4879 Accuracy 0.2830
# Epoch 12 Batch 33850 Loss 0.4882 Accuracy 0.2830
# Epoch 12 Batch 33900 Loss 0.4887 Accuracy 0.2832
# Epoch 12 Batch 33950 Loss 0.4884 Accuracy 0.2831
# Epoch 12 Batch 34000 Loss 0.4887 Accuracy 0.2832
# Epoch 12 Batch 34050 Loss 0.4886 Accuracy 0.2833
# Epoch 12 Batch 34100 Loss 0.4883 Accuracy 0.2834
# Epoch 12 Batch 34150 Loss 0.4888 Accuracy 0.2834
# Epoch 12 Batch 34200 Loss 0.4888 Accuracy 0.2834
# Epoch 12 Batch 34250 Loss 0.4887 Accuracy 0.2833
# Epoch 12 Batch 34300 Loss 0.4887 Accuracy 0.2833
# Epoch 12 Batch 34350 Loss 0.4885 Accuracy 0.2834
# Epoch 12 Batch 34400 Loss 0.4887 Accuracy 0.2833
# Epoch 12 Batch 34450 Loss 0.4888 Accuracy 0.2833
# Epoch 12 Batch 34500 Loss 0.4889 Accuracy 0.2834
# Epoch 12 Batch 34550 Loss 0.4890 Accuracy 0.2835
# Epoch 12 Batch 34600 Loss 0.4890 Accuracy 0.2834
# Epoch 12 Batch 34650 Loss 0.4891 Accuracy 0.2834
# Epoch 12 Batch 34700 Loss 0.4888 Accuracy 0.2834
# Epoch 12 Batch 34750 Loss 0.4894 Accuracy 0.2833
# Epoch 12 Batch 34800 Loss 0.4895 Accuracy 0.2834
# Epoch 12 Batch 34850 Loss 0.4897 Accuracy 0.2834
# Epoch 12 Batch 34900 Loss 0.4898 Accuracy 0.2834
# Epoch 12 Batch 34950 Loss 0.4898 Accuracy 0.2835
# Epoch 12 Batch 35000 Loss 0.4899 Accuracy 0.2834
# Epoch 12 Batch 35050 Loss 0.4901 Accuracy 0.2834
# Epoch 12 Batch 35100 Loss 0.4901 Accuracy 0.2834
# Epoch 12 Loss 0.4901 Accuracy 0.2835
# Time taken for 1 epoch: 728.7793712615967 secs
#
# Epoch 13 Batch 35150 Loss 0.4634 Accuracy 0.2864
# Epoch 13 Batch 35200 Loss 0.4686 Accuracy 0.2856
# Epoch 13 Batch 35250 Loss 0.4730 Accuracy 0.2852
# Epoch 13 Batch 35300 Loss 0.4742 Accuracy 0.2846
# Epoch 13 Batch 35350 Loss 0.4763 Accuracy 0.2852
# Epoch 13 Batch 35400 Loss 0.4756 Accuracy 0.2839
# Epoch 13 Batch 35450 Loss 0.4763 Accuracy 0.2834
# Epoch 13 Batch 35500 Loss 0.4763 Accuracy 0.2837
# Epoch 13 Batch 35550 Loss 0.4758 Accuracy 0.2831
# Epoch 13 Batch 35600 Loss 0.4747 Accuracy 0.2833
# Epoch 13 Batch 35650 Loss 0.4747 Accuracy 0.2831
# Epoch 13 Batch 35700 Loss 0.4739 Accuracy 0.2831
# Epoch 13 Batch 35750 Loss 0.4734 Accuracy 0.2831
# Epoch 13 Batch 35800 Loss 0.4724 Accuracy 0.2829
# Epoch 13 Batch 35850 Loss 0.4737 Accuracy 0.2830
# Epoch 13 Batch 35900 Loss 0.4749 Accuracy 0.2831
# Epoch 13 Batch 35950 Loss 0.4754 Accuracy 0.2830
# Epoch 13 Batch 36000 Loss 0.4762 Accuracy 0.2833
# Epoch 13 Batch 36050 Loss 0.4764 Accuracy 0.2834
# Epoch 13 Batch 36100 Loss 0.4763 Accuracy 0.2836
# Epoch 13 Batch 36150 Loss 0.4769 Accuracy 0.2838
# Epoch 13 Batch 36200 Loss 0.4774 Accuracy 0.2841
# Epoch 13 Batch 36250 Loss 0.4781 Accuracy 0.2844
# Epoch 13 Batch 36300 Loss 0.4781 Accuracy 0.2843
# Epoch 13 Batch 36350 Loss 0.4779 Accuracy 0.2840
# Epoch 13 Batch 36400 Loss 0.4779 Accuracy 0.2840
# Epoch 13 Batch 36450 Loss 0.4788 Accuracy 0.2843
# Epoch 13 Batch 36500 Loss 0.4791 Accuracy 0.2843
# Epoch 13 Batch 36550 Loss 0.4791 Accuracy 0.2843
# Epoch 13 Batch 36600 Loss 0.4798 Accuracy 0.2845
# Epoch 13 Batch 36650 Loss 0.4799 Accuracy 0.2846
# Epoch 13 Batch 36700 Loss 0.4805 Accuracy 0.2848
# Epoch 13 Batch 36750 Loss 0.4803 Accuracy 0.2847
# Epoch 13 Batch 36800 Loss 0.4804 Accuracy 0.2845
# Epoch 13 Batch 36850 Loss 0.4802 Accuracy 0.2846
# Epoch 13 Batch 36900 Loss 0.4807 Accuracy 0.2847
# Epoch 13 Batch 36950 Loss 0.4808 Accuracy 0.2847
# Epoch 13 Batch 37000 Loss 0.4815 Accuracy 0.2848
# Epoch 13 Batch 37050 Loss 0.4815 Accuracy 0.2849
# Epoch 13 Batch 37100 Loss 0.4816 Accuracy 0.2848
# Epoch 13 Batch 37150 Loss 0.4815 Accuracy 0.2847
# Epoch 13 Batch 37200 Loss 0.4818 Accuracy 0.2847
# Epoch 13 Batch 37250 Loss 0.4823 Accuracy 0.2849
# Epoch 13 Batch 37300 Loss 0.4823 Accuracy 0.2849
# Epoch 13 Batch 37350 Loss 0.4825 Accuracy 0.2849
# Epoch 13 Batch 37400 Loss 0.4826 Accuracy 0.2849
# Epoch 13 Batch 37450 Loss 0.4826 Accuracy 0.2849
# Epoch 13 Batch 37500 Loss 0.4826 Accuracy 0.2849
# Epoch 13 Batch 37550 Loss 0.4825 Accuracy 0.2848
# Epoch 13 Batch 37600 Loss 0.4822 Accuracy 0.2848
# Epoch 13 Batch 37650 Loss 0.4822 Accuracy 0.2849
# Epoch 13 Batch 37700 Loss 0.4821 Accuracy 0.2849
# Epoch 13 Batch 37750 Loss 0.4822 Accuracy 0.2850
# Epoch 13 Batch 37800 Loss 0.4823 Accuracy 0.2850
# Epoch 13 Batch 37850 Loss 0.4827 Accuracy 0.2849
# Epoch 13 Batch 37900 Loss 0.4828 Accuracy 0.2849
# Epoch 13 Batch 37950 Loss 0.4828 Accuracy 0.2849
# Epoch 13 Batch 38000 Loss 0.4828 Accuracy 0.2849
# Epoch 13 Batch 38050 Loss 0.4828 Accuracy 0.2848
# Epoch 13 Loss 0.4828 Accuracy 0.2848
# Time taken for 1 epoch: 731.044909954071 secs
#
# Epoch 14 Batch 38100 Loss 0.4663 Accuracy 0.2802
# Epoch 14 Batch 38150 Loss 0.4694 Accuracy 0.2817
# Epoch 14 Batch 38200 Loss 0.4706 Accuracy 0.2836
# Epoch 14 Batch 38250 Loss 0.4701 Accuracy 0.2839
# Epoch 14 Batch 38300 Loss 0.4697 Accuracy 0.2820
# Epoch 14 Batch 38350 Loss 0.4681 Accuracy 0.2817
# Epoch 14 Batch 38400 Loss 0.4702 Accuracy 0.2820
# Epoch 14 Batch 38450 Loss 0.4706 Accuracy 0.2818
# Epoch 14 Batch 38500 Loss 0.4701 Accuracy 0.2823
# Epoch 14 Batch 38550 Loss 0.4706 Accuracy 0.2828
# Epoch 14 Batch 38600 Loss 0.4718 Accuracy 0.2829
# Epoch 14 Batch 38650 Loss 0.4718 Accuracy 0.2830
# Epoch 14 Batch 38700 Loss 0.4720 Accuracy 0.2835
# Epoch 14 Batch 38750 Loss 0.4728 Accuracy 0.2841
# Epoch 14 Batch 38800 Loss 0.4724 Accuracy 0.2838
# Epoch 14 Batch 38850 Loss 0.4730 Accuracy 0.2841
# Epoch 14 Batch 38900 Loss 0.4736 Accuracy 0.2843
# Epoch 14 Batch 38950 Loss 0.4746 Accuracy 0.2844
# Epoch 14 Batch 39000 Loss 0.4731 Accuracy 0.2842
# Epoch 14 Batch 39050 Loss 0.4736 Accuracy 0.2841
# Epoch 14 Batch 39100 Loss 0.4736 Accuracy 0.2843
# Epoch 14 Batch 39150 Loss 0.4743 Accuracy 0.2845
# Epoch 14 Batch 39200 Loss 0.4745 Accuracy 0.2847
# Epoch 14 Batch 39250 Loss 0.4749 Accuracy 0.2849
# Epoch 14 Batch 39300 Loss 0.4750 Accuracy 0.2852
# Epoch 14 Batch 39350 Loss 0.4742 Accuracy 0.2850
# Epoch 14 Batch 39400 Loss 0.4742 Accuracy 0.2852
# Epoch 14 Batch 39450 Loss 0.4745 Accuracy 0.2854
# Epoch 14 Batch 39500 Loss 0.4744 Accuracy 0.2854
# Epoch 14 Batch 39550 Loss 0.4746 Accuracy 0.2855
# Epoch 14 Batch 39600 Loss 0.4747 Accuracy 0.2856
# Epoch 14 Batch 39650 Loss 0.4744 Accuracy 0.2855
# Epoch 14 Batch 39700 Loss 0.4748 Accuracy 0.2856
# Epoch 14 Batch 39750 Loss 0.4750 Accuracy 0.2854
# Epoch 14 Batch 39800 Loss 0.4752 Accuracy 0.2856
# Epoch 14 Batch 39850 Loss 0.4753 Accuracy 0.2856
# Epoch 14 Batch 39900 Loss 0.4752 Accuracy 0.2856
# Epoch 14 Batch 39950 Loss 0.4750 Accuracy 0.2856
# Epoch 14 Batch 40000 Loss 0.4753 Accuracy 0.2857
# Epoch 14 Batch 40050 Loss 0.4754 Accuracy 0.2857
# Epoch 14 Batch 40100 Loss 0.4756 Accuracy 0.2858
# Epoch 14 Batch 40150 Loss 0.4758 Accuracy 0.2859
# Epoch 14 Batch 40200 Loss 0.4756 Accuracy 0.2858
# Epoch 14 Batch 40250 Loss 0.4760 Accuracy 0.2860
# Epoch 14 Batch 40300 Loss 0.4760 Accuracy 0.2860
# Epoch 14 Batch 40350 Loss 0.4760 Accuracy 0.2859
# Epoch 14 Batch 40400 Loss 0.4762 Accuracy 0.2858
# Epoch 14 Batch 40450 Loss 0.4763 Accuracy 0.2858
# Epoch 14 Batch 40500 Loss 0.4763 Accuracy 0.2858
# Epoch 14 Batch 40550 Loss 0.4765 Accuracy 0.2859
# Epoch 14 Batch 40600 Loss 0.4768 Accuracy 0.2859
# Epoch 14 Batch 40650 Loss 0.4767 Accuracy 0.2859
# Epoch 14 Batch 40700 Loss 0.4766 Accuracy 0.2859
# Epoch 14 Batch 40750 Loss 0.4768 Accuracy 0.2859
# Epoch 14 Batch 40800 Loss 0.4769 Accuracy 0.2859
# Epoch 14 Batch 40850 Loss 0.4769 Accuracy 0.2859
# Epoch 14 Batch 40900 Loss 0.4765 Accuracy 0.2859
# Epoch 14 Batch 40950 Loss 0.4764 Accuracy 0.2860
# Epoch 14 Loss 0.4765 Accuracy 0.2860
# Time taken for 1 epoch: 730.368837594986 secs
#
# Epoch 15 Batch 41000 Loss 0.4485 Accuracy 0.2886
# Epoch 15 Batch 41050 Loss 0.4591 Accuracy 0.2853
# Epoch 15 Batch 41100 Loss 0.4629 Accuracy 0.2859
# Epoch 15 Batch 41150 Loss 0.4650 Accuracy 0.2865
# Epoch 15 Batch 41200 Loss 0.4641 Accuracy 0.2854
# Epoch 15 Batch 41250 Loss 0.4643 Accuracy 0.2858
# Epoch 15 Batch 41300 Loss 0.4631 Accuracy 0.2859
# Epoch 15 Batch 41350 Loss 0.4627 Accuracy 0.2856
# Epoch 15 Batch 41400 Loss 0.4643 Accuracy 0.2860
# Epoch 15 Batch 41450 Loss 0.4640 Accuracy 0.2861
# Epoch 15 Batch 41500 Loss 0.4665 Accuracy 0.2864
# Epoch 15 Batch 41550 Loss 0.4664 Accuracy 0.2865
# Epoch 15 Batch 41600 Loss 0.4655 Accuracy 0.2864
# Epoch 15 Batch 41650 Loss 0.4669 Accuracy 0.2866
# Epoch 15 Batch 41700 Loss 0.4657 Accuracy 0.2860
# Epoch 15 Batch 41750 Loss 0.4653 Accuracy 0.2861
# Epoch 15 Batch 41800 Loss 0.4647 Accuracy 0.2861
# Epoch 15 Batch 41850 Loss 0.4652 Accuracy 0.2861
# Epoch 15 Batch 41900 Loss 0.4661 Accuracy 0.2863
# Epoch 15 Batch 41950 Loss 0.4662 Accuracy 0.2863
# Epoch 15 Batch 42000 Loss 0.4666 Accuracy 0.2863
# Epoch 15 Batch 42050 Loss 0.4667 Accuracy 0.2862
# Epoch 15 Batch 42100 Loss 0.4668 Accuracy 0.2864
# Epoch 15 Batch 42150 Loss 0.4664 Accuracy 0.2863
# Epoch 15 Batch 42200 Loss 0.4665 Accuracy 0.2863
# Epoch 15 Batch 42250 Loss 0.4670 Accuracy 0.2864
# Epoch 15 Batch 42300 Loss 0.4675 Accuracy 0.2868
# Epoch 15 Batch 42350 Loss 0.4673 Accuracy 0.2868
# Epoch 15 Batch 42400 Loss 0.4670 Accuracy 0.2867
# Epoch 15 Batch 42450 Loss 0.4670 Accuracy 0.2866
# Epoch 15 Batch 42500 Loss 0.4673 Accuracy 0.2868
# Epoch 15 Batch 42550 Loss 0.4670 Accuracy 0.2864
# Epoch 15 Batch 42600 Loss 0.4672 Accuracy 0.2864
# Epoch 15 Batch 42650 Loss 0.4672 Accuracy 0.2864
# Epoch 15 Batch 42700 Loss 0.4671 Accuracy 0.2863
# Epoch 15 Batch 42750 Loss 0.4678 Accuracy 0.2864
# Epoch 15 Batch 42800 Loss 0.4677 Accuracy 0.2864
# Epoch 15 Batch 42850 Loss 0.4679 Accuracy 0.2864
# Epoch 15 Batch 42900 Loss 0.4682 Accuracy 0.2864
# Epoch 15 Batch 42950 Loss 0.4683 Accuracy 0.2865
# Epoch 15 Batch 43000 Loss 0.4683 Accuracy 0.2867
# Epoch 15 Batch 43050 Loss 0.4686 Accuracy 0.2866
# Epoch 15 Batch 43100 Loss 0.4687 Accuracy 0.2866
# Epoch 15 Batch 43150 Loss 0.4691 Accuracy 0.2867
# Epoch 15 Batch 43200 Loss 0.4693 Accuracy 0.2867
# Epoch 15 Batch 43250 Loss 0.4697 Accuracy 0.2867
# Epoch 15 Batch 43300 Loss 0.4696 Accuracy 0.2867
# Epoch 15 Batch 43350 Loss 0.4694 Accuracy 0.2867
# Epoch 15 Batch 43400 Loss 0.4697 Accuracy 0.2868
# Epoch 15 Batch 43450 Loss 0.4698 Accuracy 0.2868
# Epoch 15 Batch 43500 Loss 0.4701 Accuracy 0.2868
# Epoch 15 Batch 43550 Loss 0.4702 Accuracy 0.2869
# Epoch 15 Batch 43600 Loss 0.4702 Accuracy 0.2870
# Epoch 15 Batch 43650 Loss 0.4700 Accuracy 0.2870
# Epoch 15 Batch 43700 Loss 0.4702 Accuracy 0.2870
# Epoch 15 Batch 43750 Loss 0.4703 Accuracy 0.2870
# Epoch 15 Batch 43800 Loss 0.4703 Accuracy 0.2870
# Epoch 15 Batch 43850 Loss 0.4703 Accuracy 0.2870
# Epoch 15 Batch 43900 Loss 0.4706 Accuracy 0.2871
# Saving checkpoint for epoch 15 at /content/drive/MyDrive/Colab Notebooks/Transformer/checkpoints/gpu/model
# Save checkpoints
# Epoch 15 Loss 0.4706 Accuracy 0.2871
# Time taken for 1 epoch: 731.1658022403717 secs
#
# Epoch 16 Batch 43950 Loss 0.4633 Accuracy 0.2900
# Epoch 16 Batch 44000 Loss 0.4583 Accuracy 0.2899
# Epoch 16 Batch 44050 Loss 0.4644 Accuracy 0.2884
# Epoch 16 Batch 44100 Loss 0.4634 Accuracy 0.2879
# Epoch 16 Batch 44150 Loss 0.4608 Accuracy 0.2871
# Epoch 16 Batch 44200 Loss 0.4616 Accuracy 0.2865
# Epoch 16 Batch 44250 Loss 0.4613 Accuracy 0.2863
# Epoch 16 Batch 44300 Loss 0.4605 Accuracy 0.2866
# Epoch 16 Batch 44350 Loss 0.4595 Accuracy 0.2867
# Epoch 16 Batch 44400 Loss 0.4609 Accuracy 0.2868
# Epoch 16 Batch 44450 Loss 0.4608 Accuracy 0.2875
# Epoch 16 Batch 44500 Loss 0.4624 Accuracy 0.2881
# Epoch 16 Batch 44550 Loss 0.4623 Accuracy 0.2881
# Epoch 16 Batch 44600 Loss 0.4625 Accuracy 0.2882
# Epoch 16 Batch 44650 Loss 0.4619 Accuracy 0.2879
# Epoch 16 Batch 44700 Loss 0.4619 Accuracy 0.2881
# Epoch 16 Batch 44750 Loss 0.4624 Accuracy 0.2880
# Epoch 16 Batch 44800 Loss 0.4629 Accuracy 0.2880
# Epoch 16 Batch 44850 Loss 0.4631 Accuracy 0.2885
# Epoch 16 Batch 44900 Loss 0.4626 Accuracy 0.2882
# Epoch 16 Batch 44950 Loss 0.4628 Accuracy 0.2885
# Epoch 16 Batch 45000 Loss 0.4633 Accuracy 0.2883
# Epoch 16 Batch 45050 Loss 0.4631 Accuracy 0.2882
# Epoch 16 Batch 45100 Loss 0.4635 Accuracy 0.2882
# Epoch 16 Batch 45150 Loss 0.4641 Accuracy 0.2882
# Epoch 16 Batch 45200 Loss 0.4640 Accuracy 0.2882
# Epoch 16 Batch 45250 Loss 0.4638 Accuracy 0.2882
# Epoch 16 Batch 45300 Loss 0.4638 Accuracy 0.2883
# Epoch 16 Batch 45350 Loss 0.4634 Accuracy 0.2883
# Epoch 16 Batch 45400 Loss 0.4635 Accuracy 0.2882
# Epoch 16 Batch 45450 Loss 0.4637 Accuracy 0.2883
# Epoch 16 Batch 45500 Loss 0.4639 Accuracy 0.2881
# Epoch 16 Batch 45550 Loss 0.4642 Accuracy 0.2882
# Epoch 16 Batch 45600 Loss 0.4647 Accuracy 0.2885
# Epoch 16 Batch 45650 Loss 0.4646 Accuracy 0.2884
# Epoch 16 Batch 45700 Loss 0.4645 Accuracy 0.2883
# Epoch 16 Batch 45750 Loss 0.4646 Accuracy 0.2883
# Epoch 16 Batch 45800 Loss 0.4645 Accuracy 0.2882
# Epoch 16 Batch 45850 Loss 0.4642 Accuracy 0.2881
# Epoch 16 Batch 45900 Loss 0.4646 Accuracy 0.2882
# Epoch 16 Batch 45950 Loss 0.4647 Accuracy 0.2884
# Epoch 16 Batch 46000 Loss 0.4646 Accuracy 0.2883
# Epoch 16 Batch 46050 Loss 0.4647 Accuracy 0.2882
# Epoch 16 Batch 46100 Loss 0.4648 Accuracy 0.2882
# Epoch 16 Batch 46150 Loss 0.4647 Accuracy 0.2881
# Epoch 16 Batch 46200 Loss 0.4650 Accuracy 0.2882
# Epoch 16 Batch 46250 Loss 0.4650 Accuracy 0.2883
# Epoch 16 Batch 46300 Loss 0.4648 Accuracy 0.2882
# Epoch 16 Batch 46350 Loss 0.4646 Accuracy 0.2881
# Epoch 16 Batch 46400 Loss 0.4647 Accuracy 0.2881
# Epoch 16 Batch 46450 Loss 0.4651 Accuracy 0.2882
# Epoch 16 Batch 46500 Loss 0.4650 Accuracy 0.2882
# Epoch 16 Batch 46550 Loss 0.4651 Accuracy 0.2882
# Epoch 16 Batch 46600 Loss 0.4652 Accuracy 0.2882
# Epoch 16 Batch 46650 Loss 0.4651 Accuracy 0.2881
# Epoch 16 Batch 46700 Loss 0.4651 Accuracy 0.2880
# Epoch 16 Batch 46750 Loss 0.4655 Accuracy 0.2881
# Epoch 16 Batch 46800 Loss 0.4655 Accuracy 0.2881
# Epoch 16 Loss 0.4655 Accuracy 0.2881
# Time taken for 1 epoch: 730.7250616550446 secs
#
# Epoch 17 Batch 46850 Loss 0.4529 Accuracy 0.2908
# Epoch 17 Batch 46900 Loss 0.4508 Accuracy 0.2875
# Epoch 17 Batch 46950 Loss 0.4514 Accuracy 0.2873
# Epoch 17 Batch 47000 Loss 0.4504 Accuracy 0.2853
# Epoch 17 Batch 47050 Loss 0.4542 Accuracy 0.2854
# Epoch 17 Batch 47100 Loss 0.4539 Accuracy 0.2868
# Epoch 17 Batch 47150 Loss 0.4541 Accuracy 0.2858
# Epoch 17 Batch 47200 Loss 0.4535 Accuracy 0.2856
# Epoch 17 Batch 47250 Loss 0.4533 Accuracy 0.2861
# Epoch 17 Batch 47300 Loss 0.4546 Accuracy 0.2865
# Epoch 17 Batch 47350 Loss 0.4556 Accuracy 0.2868
# Epoch 17 Batch 47400 Loss 0.4561 Accuracy 0.2869
# Epoch 17 Batch 47450 Loss 0.4563 Accuracy 0.2873
# Epoch 17 Batch 47500 Loss 0.4568 Accuracy 0.2874
# Epoch 17 Batch 47550 Loss 0.4567 Accuracy 0.2878
# Epoch 17 Batch 47600 Loss 0.4564 Accuracy 0.2877
# Epoch 17 Batch 47650 Loss 0.4570 Accuracy 0.2879
# Epoch 17 Batch 47700 Loss 0.4567 Accuracy 0.2884
# Epoch 17 Batch 47750 Loss 0.4575 Accuracy 0.2883
# Epoch 17 Batch 47800 Loss 0.4573 Accuracy 0.2882
# Epoch 17 Batch 47850 Loss 0.4568 Accuracy 0.2883
# Epoch 17 Batch 47900 Loss 0.4584 Accuracy 0.2885
# ...
# Epoch 25 Batch 72300 Loss 0.4313 Accuracy 0.2940
# Epoch 25 Batch 72350 Loss 0.4309 Accuracy 0.2940
# Epoch 25 Batch 72400 Loss 0.4309 Accuracy 0.2939
# Epoch 25 Batch 72450 Loss 0.4311 Accuracy 0.2940
# Epoch 25 Batch 72500 Loss 0.4310 Accuracy 0.2942
# Epoch 25 Batch 72550 Loss 0.4311 Accuracy 0.2942
# Epoch 25 Batch 72600 Loss 0.4312 Accuracy 0.2942
# Epoch 25 Batch 72650 Loss 0.4314 Accuracy 0.2942
# Epoch 25 Batch 72700 Loss 0.4316 Accuracy 0.2943
# Epoch 25 Batch 72750 Loss 0.4315 Accuracy 0.2942
# Epoch 25 Batch 72800 Loss 0.4315 Accuracy 0.2942
# Epoch 25 Batch 72850 Loss 0.4317 Accuracy 0.2943
# Epoch 25 Batch 72900 Loss 0.4320 Accuracy 0.2941
# Epoch 25 Batch 72950 Loss 0.4321 Accuracy 0.2941
# Epoch 25 Batch 73000 Loss 0.4322 Accuracy 0.2941
# Epoch 25 Batch 73050 Loss 0.4324 Accuracy 0.2942
# Epoch 25 Batch 73100 Loss 0.4326 Accuracy 0.2941
# Epoch 25 Batch 73150 Loss 0.4327 Accuracy 0.2941
# Saving checkpoint for epoch 25 at /content/drive/MyDrive/Colab Notebooks/Transformer/checkpoints/gpu/model
# Save checkpoints
# Epoch 25 Loss 0.4328 Accuracy 0.2941
# Time taken for 1 epoch: 726.1847529411316 secs
#
# Epoch 26 Batch 73200 Loss 0.4048 Accuracy 0.2934
# Epoch 26 Batch 73250 Loss 0.4152 Accuracy 0.2966
# Epoch 26 Batch 73300 Loss 0.4161 Accuracy 0.2978
# Epoch 26 Batch 73350 Loss 0.4188 Accuracy 0.2969
# Epoch 26 Batch 73400 Loss 0.4230 Accuracy 0.2968
# Epoch 26 Batch 73450 Loss 0.4211 Accuracy 0.2939
# Epoch 26 Batch 73500 Loss 0.4201 Accuracy 0.2932
# Epoch 26 Batch 73550 Loss 0.4200 Accuracy 0.2933
# Epoch 26 Batch 73600 Loss 0.4208 Accuracy 0.2936
# Epoch 26 Batch 73650 Loss 0.4222 Accuracy 0.2936
# Epoch 26 Batch 73700 Loss 0.4215 Accuracy 0.2936
# Epoch 26 Batch 73750 Loss 0.4232 Accuracy 0.2931
# Epoch 26 Batch 73800 Loss 0.4230 Accuracy 0.2930
# Epoch 26 Batch 73850 Loss 0.4233 Accuracy 0.2934
# Epoch 26 Batch 73900 Loss 0.4236 Accuracy 0.2933
# Epoch 26 Batch 73950 Loss 0.4235 Accuracy 0.2935
# Epoch 26 Batch 74000 Loss 0.4237 Accuracy 0.2936
# Epoch 26 Batch 74050 Loss 0.4244 Accuracy 0.2938
# Epoch 26 Batch 74100 Loss 0.4246 Accuracy 0.2936
# Epoch 26 Batch 74150 Loss 0.4248 Accuracy 0.2936
# Epoch 26 Batch 74200 Loss 0.4249 Accuracy 0.2936
# Epoch 26 Batch 74250 Loss 0.4247 Accuracy 0.2935
# Epoch 26 Batch 74300 Loss 0.4255 Accuracy 0.2937
# Epoch 26 Batch 74350 Loss 0.4259 Accuracy 0.2938
# Epoch 26 Batch 74400 Loss 0.4267 Accuracy 0.2940
# Epoch 26 Batch 74450 Loss 0.4271 Accuracy 0.2943
# Epoch 26 Batch 74500 Loss 0.4277 Accuracy 0.2942
# Epoch 26 Batch 74550 Loss 0.4281 Accuracy 0.2944
# Epoch 26 Batch 74600 Loss 0.4279 Accuracy 0.2943
# Epoch 26 Batch 74650 Loss 0.4279 Accuracy 0.2940
# Epoch 26 Batch 74700 Loss 0.4283 Accuracy 0.2940
# Epoch 26 Batch 74750 Loss 0.4282 Accuracy 0.2941
# Epoch 26 Batch 74800 Loss 0.4281 Accuracy 0.2939
# Epoch 26 Batch 74850 Loss 0.4282 Accuracy 0.2939
# Epoch 26 Batch 74900 Loss 0.4286 Accuracy 0.2940
# Epoch 26 Batch 74950 Loss 0.4290 Accuracy 0.2940
# Epoch 26 Batch 75000 Loss 0.4289 Accuracy 0.2942
# Epoch 26 Batch 75050 Loss 0.4291 Accuracy 0.2943
# Epoch 26 Batch 75100 Loss 0.4289 Accuracy 0.2943
# Epoch 26 Batch 75150 Loss 0.4290 Accuracy 0.2944
# Epoch 26 Batch 75200 Loss 0.4292 Accuracy 0.2945
# Epoch 26 Batch 75250 Loss 0.4293 Accuracy 0.2946
# Epoch 26 Batch 75300 Loss 0.4291 Accuracy 0.2945
# Epoch 26 Batch 75350 Loss 0.4292 Accuracy 0.2945
# Epoch 26 Batch 75400 Loss 0.4289 Accuracy 0.2944
# Epoch 26 Batch 75450 Loss 0.4291 Accuracy 0.2945
# Epoch 26 Batch 75500 Loss 0.4292 Accuracy 0.2945
# Epoch 26 Batch 75550 Loss 0.4294 Accuracy 0.2946
# Epoch 26 Batch 75600 Loss 0.4295 Accuracy 0.2947
# Epoch 26 Batch 75650 Loss 0.4295 Accuracy 0.2948
# Epoch 26 Batch 75700 Loss 0.4300 Accuracy 0.2948
# Epoch 26 Batch 75750 Loss 0.4300 Accuracy 0.2948
# Epoch 26 Batch 75800 Loss 0.4300 Accuracy 0.2947
# Epoch 26 Batch 75850 Loss 0.4301 Accuracy 0.2947
# Epoch 26 Batch 75900 Loss 0.4301 Accuracy 0.2946
# Epoch 26 Batch 75950 Loss 0.4301 Accuracy 0.2945
# Epoch 26 Batch 76000 Loss 0.4302 Accuracy 0.2944
# Epoch 26 Batch 76050 Loss 0.4300 Accuracy 0.2944
# Epoch 26 Batch 76100 Loss 0.4300 Accuracy 0.2945
# Epoch 26 Loss 0.4301 Accuracy 0.2945
# Time taken for 1 epoch: 725.2854919433594 secs
#
# Epoch 27 Batch 76150 Loss 0.4165 Accuracy 0.2979
# Epoch 27 Batch 76200 Loss 0.4162 Accuracy 0.2954
# Epoch 27 Batch 76250 Loss 0.4182 Accuracy 0.2936
# Epoch 27 Batch 76300 Loss 0.4217 Accuracy 0.2932
# Epoch 27 Batch 76350 Loss 0.4202 Accuracy 0.2931
# Epoch 27 Batch 76400 Loss 0.4208 Accuracy 0.2928
# Epoch 27 Batch 76450 Loss 0.4204 Accuracy 0.2924
# Epoch 27 Batch 76500 Loss 0.4214 Accuracy 0.2927
# Epoch 27 Batch 76550 Loss 0.4223 Accuracy 0.2935
# Epoch 27 Batch 76600 Loss 0.4228 Accuracy 0.2937
# Epoch 27 Batch 76650 Loss 0.4232 Accuracy 0.2941
# Epoch 27 Batch 76700 Loss 0.4237 Accuracy 0.2945
# Epoch 27 Batch 76750 Loss 0.4235 Accuracy 0.2949
# Epoch 27 Batch 76800 Loss 0.4242 Accuracy 0.2953
# Epoch 27 Batch 76850 Loss 0.4243 Accuracy 0.2952
# Epoch 27 Batch 76900 Loss 0.4243 Accuracy 0.2950
# Epoch 27 Batch 76950 Loss 0.4248 Accuracy 0.2952
# Epoch 27 Batch 77000 Loss 0.4248 Accuracy 0.2949
# Epoch 27 Batch 77050 Loss 0.4252 Accuracy 0.2949
# Epoch 27 Batch 77100 Loss 0.4250 Accuracy 0.2950
# Epoch 27 Batch 77150 Loss 0.4251 Accuracy 0.2952
# Epoch 27 Batch 77200 Loss 0.4258 Accuracy 0.2954
# Epoch 27 Batch 77250 Loss 0.4257 Accuracy 0.2952
# Epoch 27 Batch 77300 Loss 0.4252 Accuracy 0.2952
# Epoch 27 Batch 77350 Loss 0.4255 Accuracy 0.2952
# Epoch 27 Batch 77400 Loss 0.4257 Accuracy 0.2952
# Epoch 27 Batch 77450 Loss 0.4257 Accuracy 0.2952
# Epoch 27 Batch 77500 Loss 0.4259 Accuracy 0.2952
# Epoch 27 Batch 77550 Loss 0.4263 Accuracy 0.2951
# Epoch 27 Batch 77600 Loss 0.4261 Accuracy 0.2952
# Epoch 27 Batch 77650 Loss 0.4264 Accuracy 0.2952
# Epoch 27 Batch 77700 Loss 0.4265 Accuracy 0.2952
# Epoch 27 Batch 77750 Loss 0.4263 Accuracy 0.2950
# Epoch 27 Batch 77800 Loss 0.4265 Accuracy 0.2949
# Epoch 27 Batch 77850 Loss 0.4267 Accuracy 0.2950
# Epoch 27 Batch 77900 Loss 0.4262 Accuracy 0.2949
# Epoch 27 Batch 77950 Loss 0.4263 Accuracy 0.2950
# Epoch 27 Batch 78000 Loss 0.4262 Accuracy 0.2948
# Epoch 27 Batch 78050 Loss 0.4263 Accuracy 0.2949
# Epoch 27 Batch 78100 Loss 0.4263 Accuracy 0.2949
# Epoch 27 Batch 78150 Loss 0.4263 Accuracy 0.2948
# Epoch 27 Batch 78200 Loss 0.4265 Accuracy 0.2950
# Epoch 27 Batch 78250 Loss 0.4266 Accuracy 0.2949
# Epoch 27 Batch 78300 Loss 0.4268 Accuracy 0.2950
# Epoch 27 Batch 78350 Loss 0.4268 Accuracy 0.2951
# Epoch 27 Batch 78400 Loss 0.4267 Accuracy 0.2949
# Epoch 27 Batch 78450 Loss 0.4268 Accuracy 0.2949
# Epoch 27 Batch 78500 Loss 0.4270 Accuracy 0.2949
# Epoch 27 Batch 78550 Loss 0.4270 Accuracy 0.2949
# Epoch 27 Batch 78600 Loss 0.4268 Accuracy 0.2949
# Epoch 27 Batch 78650 Loss 0.4268 Accuracy 0.2949
# Epoch 27 Batch 78700 Loss 0.4268 Accuracy 0.2949
# Epoch 27 Batch 78750 Loss 0.4266 Accuracy 0.2949
# Epoch 27 Batch 78800 Loss 0.4268 Accuracy 0.2949
# Epoch 27 Batch 78850 Loss 0.4270 Accuracy 0.2948
# Epoch 27 Batch 78900 Loss 0.4273 Accuracy 0.2949
# Epoch 27 Batch 78950 Loss 0.4274 Accuracy 0.2949
# Epoch 27 Batch 79000 Loss 0.4276 Accuracy 0.2950
# Epoch 27 Loss 0.4277 Accuracy 0.2950
# Time taken for 1 epoch: 723.6234385967255 secs
#
# Epoch 28 Batch 79050 Loss 0.4294 Accuracy 0.2961
# Epoch 28 Batch 79100 Loss 0.4105 Accuracy 0.2933
# Epoch 28 Batch 79150 Loss 0.4171 Accuracy 0.2929
# Epoch 28 Batch 79200 Loss 0.4179 Accuracy 0.2917
# Epoch 28 Batch 79250 Loss 0.4177 Accuracy 0.2920
# Epoch 28 Batch 79300 Loss 0.4176 Accuracy 0.2933
# Epoch 28 Batch 79350 Loss 0.4182 Accuracy 0.2929
# Epoch 28 Batch 79400 Loss 0.4183 Accuracy 0.2932
# Epoch 28 Batch 79450 Loss 0.4188 Accuracy 0.2937
# Epoch 28 Batch 79500 Loss 0.4199 Accuracy 0.2941
# Epoch 28 Batch 79550 Loss 0.4197 Accuracy 0.2938
# Epoch 28 Batch 79600 Loss 0.4197 Accuracy 0.2940
# Epoch 28 Batch 79650 Loss 0.4195 Accuracy 0.2946
# Epoch 28 Batch 79700 Loss 0.4190 Accuracy 0.2946
# Epoch 28 Batch 79750 Loss 0.4195 Accuracy 0.2944
# Epoch 28 Batch 79800 Loss 0.4188 Accuracy 0.2941
# Epoch 28 Batch 79850 Loss 0.4193 Accuracy 0.2943
# Epoch 28 Batch 79900 Loss 0.4213 Accuracy 0.2944
# Epoch 28 Batch 79950 Loss 0.4211 Accuracy 0.2946
# Epoch 28 Batch 80000 Loss 0.4210 Accuracy 0.2948
# Epoch 28 Batch 80050 Loss 0.4213 Accuracy 0.2949
# Epoch 28 Batch 80100 Loss 0.4218 Accuracy 0.2948
# Epoch 28 Batch 80150 Loss 0.4215 Accuracy 0.2948
# Epoch 28 Batch 80200 Loss 0.4217 Accuracy 0.2949
# Epoch 28 Batch 80250 Loss 0.4218 Accuracy 0.2949
# Epoch 28 Batch 80300 Loss 0.4219 Accuracy 0.2951
# Epoch 28 Batch 80350 Loss 0.4216 Accuracy 0.2951
# Epoch 28 Batch 80400 Loss 0.4218 Accuracy 0.2951
# Epoch 28 Batch 80450 Loss 0.4219 Accuracy 0.2953
# Epoch 28 Batch 80500 Loss 0.4219 Accuracy 0.2953
# Epoch 28 Batch 80550 Loss 0.4226 Accuracy 0.2955
# Epoch 28 Batch 80600 Loss 0.4224 Accuracy 0.2954
# Epoch 28 Batch 80650 Loss 0.4224 Accuracy 0.2953
# Epoch 28 Batch 80700 Loss 0.4227 Accuracy 0.2954
# Epoch 28 Batch 80750 Loss 0.4227 Accuracy 0.2953
# Epoch 28 Batch 80800 Loss 0.4228 Accuracy 0.2952
# Epoch 28 Batch 80850 Loss 0.4227 Accuracy 0.2952
# Epoch 28 Batch 80900 Loss 0.4227 Accuracy 0.2951
# Epoch 28 Batch 80950 Loss 0.4229 Accuracy 0.2950
# Epoch 28 Batch 81000 Loss 0.4228 Accuracy 0.2952
# Epoch 28 Batch 81050 Loss 0.4233 Accuracy 0.2953
# Epoch 28 Batch 81100 Loss 0.4235 Accuracy 0.2953
# Epoch 28 Batch 81150 Loss 0.4236 Accuracy 0.2955
# Epoch 28 Batch 81200 Loss 0.4235 Accuracy 0.2955
# Epoch 28 Batch 81250 Loss 0.4237 Accuracy 0.2955
# Epoch 28 Batch 81300 Loss 0.4238 Accuracy 0.2955
# Epoch 28 Batch 81350 Loss 0.4241 Accuracy 0.2956
# Epoch 28 Batch 81400 Loss 0.4242 Accuracy 0.2955
# Epoch 28 Batch 81450 Loss 0.4245 Accuracy 0.2955
# Epoch 28 Batch 81500 Loss 0.4245 Accuracy 0.2956
# Epoch 28 Batch 81550 Loss 0.4247 Accuracy 0.2957
# Epoch 28 Batch 81600 Loss 0.4247 Accuracy 0.2958
# Epoch 28 Batch 81650 Loss 0.4248 Accuracy 0.2957
# Epoch 28 Batch 81700 Loss 0.4248 Accuracy 0.2958
# Epoch 28 Batch 81750 Loss 0.4250 Accuracy 0.2957
# Epoch 28 Batch 81800 Loss 0.4247 Accuracy 0.2957
# Epoch 28 Batch 81850 Loss 0.4246 Accuracy 0.2956
# Epoch 28 Batch 81900 Loss 0.4249 Accuracy 0.2956
# Epoch 28 Batch 81950 Loss 0.4248 Accuracy 0.2955
# Epoch 28 Loss 0.4248 Accuracy 0.2955
# Time taken for 1 epoch: 723.4928302764893 secs
#
# Epoch 29 Batch 82000 Loss 0.4198 Accuracy 0.2939
# Epoch 29 Batch 82050 Loss 0.4193 Accuracy 0.2945
# Epoch 29 Batch 82100 Loss 0.4180 Accuracy 0.2951
# Epoch 29 Batch 82150 Loss 0.4208 Accuracy 0.2961
# Epoch 29 Batch 82200 Loss 0.4187 Accuracy 0.2954
# Epoch 29 Batch 82250 Loss 0.4199 Accuracy 0.2948
# Epoch 29 Batch 82300 Loss 0.4196 Accuracy 0.2941
# Epoch 29 Batch 82350 Loss 0.4202 Accuracy 0.2944
# Epoch 29 Batch 82400 Loss 0.4196 Accuracy 0.2944
# Epoch 29 Batch 82450 Loss 0.4184 Accuracy 0.2940
# Epoch 29 Batch 82500 Loss 0.4184 Accuracy 0.2941
# Epoch 29 Batch 82550 Loss 0.4179 Accuracy 0.2941
# Epoch 29 Batch 82600 Loss 0.4180 Accuracy 0.2941
# Epoch 29 Batch 82650 Loss 0.4181 Accuracy 0.2939
# Epoch 29 Batch 82700 Loss 0.4188 Accuracy 0.2942
# Epoch 29 Batch 82750 Loss 0.4192 Accuracy 0.2941
# Epoch 29 Batch 82800 Loss 0.4196 Accuracy 0.2944
# Epoch 29 Batch 82850 Loss 0.4197 Accuracy 0.2946
# Epoch 29 Batch 82900 Loss 0.4198 Accuracy 0.2947
# Epoch 29 Batch 82950 Loss 0.4203 Accuracy 0.2951
# Epoch 29 Batch 83000 Loss 0.4202 Accuracy 0.2952
# Epoch 29 Batch 83050 Loss 0.4199 Accuracy 0.2951
# Epoch 29 Batch 83100 Loss 0.4203 Accuracy 0.2952
# Epoch 29 Batch 83150 Loss 0.4205 Accuracy 0.2951
# Epoch 29 Batch 83200 Loss 0.4203 Accuracy 0.2953
# Epoch 29 Batch 83250 Loss 0.4207 Accuracy 0.2955
# Epoch 29 Batch 83300 Loss 0.4203 Accuracy 0.2955
# Epoch 29 Batch 83350 Loss 0.4203 Accuracy 0.2955
# Epoch 29 Batch 83400 Loss 0.4206 Accuracy 0.2956
# Epoch 29 Batch 83450 Loss 0.4208 Accuracy 0.2958
# Epoch 29 Batch 83500 Loss 0.4209 Accuracy 0.2958
# Epoch 29 Batch 83550 Loss 0.4207 Accuracy 0.2959
# Epoch 29 Batch 83600 Loss 0.4212 Accuracy 0.2959
# Epoch 29 Batch 83650 Loss 0.4210 Accuracy 0.2958
# Epoch 29 Batch 83700 Loss 0.4208 Accuracy 0.2957
# Epoch 29 Batch 83750 Loss 0.4211 Accuracy 0.2957
# Epoch 29 Batch 83800 Loss 0.4214 Accuracy 0.2956
# Epoch 29 Batch 83850 Loss 0.4212 Accuracy 0.2957
# Epoch 29 Batch 83900 Loss 0.4214 Accuracy 0.2958
# Epoch 29 Batch 83950 Loss 0.4216 Accuracy 0.2959
# Epoch 29 Batch 84000 Loss 0.4219 Accuracy 0.2959
# Epoch 29 Batch 84050 Loss 0.4218 Accuracy 0.2957
# Epoch 29 Batch 84100 Loss 0.4217 Accuracy 0.2956
# Epoch 29 Batch 84150 Loss 0.4222 Accuracy 0.2958
# Epoch 29 Batch 84200 Loss 0.4224 Accuracy 0.2959
# Epoch 29 Batch 84250 Loss 0.4227 Accuracy 0.2959
# Epoch 29 Batch 84300 Loss 0.4226 Accuracy 0.2958
# Epoch 29 Batch 84350 Loss 0.4230 Accuracy 0.2959
# Epoch 29 Batch 84400 Loss 0.4227 Accuracy 0.2958
# Epoch 29 Batch 84450 Loss 0.4229 Accuracy 0.2959
# Epoch 29 Batch 84500 Loss 0.4228 Accuracy 0.2959
# Epoch 29 Batch 84550 Loss 0.4229 Accuracy 0.2959
# Epoch 29 Batch 84600 Loss 0.4228 Accuracy 0.2959
# Epoch 29 Batch 84650 Loss 0.4231 Accuracy 0.2959
# Epoch 29 Batch 84700 Loss 0.4232 Accuracy 0.2959
# Epoch 29 Batch 84750 Loss 0.4231 Accuracy 0.2958
# Epoch 29 Batch 84800 Loss 0.4233 Accuracy 0.2959
# Epoch 29 Batch 84850 Loss 0.4235 Accuracy 0.2959
# Epoch 29 Loss 0.4235 Accuracy 0.2959
# Time taken for 1 epoch: 726.6185269355774 secs
#
# Epoch 30 Batch 84900 Loss 0.4054 Accuracy 0.2993
# Epoch 30 Batch 84950 Loss 0.4197 Accuracy 0.2969
# Epoch 30 Batch 85000 Loss 0.4097 Accuracy 0.2945
# Epoch 30 Batch 85050 Loss 0.4090 Accuracy 0.2951
# Epoch 30 Batch 85100 Loss 0.4114 Accuracy 0.2950
# Epoch 30 Batch 85150 Loss 0.4116 Accuracy 0.2952
# Epoch 30 Batch 85200 Loss 0.4110 Accuracy 0.2943
# Epoch 30 Batch 85250 Loss 0.4111 Accuracy 0.2938
# Epoch 30 Batch 85300 Loss 0.4127 Accuracy 0.2937
# Epoch 30 Batch 85350 Loss 0.4133 Accuracy 0.2945
# Epoch 30 Batch 85400 Loss 0.4132 Accuracy 0.2948
# Epoch 30 Batch 85450 Loss 0.4139 Accuracy 0.2948
# Epoch 30 Batch 85500 Loss 0.4154 Accuracy 0.2950
# Epoch 30 Batch 85550 Loss 0.4157 Accuracy 0.2954
# Epoch 30 Batch 85600 Loss 0.4144 Accuracy 0.2954
# Epoch 30 Batch 85650 Loss 0.4145 Accuracy 0.2952
# Epoch 30 Batch 85700 Loss 0.4153 Accuracy 0.2951
# Epoch 30 Batch 85750 Loss 0.4163 Accuracy 0.2953
# Epoch 30 Batch 85800 Loss 0.4167 Accuracy 0.2953
# Epoch 30 Batch 85850 Loss 0.4172 Accuracy 0.2953
# Epoch 30 Batch 85900 Loss 0.4175 Accuracy 0.2955
# Epoch 30 Batch 85950 Loss 0.4176 Accuracy 0.2958
# Epoch 30 Batch 86000 Loss 0.4181 Accuracy 0.2960
# Epoch 30 Batch 86050 Loss 0.4181 Accuracy 0.2960
# Epoch 30 Batch 86100 Loss 0.4177 Accuracy 0.2962
# Epoch 30 Batch 86150 Loss 0.4180 Accuracy 0.2963
# Epoch 30 Batch 86200 Loss 0.4183 Accuracy 0.2961
# Epoch 30 Batch 86250 Loss 0.4183 Accuracy 0.2961
# Epoch 30 Batch 86300 Loss 0.4181 Accuracy 0.2961
# Epoch 30 Batch 86350 Loss 0.4183 Accuracy 0.2960
# Epoch 30 Batch 86400 Loss 0.4184 Accuracy 0.2959
# Epoch 30 Batch 86450 Loss 0.4185 Accuracy 0.2961
# Epoch 30 Batch 86500 Loss 0.4186 Accuracy 0.2961
# Epoch 30 Batch 86550 Loss 0.4187 Accuracy 0.2961
# Epoch 30 Batch 86600 Loss 0.4191 Accuracy 0.2961
# Epoch 30 Batch 86650 Loss 0.4198 Accuracy 0.2962
# Epoch 30 Batch 86700 Loss 0.4197 Accuracy 0.2962
# Epoch 30 Batch 86750 Loss 0.4194 Accuracy 0.2962
# Epoch 30 Batch 86800 Loss 0.4194 Accuracy 0.2961
# Epoch 30 Batch 86850 Loss 0.4197 Accuracy 0.2961
# Epoch 30 Batch 86900 Loss 0.4196 Accuracy 0.2962
# Epoch 30 Batch 86950 Loss 0.4197 Accuracy 0.2963
# Epoch 30 Batch 87000 Loss 0.4197 Accuracy 0.2963
# Epoch 30 Batch 87050 Loss 0.4199 Accuracy 0.2962
# Epoch 30 Batch 87100 Loss 0.4197 Accuracy 0.2962
# Epoch 30 Batch 87150 Loss 0.4197 Accuracy 0.2962
# Epoch 30 Batch 87200 Loss 0.4200 Accuracy 0.2963
# Epoch 30 Batch 87250 Loss 0.4198 Accuracy 0.2963
# Epoch 30 Batch 87300 Loss 0.4197 Accuracy 0.2961
# Epoch 30 Batch 87350 Loss 0.4198 Accuracy 0.2961
# Epoch 30 Batch 87400 Loss 0.4199 Accuracy 0.2962
# Epoch 30 Batch 87450 Loss 0.4199 Accuracy 0.2962
# Epoch 30 Batch 87500 Loss 0.4202 Accuracy 0.2962
# Epoch 30 Batch 87550 Loss 0.4204 Accuracy 0.2963
# Epoch 30 Batch 87600 Loss 0.4207 Accuracy 0.2963
# Epoch 30 Batch 87650 Loss 0.4210 Accuracy 0.2964
# Epoch 30 Batch 87700 Loss 0.4212 Accuracy 0.2964
# Epoch 30 Batch 87750 Loss 0.4211 Accuracy 0.2963
# Epoch 30 Batch 87800 Loss 0.4213 Accuracy 0.2963
# Saving checkpoint for epoch 30 at /content/drive/MyDrive/Colab Notebooks/Transformer/checkpoints/gpu/model
# Save checkpoints
# Epoch 30 Loss 0.4213 Accuracy 0.2963
# Time taken for 1 epoch: 730.407232761383 secs
